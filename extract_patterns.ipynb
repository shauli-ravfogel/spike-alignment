# %%
# %load_ext autoreload
# %autoreload 2
import bert
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import spike_queries
import spacy
from typing import List
from collections import defaultdict
import tqdm
from termcolor import colored
from collections import Counter
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
def load_results(fname):
    
    with open(fname, "r", encoding = "utf-8") as f:
        sents = f.readlines()
    
    sents = [s.strip().split("\t")[-1] for s in sents]
    original, results = sents[0], sents[1:]
    return original, results


def get_spike_results_arguments_representations(model, spike_results, layers):
    
    sents = spike_results["sentence_text"].tolist()
    arg1_idx_start = spike_results["arg1_first_index"].to_numpy().astype(int)
    arg2_idx_start = spike_results["arg2_first_index"].to_numpy().astype(int)
    arg1_idx_end = spike_results["arg1_last_index"].to_numpy().astype(int)
    arg2_idx_end = spike_results["arg2_last_index"].to_numpy().astype(int)
    
    arg1_rep = []
    arg2_rep = []
    
    for s, arg1_start, arg2_start, arg1_end, arg2_end in zip(sents, arg1_idx_start, arg2_idx_start, arg1_idx_end, arg2_idx_end):
        #idx_to_mask = [arg1_start, arg2_start, arg1_end, arg2_end]
        H, _, _, orig2tok = model.encode(s, layers = layers)

        h1, h2 = H[orig2tok[arg1_start]:orig2tok[arg1_end] + 1], H[orig2tok[arg2_start]:orig2tok[arg2_end] + 1]
        
        h1 = np.mean(h1, axis = 0)
        h2 = np.mean(h2, axis = 0)
        
        arg1_rep.append(h1)
        arg2_rep.append(h2)
        
    arg1_mean = np.mean(arg1_rep, axis = 0)
    arg2_mean = np.mean(arg2_rep, axis = 0)
        
    return arg1_mean, arg2_mean
    


def main(filename, layers = [-1], num = 500):
    
    
    query, results1 = load_results(filename)
    results1 = results1[:num]
    
    spike_results = spike_queries.perform_query(query, dataset_name = "covid19", num_results = 100, query_type = "syntactic")
    spike_results = spike_results[spike_results['sentence_text'].notnull()]
    arg1_rep, arg2_rep = get_spike_results_arguments_representations(model, spike_results, layers)
        
    first, first_ind1, first_ind2 = spike_results["sentence_text"].tolist()[-1], int(spike_results["arg1_first_index"].tolist()[-1]), int(spike_results["arg2_first_index"].tolist()[-1])
    
    alignments = []
    
    for s in results1:
                    
        H, tokenized_text, tok_to_orig_map, orig2tok = model.encode(s, layers = layers)
        sims_arg1 = cosine_similarity([arg1_rep], H[1:-2])[0]
        sims_arg2 = cosine_similarity([arg2_rep], H[1:-2])[0]
        arg1_ind = np.argmax(sims_arg1) + 1
        
        sims_arg2[np.argmax(sims_arg1)] = -1
        arg2_ind = np.argmax(sims_arg2) + 1
        #print(arg1_ind, arg2_ind)
        if arg1_ind not in tok_to_orig_map or arg2_ind not in tok_to_orig_map:
            #print("ERROR")
            continue
        alignments.append((s, tok_to_orig_map[arg1_ind], tok_to_orig_map[arg2_ind]))
            
    return query, spike_results, alignments

# %%
model = bert.BertEncoder("cuda", "scibert")
# Out:
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# Model name 'allenai/scibert_scivocab_uncased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'allenai/scibert_scivocab_uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/vocab.txt from cache at /home/shauli/.cache/torch/transformers/e3debd8fbdf40874753724814ee0520f612b577b26c8755bca485103b47cd3bc.60287becc5ab96d85a4bf377eb90feaf3b9c80d3b23e84311dccd3588f56d4fb
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/added_tokens.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/special_tokens_map.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/tokenizer_config.json from cache at None
# loading weights file https://cdn.huggingface.co/allenai/scibert_scivocab_uncased/pytorch_model.bin from cache at /home/shauli/.cache/torch/transformers/54e18c298451d3195ba8359e7a3fa2bc04c70c730c5b6744928278e67940eacb.7587182ea55c40bf7fd0961c1176c31fa22558da2bf20c199874fa5a8ecb4613

# %% [markdown]
# ## Parse

# %%
def parse_results(sentences: List[str]):
    
    #nlp = spacy.load("en_core_sci_sm")
    nlp = spacy.load("en_core_sci_lg")
    
    docs = [spacy.tokens.Doc(vocab=nlp.vocab, words = sentence.split(" ")) for sentence in sentences]
    for name, proc in nlp.pipeline:
        for i,doc in enumerate(docs):
            docs[i] = proc(doc)
    return docs



def get_ancestors(tok):
    
    parents = [tok]
    
    while tok.head != tok:
    
        parents.append(tok.head)
        tok = tok.head
        
    
    return parents
    
def get_path_between_tokens(tok1, tok2, doc):
    
    path1 = get_ancestors(tok1)
    path2 = get_ancestors(tok2)
    #print(path1, path2)
    
    lowest_ancestor = None
    for tok in path1:
        if tok in path2:
            lowest_ancestor = tok
            break

    path1 =  path1[:path1.index(lowest_ancestor)+1]
    path2 =  path2[:path2.index(lowest_ancestor)+1]
    
    linear_path_before = [tok1 if tok1.i < tok2.i else tok2]
    linear_path_after = [tok1 if tok1.i > tok2.i else tok2]
    linear_path_between =  [t for t in doc if t.i < max(tok1.i, tok2.i) and t.i > min(tok1.i, tok2.i)]
    
    min_i, max_i = min(tok1.i, lowest_ancestor.i, tok2.i), max(tok1.i, lowest_ancestor.i, tok2.i)
    
    linear_path = [t.text for t in doc if t.i >= min_i and t.i <= max_i]
    linear_path[linear_path.index(tok1.text)] = colored(tok1.text, "red")
    linear_path[linear_path.index(tok2.text)] = colored(tok2.text, "blue")    
    linear_path_str = " ".join(linear_path)
    
    path = {"ancestor": lowest_ancestor, "path1": path1, "path2": path2, "tok1": tok1, "tok2": tok2, "linear_path": linear_path,
           "linear_path_str": linear_path_str}
    return path

# %%
#from spacy import displacy
#displacy.render(doc, style='dep', jupyter=True)

# %%
def regularize(path1: List[str], path2: List[str]):

    #print("path1", path1)
    #print("path2", path2)
    
    
    path1[-1] = color.BOLD + path1[-1] + color.END
    path2[0] = colored(path2[0], "blue")
    path1[0] = colored(path1[0], "red")
        
    path = path1 + path2[::-1][1:]

    return path
        

def get_paths(docs, alignments, path_type = "lemmas-deps"):

    paths_lemmas = []
    paths_deps = []
    paths_lemmas_deps = []
    paths_pos = []
    i = 0
    linear_paths = []
    
    for doc, (sent, idx1, idx2) in zip(docs, alignments):
        
        tok1, tok2 = doc[idx1], doc[idx2]
        
        try:
            path_dict = get_path_between_tokens(tok1, tok2, doc)
        except: continue #TODO: check the "None" error.
            
        linear_paths.append(path_dict["linear_path_str"])
    
        tok1_2ances = path_dict["path1"]
        tok2_2ances = path_dict["path2"]
        
        
        lemmas1 = [tok.lemma_ for tok in tok1_2ances]
        lemmas2 = [tok.lemma_ for tok in tok2_2ances]
        deps1 = [tok.dep_ for tok in tok1_2ances]
        deps2 = [tok.dep_ for tok in tok2_2ances]
        #pos1 = [tok.tag_ for tok in tok1_2ances]
        #pos2 = [tok.tag_ for tok in tok2_2ances]
        
        lemmas = regularize(lemmas1, lemmas2)
        deps = regularize(deps1, deps2)
        #pos = regularize(pos1, pos2)
        
        zipped = "-".join([lemma+"."+dep for lemma, dep in zip(lemmas, deps)])
        paths_lemmas_deps.append(zipped)
        paths_lemmas.append("-".join(lemmas))
        paths_deps.append("-".join(deps))
        #paths_pos.append("-".join(paths_pos))
        
        i += 1
    
    paths = None
    
    if path_type == "lemmas-deps":
        
        paths =  paths_lemmas_deps

    elif path_type == "lemmas":
        
        paths = paths_lemmas
    
    elif path_type == "deps":
        
        paths = paths_deps
    
    elif path_type == "pos":
        
        paths = paths_pos
    
    else:
        
        raise Exception("Unknown type")
    
    return paths, linear_paths

# %%
def sort_by_freq(paths, linear_paths):
    
    together = zip(paths, linear_paths)
    counts = []
    
    for p, p_lin in zip(paths, linear_paths):
        
        counts.append(paths.count(p))

    paths_linpaths_counts = zip(paths, linear_paths, counts)    
    paths_linpaths_counts = sorted(paths_linpaths_counts, key = lambda pair: -pair[-1])
    
    paths, linear_paths, counts = list(zip(*paths_linpaths_counts))
    return paths, linear_paths, counts

# %% [markdown]
# # Collect Paths

# %%
def collect(num_results, path_type):
    
    fnames = ["results{}.txt".format(i) for i in range(1,10)]
    k = 0
    
    for fname in fnames:
        query, spike_results, alignments = main(fname, layers = [-1], num = num_results)    
        sents = [s for s,ind1,ind2 in alignments]
        docs = parse_results(sents)
    
        paths, linear_paths = get_paths(docs, alignments, path_type)
        paths, linear_paths, counts = sort_by_freq(paths, linear_paths)
    
        #df = pd.DataFrame({"paths": paths, "linear_paths": linear_paths})
    
        print(color.BOLD + "QUERY {}:\n\t".format(k) + query + color.END )
        print(color.BOLD + "\nMOST FREQUENT PATTERNS:\n" + color.END)
        for i in range(100):
        
            print("PATH: "+ paths[i] + "\tLINEAR: " + linear_paths[i] +"\tCOUNT: " + str(counts[i]))
        
        print("\n\n")
        print("=================================================================")
        print("=================================================================")    
        
        k += 1

# %% [markdown]
# ## Pattern: dep labels + lemmas

# %%
collect(500, "lemmas-deps")
# Out:
# QUERY 0:
# 	<>arg1:virus $infection $causes a <>arg2:condition .
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infections cause a debilitating disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infection causes respiratory tract disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infection of JEV can cause nervous system disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: Infection with LIV in humans can cause a neurological disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: Infection with SARS-CoV causes lower respiratory tract disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: Infection with MAdV-1 causes multisystemic disease	COUNT: 7
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infection can cause severe lung disease	COUNT: 7
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection can result in severe respiratory disease	COUNT: 6
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection results in an acute , self-limiting and icteric disease	COUNT: 6
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection in humans often results in a severe , life-threatening disease	COUNT: 6
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection with encephalitic alphaviruses may result in severe neurologic disease	COUNT: 6
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: Infection by LCMV can result in acute central nervous system disease	COUNT: 6
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection of cattle with BoHV-1 generally results in inflammatory disease	COUNT: 6
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 4
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 4
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is also characterized	COUNT: 4
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection in humans is characterized	COUNT: 4
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: Infection with hMPV is associated	COUNT: 3
# PATH: infection.nsubjpass-characterize.ROOT-inflammation.nmod	LINEAR: infection in humans is characterized by extensive pulmonary inflammation	COUNT: 3
# PATH: infection.nsubj-result.ROOT-can.aux	LINEAR: infection of humans can result	COUNT: 3
# PATH: infection.nsubj-result.ROOT-can.aux	LINEAR: infection can result	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is associated	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is associated	COUNT: 3
# PATH: infection.nsubj-result.ROOT-can.aux	LINEAR: infection can results	COUNT: 3
# PATH: infection.nsubjpass-characterize.ROOT-inflammation.nmod	LINEAR: infections are characterized by inflammation	COUNT: 3
# PATH: infection.nsubjpass-characterize.ROOT-inflammation.nmod	LINEAR: infections are characterized by inflammation	COUNT: 3
# PATH: infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: infection , in domestic cats , causes a variable immunodeficiency syndrome	COUNT: 2
# PATH: virus.nsubj-cause.ROOT-disease.dobj	LINEAR: virus causes a lower respiratory tract disease	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-myocarditis.dobj	LINEAR: infection causes myocarditis	COUNT: 2
# PATH: pedv.compound-infection.nsubj-cause.ROOT-enteritis.dobj	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-illness.dobj	LINEAR: infection causes undifferentiated febrile illness	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-symptom.nmod-clinical.amod	LINEAR: Infection with DENV can cause a spectrum of clinical	COUNT: 2
# PATH: pedv.compound-infection.nsubj-cause.ROOT-enteritis.dobj	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-illness.dobj	LINEAR: infection causes illness	COUNT: 2
# PATH: disease.ROOT-result.acl-damage.nmod	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: disease.ROOT-result.acl-damage.nmod	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: bkv.nsubj-establish.ROOT-cause.conj-number.dobj-disorder.nmod	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: bkv.nsubj-establish.ROOT-cause.conj-number.dobj-disorder.nmod	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: Infection of humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: infection.ROOT-be.cop	LINEAR: is a systemic infection	COUNT: 2
# PATH: infection.nsubj-induce.ROOT-disease.dobj	LINEAR: Infection of both susceptible and resistant mouse strains induces an early acute disease	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-symptom.nmod-clinical.amod	LINEAR: infection causes a broad spectrum of clinical	COUNT: 2
# PATH: infection.nmod-associate.ROOT-onset.nsubjpass-enteritis.nmod	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection.nmod-associate.ROOT-onset.nsubjpass-enteritis.nmod	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection.ROOT-be.cop	LINEAR: is an important systemic parvoviral infection	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-disease.nmod	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-disease.nmod	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-can.aux	LINEAR: infection by SFTSV can cause	COUNT: 2
# PATH: pneumonia.dobj-cause.ROOT-however.advmod	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: pneumonia.dobj-cause.ROOT-however.advmod	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: infection.nsubj-result.ROOT-loss.nmod-focal.amod	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection.nsubj-result.ROOT-loss.nmod-focal.amod	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection.nsubj-result.ROOT-illness.nmod	LINEAR: Infection with CHIKV often results in acute illness	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-myocarditis.dobj	LINEAR: infection of mice can cause myocarditis	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-can.aux	LINEAR: infection can cause	COUNT: 2
# PATH: infection.nsubj-result.ROOT-illness.nmod	LINEAR: Infection of ZV results in a self-limiting mild illness	COUNT: 2
# PATH: virus.nsubj-cause.ROOT-disease.dobj	LINEAR: virus causes disease	COUNT: 2
# PATH: infection.nsubj-induce.ROOT-disease.dobj	LINEAR: infection in dogs generally induces a multisystemic disease	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-manifestation.dobj-neurologic.amod	LINEAR: infection can also cause neurologic	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-manifestation.dobj-neurologic.amod	LINEAR: infection can also cause neurologic	COUNT: 2
# PATH: be.cop-cause.ROOT-characterize.conj-be.auxpass	LINEAR: is the major cause of lower respiratory tract infections in infants and is	COUNT: 2
# PATH: be.cop-cause.ROOT-characterize.conj-be.auxpass	LINEAR: is the major cause of lower respiratory tract infections in infants and is	COUNT: 2
# PATH: virus.nsubj-induce.ROOT-inflammation.dobj	LINEAR: virus , like MHV-3 infection in mice , can induce exaggerated inflammation	COUNT: 1
# PATH: MERS-CoV.nsubj-induce.ROOT-pneumonia.dobj	LINEAR: MERS-CoV induces acute pneumonia	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-immunosuppression.dobj-progressive.amod	LINEAR: infection causes progressive	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-encephalitis.dobj-disorder.nmod-severe.amod	LINEAR: infection can cause Japanese encephalitis ( JE ) with severe	COUNT: 1
# PATH: infection.nsubj-produce.ROOT-disease.dobj	LINEAR: infection with HHV-6 can produce a mononucleosis-like illness and , more rarely , severe disease	COUNT: 1
# PATH: infection.nsubj-result.ROOT-illness.nmod-febrile.amod	LINEAR: Infection with MV typically results in an acute febrile	COUNT: 1
# PATH: brv.nsubj-infection.nsubj-component.ROOT-pathogenesis.nmod-disease.compound	LINEAR: BRV is a lytic infection and destruction of infected mucosal epithelial cells is an important component of disease	COUNT: 1
# PATH: disease.nsubj-begin.ROOT-progress.conj-stage.nmod-infection.nmod-characterize.acl:relcl-fever.nmod-shock.conj	LINEAR: disease begins with flu-like symptoms and progresses rapidly to the final stages of viral hemorrhagic fever infection , which are characterized by fever , hemorrhage , and hypotensive shock	COUNT: 1
# PATH: pedv.nsubj-infect.ROOT-cause.conj-atrophy.dobj-villi.nmod-result.acl-diarrhea.nmod	LINEAR: PEDV infects the epithelium of the small intestine , an environment rich in proteases , and causes atrophy of the villi resulting in diarrhea	COUNT: 1
# PATH: infection.nsubj-result.ROOT-associate.conj-gastroenteritis.nmod	LINEAR: infection results in respiratory tract complications with varying degree of severity and has been associated with gastroenteritis	COUNT: 1
# PATH: infect.acl-human.nsubj-develop.ROOT-syndrome.dobj	LINEAR: infected with RVFV usually develop an acute febrile myalgic syndrome	COUNT: 1
# PATH: prrsv.nsubj-increase.ROOT-result.advcl-severity.nmod	LINEAR: PRRSV increases the susceptibility of the host to a wide range of viral and bacterial respiratory pathogens , resulting in increased severity	COUNT: 1
# PATH: MERS-CoV.nsubj-cause.ROOT-infection.dobj	LINEAR: MERS-CoV causes severe infection	COUNT: 1
# PATH: sars-cov.nsubj-cause.ROOT-pneumonia.dobj	LINEAR: SARS-CoV causes interstitial pneumonia	COUNT: 1
# PATH: virus.nmod-spread.nmod-characterize.ROOT-be.auxpass	LINEAR: is characterized by a rapid and extensive spread of the virus	COUNT: 1
# PATH: infection.nsubjpass-represent.ROOT-be.auxpass	LINEAR: infection is mostly represented	COUNT: 1
# PATH: virus.nmod-ability.nmod-result.conj-damage.nmod	LINEAR: results from overwhelming cytopathic damage due to the ability of Ebola virus	COUNT: 1
# PATH: mers-cov.nmod-infect.acl-human.nsubjpass-report.ROOT-develop.xcomp-illness.dobj	LINEAR: MERS-CoV have been reported to develop a severe acute respiratory illness	COUNT: 1
# PATH: JEV.nsubj-invade.ROOT-trigger.advcl-response.dobj-inflammatory.amod	LINEAR: JEV invades the central nervous system , wherein virus replication triggers a massive inflammatory	COUNT: 1
# PATH: mcmv.nsubj-cause.ROOT-cause.conj-disease.dobj	LINEAR: MCMV causes asymptomatic infection in adult immunocompetent mice , but experimental inoculation of neonates has caused lethal disease	COUNT: 1
# PATH: infection.nsubj-lead.ROOT-viremia.nmod-to.case	LINEAR: infection leads to	COUNT: 1
# PATH: fiv.nsubj-pathogen.nsubj-cause.ROOT-degeneration.dobj-function.nmod-lead.acl:relcl-disease.nmod	LINEAR: FIV is an important viral pathogen worldwide in the domestic cat ( Felis catus ) , causes a slow progressive degeneration of immune functions that eventually leads to a disease	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-onset.dobj	LINEAR: infection causes a sudden onset	COUNT: 1
# PATH: infection.nsubj-result.ROOT-immunosuppression.nmod-severe.amod	LINEAR: infection in young chickens results in severe	COUNT: 1
# PATH: prrsv.compound-replicate.ROOT-lead.conj-infection.nmod-pneumonia.conj	LINEAR: PRRSV replicates mainly in porcine alveolar macrophages ( PAMs ) and dendritic cells ( DCs ) and leads to persistent infection , interstitial pneumonia	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-characterize.conj-cascade.nmod-event.nmod-lead.acl-inflammation.nmod-pulmonary.amod	LINEAR: Infection of SARS-CoV causes severe acute respiratory syndrome ( SARS ) , which is an emerging infectious disease and characterized by a cascade of immunological events leading to pulmonary	COUNT: 1
# PATH: mhv.compound-infection.nsubj-cause.ROOT-encephalitis.dobj	LINEAR: MHV infection causes encephalitis	COUNT: 1
# PATH: alphavirus.compound-infection.nsubj-induce.ROOT-arthritis.dobj	LINEAR: alphavirus infections , such as those involving CHIKV , Ross River virus ( RRV ) , and Sindbis virus ( SINV ) , induce debilitating arthritis	COUNT: 1
# PATH: infection.nsubjpass-characterize.ROOT-atrophy.nmod-intestine.nmod-result.acl:relcl-diarrhea.nmod	LINEAR: infection is characterized by severe villous atrophy in the small intestine that results in watery diarrhea	COUNT: 1
# PATH: virus.nsubj-able.advcl-cross.xcomp-stimulate.conj-inflammation.dobj	LINEAR: virus is able to cross the blood-brain barrier and stimulate inflammation	COUNT: 1
# PATH: mnv.compound-infection.nsubj-result.ROOT-replication.nmod-associate.acl-diarrhea.nmod	LINEAR: MNV infection in immunocompromised mice lacking innate immunity factors such as STAT1 or interferon receptors can result in persistent or acute virus replication associated with severe diarrhea	COUNT: 1
# PATH: infection.nsubj-result.ROOT-severe.nmod-disease.dep	LINEAR: infection results in severe and even fatal lung disease	COUNT: 1
# PATH: biv.nsubj-induce.ROOT-splenomegaly.dobj-syndrome.conj	LINEAR: BIV induces splenomegaly and lymphademopathy syndromes	COUNT: 1
# PATH: infection.nmod-consequence.nsubjpass-report.ROOT-result.parataxis-disease.nmod-cns.nmod-sepsis.conj	LINEAR: infection , such as acute flaccid paralysis , myocarditis , and Reye syndrome , have been reported [ 13 , 18 ] ; HPeV3 infection results in severe diseases of the CNS and neonatal sepsis	COUNT: 1
# PATH: jhmv.nmod-strain.nsubj-cause.ROOT-infection.dobj	LINEAR: jHMV cause a subacute or persistent infection	COUNT: 1
# PATH: marv.nsubj-cause.ROOT-illness.dobj	LINEAR: MARV causes an acute febrile illness	COUNT: 1
# PATH: virus.nmod-mouse.nmod-infection.nsubj-produce.ROOT-disease.dobj	LINEAR: virus produces clinical disease	COUNT: 1
# PATH: infection.nsubj-term.ROOT-cause.parataxis-enteritis.dobj	LINEAR: infection , also termed epizootic catarrhal enteritis or ECE , causes mucoid enteritis	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY 1:
# 	infected arg1:patients $usually $develop <>arg2:[entity]respiratory illness.
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: Infection with PEDV is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: Infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is clinically characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is characterized	COUNT: 9
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infections are characterized	COUNT: 9
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: Clinical signs of CPV-2 infection	COUNT: 5
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: Clinical signs in human infections	COUNT: 5
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: clinical signs of respiratory infection	COUNT: 5
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: clinical signs of BDV infection	COUNT: 5
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: clinical signs of FPV infection	COUNT: 5
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients who have pneumonic plague typically develop fulminant pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients rapidly develop pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: Patients with severe cases usually develop pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients with BCC develop a life-threatening , sometimes necrotizing , pneumonia	COUNT: 4
# PATH: patient.nsubj-present.ROOT-symptom.nmod	LINEAR: patients infected with SARS-CoV often present with symptoms	COUNT: 3
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: patient.nsubj-develop.ROOT-fever.dobj	LINEAR: patients develop rapid onset fever	COUNT: 3
# PATH: disease.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: disease is characterized	COUNT: 3
# PATH: patient.nsubj-present.ROOT-symptom.nmod	LINEAR: Patients with severe MERS often present with pneumonic symptoms	COUNT: 3
# PATH: patient.nsubj-develop.ROOT-fever.dobj	LINEAR: patients develop fever	COUNT: 3
# PATH: disease.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: disease in neonatal kids is characterized	COUNT: 3
# PATH: disease.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: disease is characterized	COUNT: 3
# PATH: patient.nsubj-present.ROOT-symptom.nmod	LINEAR: patients generally present with mild upper respiratory infection symptoms	COUNT: 3
# PATH: patient.nsubj-develop.ROOT-fever.dobj	LINEAR: patients usually develop fever	COUNT: 3
# PATH: human.nmod-infection.nsubj	LINEAR: Infection in humans	COUNT: 2
# PATH: infection.nmod-symptom.nsubj-clinical.amod	LINEAR: clinical symptoms of MERS-CoV infection	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-symptom.dobj	LINEAR: infection initially causes non-specific symptoms	COUNT: 2
# PATH: animal.nsubj-die.ROOT	LINEAR: animals usually die	COUNT: 2
# PATH: disease.ROOT-lead.conj-fever.nmod	LINEAR: disease , immature schistosomula pass through the lung and can lead to fever	COUNT: 2
# PATH: clinical.amod-manifestation.nsubj-evolve.ROOT-picture.nmod-septic.amod	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: clinical.amod-manifestation.nsubj-evolve.ROOT-picture.nmod-septic.amod	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: infant.nsubj-have.ROOT-symptom.dobj	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: infant.nsubj-have.ROOT-symptom.dobj	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: animal.nsubj-die.ROOT	LINEAR: animals usually die	COUNT: 2
# PATH: host.nsubj-develop.ROOT-diarrhea.dobj	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: host.nsubj-develop.ROOT-diarrhea.dobj	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: sepsis.nmod-sign.dobj-clinical.amod	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: sepsis.nmod-sign.dobj-clinical.amod	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: human.nmod-infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: humans typically causes an influenza-like syndrome	COUNT: 2
# PATH: human.nmod-disease.dobj	LINEAR: disease in humans	COUNT: 2
# PATH: human.nmod-disease.dobj	LINEAR: disease in humans	COUNT: 2
# PATH: human.nmod-infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: patient.nsubj-infection.nmod	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: infection.nmod-symptom.nsubj	LINEAR: symptoms of rapidly-lethal infections	COUNT: 2
# PATH: human.nmod-infection.nsubj	LINEAR: Infection in humans	COUNT: 2
# PATH: case.nmod-occur.ROOT-dyspnea.nsubj	LINEAR: cases , dyspnea and hypoxemia usually occur	COUNT: 2
# PATH: patient.nsubj-infection.nmod	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: be.cop-severe.ROOT-infection.nsubj	LINEAR: infection is usually more severe	COUNT: 2
# PATH: mouse.conj-suckle.nmod-growth.nmod-characterize.ROOT-infection.nsubjpass	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: mouse.conj-suckle.nmod-growth.nmod-characterize.ROOT-infection.nsubjpass	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-symptom.dobj	LINEAR: infection usually causes mild symptoms	COUNT: 2
# PATH: disease.ROOT-lead.conj-fever.nmod	LINEAR: disease , immature schistosomula pass through the lung , and can lead to fever	COUNT: 2
# PATH: be.cop-severe.ROOT-infection.nsubj	LINEAR: infection is usually more severe	COUNT: 2
# PATH: be.ROOT-disease.attr	LINEAR: is usually a self-limited disease	COUNT: 2
# PATH: be.ROOT-disease.attr	LINEAR: is usually a self-limited disease	COUNT: 2
# PATH: patient.nsubj-cause.ROOT-pneumonia.dobj	LINEAR: Patients infected with COVID-19 typically present with fever , cough , dyspnea , and myalgia , and the infection may cause severe pneumonia	COUNT: 2
# PATH: patient.nsubj-cause.ROOT-pneumonia.dobj	LINEAR: Patients infected with COVID-19 typically present with fever , cough , dyspnea , and myalgia , and the infection may cause severe pneumonia	COUNT: 2
# PATH: infection.nsubj-result.ROOT-diarrhea.nmod	LINEAR: infections usually result in diarrhea	COUNT: 2
# PATH: disease.nsubj-manifest.ROOT-infection.nmod	LINEAR: disease caused by the virus manifests in most cases as a lower respiratory tract infection	COUNT: 2
# PATH: disease.nsubj-manifest.ROOT-infection.nmod	LINEAR: disease caused by the virus manifests in most cases as a lower respiratory tract infection	COUNT: 2
# PATH: infection.nmod-symptom.nsubj-clinical.amod	LINEAR: clinical symptoms of norovirus infection	COUNT: 2
# PATH: infection.nmod-symptom.nsubj	LINEAR: symptoms of calicivirus infection	COUNT: 2
# PATH: case.nmod-occur.ROOT-dyspnea.nsubj	LINEAR: cases , dyspnea occurs	COUNT: 2
# PATH: human.nmod-symptom.nsubj	LINEAR: Symptoms in humans	COUNT: 2
# PATH: infection.nsubj-result.ROOT-diarrhea.nmod	LINEAR: infection results in profuse greenish , mucoid diarrhea	COUNT: 2
# PATH: human.nmod-symptom.nsubj	LINEAR: Symptoms in humans	COUNT: 2
# PATH: cat.conj-young.nsubj-have.aux-profuse.ROOT-diarrhea.conj	LINEAR: cats with cryptosporidiosis will have profuse , watery diarrhea	COUNT: 2
# PATH: cat.conj-young.nsubj-have.aux-profuse.ROOT-diarrhea.conj	LINEAR: cats with cryptosporidiosis will have profuse , watery diarrhea	COUNT: 2
# PATH: people.nsubj-manifest.ROOT-feature.dobj-pneumonia.nmod	LINEAR: people commonly manifest features of pneumonia	COUNT: 1
# PATH: patient.nsubj-exhibit.ROOT-encephalopathy.dobj-encephalitis.conj	LINEAR: Patients suffering from severe DENV infection often exhibit encephalopathy and encephalitis	COUNT: 1
# PATH: cat.nsubj-show.ROOT-sign.dobj-clinical.amod	LINEAR: Cats with FIP show nonspecific clinical	COUNT: 1
# PATH: cat.nsubj-have.ROOT	LINEAR: Cats with signs from FIV often have	COUNT: 1
# PATH: infection.nsubj-enteric.amod	LINEAR: Enteric FCoV infection	COUNT: 1
# PATH: patient.nsubj-develop.ROOT-illness.dobj-respiratory.amod	LINEAR: patients with MERS develop severe acute respiratory	COUNT: 1
# PATH: infection.nmod-stage.nsubj-include.ROOT-bleeding.dobj	LINEAR: infection usually include diffuse bleeding	COUNT: 1
# PATH: infection.nsubj-asymptomatic.ROOT-occur.advcl-sign.nsubj-clinical.amod	LINEAR: infection is usually asymptomatic , although nonspecific clinical	COUNT: 1
# PATH: patient.nsubj-present.ROOT-headache.nmod-severe.amod	LINEAR: patients can present with severe	COUNT: 1
# PATH: patient.nsubj-deteriorate.ROOT-present.conj-symptom.nmod	LINEAR: Patients infected with EVD rapidly deteriorate and commonly present with gastrointestinal symptoms	COUNT: 1
# PATH: rabbit.nsubj-develop.ROOT-course.dobj-disease.compound	LINEAR: rabbits usually develop a chronic disease	COUNT: 1
# PATH: cat.nsubjpass-infect.ROOT-manifest.conj-disease.nsubj	LINEAR: Cats are primarily infected subclinically , but gastrointestinal disease	COUNT: 1
# PATH: marmoset.nsubj-infection.nmod	LINEAR: marmosets with measles infection	COUNT: 1
# PATH: human.nmod-cause.ROOT-onset.dobj-sudden.amod	LINEAR: humans , VEEV infection causes a sudden	COUNT: 1
# PATH: human.nsubj-develop.ROOT-syndrome.dobj	LINEAR: Humans infected with RVFV usually develop an acute febrile myalgic syndrome	COUNT: 1
# PATH: patient.nmod-subset.nsubj-progress.conj-associate.ROOT-infection.nsubjpass	LINEAR: infection is associated with fever and liver damage , but a subset of patients	COUNT: 1
# PATH: human.nmod-present.ROOT-infection.nmod	LINEAR: presents in humans as a lower respiratory infection	COUNT: 1
# PATH: patient.nsubj-develop.ROOT-symptom.dobj	LINEAR: Patients with bubonic plague usually develop symptoms	COUNT: 1
# PATH: infection.nsubj-symptomatic.amod	LINEAR: Symptomatic CHIKV infection	COUNT: 1
# PATH: pneumonia.nsubj-have.ROOT-worsen.conj-symptom.nsubj-respiratory.amod	LINEAR: Pneumonia caused by SARS-CoV typically has an insidious onset , and respiratory	COUNT: 1
# PATH: those.nsubj-suffer.ROOT-progress.conj-inflammation.nmod-lung.compound	LINEAR: Those infected with SARS suffer fever , cough , muscle aches , and shortness of breath and often progress to severe lung	COUNT: 1
# PATH: human.nmod-infection.nsubj-cause.ROOT-illness.dobj	LINEAR: humans usually causes a self-limiting , acute and febrile illness	COUNT: 1
# PATH: human.amod-leptospirosis.nsubj	LINEAR: Human leptospirosis	COUNT: 1
# PATH: pig.nsubj-present.ROOT-symptom.dobj-as.prep-vomiting.pobj-diarrhea.conj	LINEAR: Pigs that are infected with TGEV usually present symptoms such as vomiting , dehydration , and severe diarrhea	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY 2:
# 	a arg1:subset of patients $progress to arg2:hemorrhagic fever
#
# MOST FREQUENT PATTERNS:
#
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: Severe pediatric cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 9
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 9
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 4
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-failure.dobj-severe.amod	LINEAR: patients develop severe	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-failure.dobj-severe.amod	LINEAR: patients can develop severe	COUNT: 4
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 4
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-failure.dobj-severe.amod	LINEAR: patients rapidly develop severe	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-failure.dobj-severe.amod	LINEAR: patients rapidly develop severe	COUNT: 4
# PATH: disease.nsubj-progress.ROOT-failure.nmod-respiratory.amod	LINEAR: disease may progress into respiratory	COUNT: 3
# PATH: disease.nsubj-progress.ROOT-failure.nmod-respiratory.amod	LINEAR: disease quickly progresses to respiratory	COUNT: 3
# PATH: disease.nsubj-progress.ROOT-failure.nmod-respiratory.amod	LINEAR: disease quickly progresses to respiratory	COUNT: 3
# PATH: disease.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , the disease may progress	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: -PRON-.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , it can progress	COUNT: 2
# PATH: condition.nsubj-develop.ROOT-case.nmod-severe.amod	LINEAR: severe cases , the conditions may develop	COUNT: 2
# PATH: condition.nsubj-develop.ROOT-case.nmod-severe.amod	LINEAR: severe cases , the conditions may develop	COUNT: 2
# PATH: pneumonia.nsubj-develop.ROOT-progress.conj-failure.nmod-respiratory.amod	LINEAR: Pneumonia develops with primary infection , occurs rarely in children , and progresses to respiratory	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-disease.dobj-severe.amod	LINEAR: patients may develop severe	COUNT: 2
# PATH: disease.nsubj-progress.advcl-pneumonia.nmod-viral.amod	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease.nsubj-progress.advcl-pneumonia.nmod-viral.amod	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-result.conj-failure.nmod-cardiac.amod	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-result.conj-failure.nmod-cardiac.amod	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: pneumonia.nmod-viral.amod	LINEAR: viral pneumonia	COUNT: 2
# PATH: pneumonia.nmod-viral.amod	LINEAR: viral pneumonia	COUNT: 2
# PATH: Disease.nsubj-progress.ROOT-syndrome.nmod-and.cc	LINEAR: Disease can progress to acute respiratory distress syndrome and	COUNT: 2
# PATH: Disease.nsubj-progress.ROOT-syndrome.nmod-and.cc	LINEAR: Disease can progress to acute respiratory distress syndrome and	COUNT: 2
# PATH: patient.nsubj-infection.nmod-severe.amod	LINEAR: patients with severe	COUNT: 2
# PATH: pneumonia.nsubj-develop.ROOT-progress.conj-failure.nmod-respiratory.amod	LINEAR: Pneumonia develops rapidly and eventually progresses after 2 to 4 days into respiratory	COUNT: 2
# PATH: case.nmod-severe.amod	LINEAR: severe cases	COUNT: 2
# PATH: patient.nsubj-infection.nmod-severe.amod	LINEAR: Patients with severe	COUNT: 2
# PATH: case.nsubj-develop.ROOT-edema.dobj-pulmonary.amod	LINEAR: cases often develop refractory pulmonary	COUNT: 2
# PATH: case.nsubj-develop.ROOT-edema.dobj-pulmonary.amod	LINEAR: cases often develop refractory pulmonary	COUNT: 2
# PATH: patient.nsubj-progress.ROOT-may.aux	LINEAR: patients may progress	COUNT: 2
# PATH: can.aux-result.ROOT-complication.nsubj-involvement.nmod-pulmonary.amod	LINEAR: pulmonary involvement can result	COUNT: 2
# PATH: can.aux-result.ROOT-complication.nsubj-involvement.nmod-pulmonary.amod	LINEAR: pulmonary involvement can result	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-failure.dobj-response.conj-severe.amod	LINEAR: Patients whose condition deteriorates to critical status primarily decompensate from a respiratory standpoint , but may also develop multi-organ failure ( respiratory failure , cardiac failure , renal failure , hypercoagulable state , thrombotic microangiopathy ) , as well as severe	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-failure.dobj-response.conj-severe.amod	LINEAR: Patients whose condition deteriorates to critical status primarily decompensate from a respiratory standpoint , but may also develop multi-organ failure ( respiratory failure , cardiac failure , renal failure , hypercoagulable state , thrombotic microangiopathy ) , as well as severe	COUNT: 2
# PATH: pneumonia.nsubj-severe.amod	LINEAR: Severe pneumonia	COUNT: 2
# PATH: patient.nsubj-progress.ROOT-may.aux	LINEAR: patients may progress	COUNT: 2
# PATH: disease.nmod-form.dobj-experience.ROOT-suffer.conj-complication.dobj-severe.amod	LINEAR: experience a mild form of disease , but those with advanced age or underlying comorbidities may suffer severe	COUNT: 2
# PATH: disease.nmod-form.dobj-experience.ROOT-suffer.conj-complication.dobj-severe.amod	LINEAR: experience a mild form of disease , but those with advanced age or underlying comorbidities may suffer severe	COUNT: 2
# PATH: -PRON-.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , it can progress	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-disease.dobj-severe.amod	LINEAR: patients of every age can develop severe	COUNT: 2
# PATH: patient.nsubj-have.advcl-develop.ROOT-lead.advcl-death.nmod	LINEAR: patients have mild symptoms such as fever , headache , cough , myalgia and anosmia , some develop acute respiratory distress syndrome , leading to death	COUNT: 2
# PATH: patient.nsubj-have.advcl-develop.ROOT-lead.advcl-death.nmod	LINEAR: patients have mild symptoms such as fever , headache , cough , myalgia and anosmia , some develop acute respiratory distress syndrome , leading to death	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , the disease may progress	COUNT: 2
# PATH: patient.nsubj-progress.ROOT-develop.xcomp	LINEAR: patients progress rapidly to develop	COUNT: 2
# PATH: patient.nsubj-progress.ROOT-develop.xcomp	LINEAR: patients progress rapidly to develop	COUNT: 2
# PATH: disease.ROOT-progressive.amod	LINEAR: progressive local disease	COUNT: 2
# PATH: disease.ROOT-progressive.amod	LINEAR: progressive local disease	COUNT: 2
# PATH: -PRON-.nsubj-result.ROOT-syndrome.nmod-failure.conj-respiratory.amod	LINEAR: it may result in adult respiratory distress syndrome and respiratory	COUNT: 2
# PATH: -PRON-.nsubj-result.ROOT-syndrome.nmod-failure.conj-respiratory.amod	LINEAR: it may result in adult respiratory distress syndrome and respiratory	COUNT: 2
# PATH: disease.nmod-result.ROOT-lymphadenopathy.conj-generalize.amod	LINEAR: results in disease that is less severe and commonly presents as nondescript , consisting of fever , myalgia , and generalized	COUNT: 2
# PATH: disease.nmod-result.ROOT-lymphadenopathy.conj-generalize.amod	LINEAR: results in disease that is less severe and commonly presents as nondescript , consisting of fever , myalgia , and generalized	COUNT: 2
# PATH: disease.nmod-form.nsubj-this.det	LINEAR: this form of the disease	COUNT: 2
# PATH: disease.nmod-form.nsubj-this.det	LINEAR: this form of the disease	COUNT: 2
# PATH: disease.nmod-onset.nsubj-begin.ROOT-case.nmod-symptomatic.amod	LINEAR: symptomatic cases , the onset of disease begins	COUNT: 2
# PATH: disease.nmod-onset.nsubj-begin.ROOT-case.nmod-symptomatic.amod	LINEAR: symptomatic cases , the onset of disease begins	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-plague.dobj-pneumonic.amod-severe.amod	LINEAR: disease may progress to severe	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-plague.dobj-pneumonic.amod-severe.amod	LINEAR: disease may progress to severe	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj-severe.amod	LINEAR: patients may develop severe	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj-severe.amod	LINEAR: patients may develop severe	COUNT: 2
# PATH: may.aux-progress.ROOT-to.prep-state.pobj-toxic.amod	LINEAR: may progress to an increasingly toxic	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-can.aux	LINEAR: disease in this age group can progress	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-can.aux	LINEAR: disease can progress	COUNT: 2
# PATH: pneumonia.nsubj-severe.amod	LINEAR: Severe pneumonia	COUNT: 2
# PATH: may.aux-progress.ROOT-to.prep-state.pobj-toxic.amod	LINEAR: may progress to an increasingly toxic	COUNT: 2
# PATH: be.cop-asymptomatic.advcl-cause.ROOT-symptom.dobj-serious.amod	LINEAR: is usually asymptomatic , cryptococcosis can cause serious	COUNT: 2
# PATH: be.cop-asymptomatic.advcl-cause.ROOT-symptom.dobj-serious.amod	LINEAR: is usually asymptomatic , cryptococcosis can cause serious	COUNT: 2
# PATH: infection.nsubj-develop.ROOT-presentation.nmod-include.acl:relcl-pharyngitis.dobj-disease.conj	LINEAR: Infection usually develops within the first 3 months of transplantation , with a presentation that might include pharyngitis , tracheitis , bronchitis , pneumonitis , enteritis , hemorrhagic cystitis , or disseminated disease	COUNT: 2
# PATH: infection.nsubj-develop.ROOT-presentation.nmod-include.acl:relcl-pharyngitis.dobj-disease.conj	LINEAR: Infection usually develops within the first 3 months of transplantation , with a presentation that might include pharyngitis , tracheitis , bronchitis , pneumonitis , enteritis , hemorrhagic cystitis , or disseminated disease	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-lead.advcl-to.prep-dyspnea.pobj-stridor.conj-cyanosis.conj-shock.conj-septic.amod	LINEAR: disease progresses rapidly , leading to dyspnea , stridor , cyanosis , and septic	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-lead.advcl-to.prep-dyspnea.pobj-stridor.conj-cyanosis.conj-shock.conj-septic.amod	LINEAR: disease progresses rapidly , leading to dyspnea , stridor , cyanosis , and septic	COUNT: 2
# PATH: Disease.nsubjpass-limited.ROOT-progress.conj-infection.nmod-bronchiolitis.nmod-pneumonia.conj	LINEAR: Disease is mostly limited to the upper airways and is self-limiting , but a small percentage can progress to lower respiratory tract infections as bronchiolitis and pneumonia	COUNT: 2
# PATH: Disease.nsubjpass-limited.ROOT-progress.conj-infection.nmod-bronchiolitis.nmod-pneumonia.conj	LINEAR: Disease is mostly limited to the upper airways and is self-limiting , but a small percentage can progress to lower respiratory tract infections as bronchiolitis and pneumonia	COUNT: 2
# PATH: infection.nmod-some.nsubj-severe.ROOT	LINEAR: infections may be severe	COUNT: 2
# PATH: infection.nmod-some.nsubj-severe.ROOT	LINEAR: infections may be severe	COUNT: 2
# PATH: patient.nmod-shock.nmod	LINEAR: shock in approximately 15 % patients	COUNT: 2
# PATH: case.nsubj-die.ROOT-have.conj-sign.dobj-clinical.amod	LINEAR: cases may die within 1 to 2 days because of overwhelming viremia and vasculitis of all major organs and yet have minimal clinical	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY 3:
# 	people with arg1:[e]asthma are $susceptible to arg2:[e]asthma
#
# MOST FREQUENT PATTERNS:
#
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are highly susceptible to infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are highly susceptible to infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to the infection	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infection	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infections	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients with iatrogenic or disease related immune suppression are highly susceptible to infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are generally more susceptible to infections	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients who are immunocompromised such as due to steroids or organ and hematopoietic stem cell transplantation are highly susceptible to atypical viral infections	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer may be as susceptible to active Mycobacterium tuberculous infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are also susceptible to nosocomial viral infections	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients with hematologic malignancies , especially in the neutropenic state after aggressive chemotherapy or HSCT and HSCT recipients with GVHD , are particularly susceptible to invasive fungal infections	COUNT: 9
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to bacterial , fungal , viral , and parasitic infections	COUNT: 9
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients with DAH are especially susceptible to pulmonary infections	COUNT: 9
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients , particularly those under anticancer treatment , are potentially more susceptible for a severe infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients and immunocompromised hosts are particularly susceptible to lung infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are more susceptible to infections	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer patients are more susceptible to infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are potentially more susceptible to Coronavirus infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are more susceptible to infections	COUNT: 6
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with liver cirrhosis or liver cancer are at high risk of SARS-CoV-2 infection	COUNT: 5
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with defective cell-mediated immunity are at risk of infections	COUNT: 5
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with primary adrenal insufficiency including Addison 's disease and congenital adrenal hyperplasia are at an increased risk of infections	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with prolonged neutropenia who have received intensive cytotoxic chemotherapy are at risk for invasive fungal infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: patients , especially those with neutropenia , are at increased risk of infection	COUNT: 5
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 5
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 5
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients , including those with HIV/AIDS and patients taking immunosuppressants post-transplant , are at an increased risk for viral and fungal pneumonia	COUNT: 4
# PATH: patient.nsubj-prone.ROOT-infection.nmod	LINEAR: patients are also more prone to RSV infections	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: Patients with immunodeficiency syndromes are also at risk of pneumonia	COUNT: 4
# PATH: patient.nsubj-prone.ROOT-infection.nmod	LINEAR: Patients with ESLD are prone to infections	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients with associated CD4 + cell depletion not receiving appropriate prophylaxis are at high risk for Pneumocystis jiroveci pneumonia	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients with a single LT may be at greater risk of pneumonia	COUNT: 4
# PATH: patient.nsubj-prone.ROOT-infection.nmod	LINEAR: patients , including not only those with HIV infection but also those who undergo small bowel transplantation for short bowel syndrome , are prone to CMV infection	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# ...
# PATH: sars-cov-2.nsubj-infect.ccomp-tract.dobj	LINEAR: SARS-CoV-2 infects the GI tract	COUNT: 2
# PATH: sars-cov-2.nsubj-infect.ccomp-tract.dobj	LINEAR: SARS-CoV-2 infects the GI tract	COUNT: 2
# PATH: sars-cov-2.nsubj-recognize.ROOT-receptor.nmod-allow.acl:relcl-infect.xcomp-cell.dobj	LINEAR: SARS-CoV-2 recognizes the human Angiotensin Converting Enzyme 2 ( hACE2 ) as a cellular receptor that allows it to infect different host cells	COUNT: 2
# PATH: sars-cov-2.nsubj-recognize.ROOT-receptor.nmod-allow.acl:relcl-infect.xcomp-cell.dobj	LINEAR: SARS-CoV-2 recognizes the human Angiotensin Converting Enzyme 2 ( hACE2 ) as a cellular receptor that allows it to infect different host cells	COUNT: 2
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.nmod-cell.nmod	LINEAR: SARS-CoV-2 binds to the ACE2 receptor on ciliated bronchial epithelial cells	COUNT: 2
# PATH: sars-cov-2.nmod-enter.acl:relcl-cell.dobj	LINEAR: SARS-CoV-2 , which enters host cells	COUNT: 2
# PATH: sars-cov-2.appos-coronavirus.ROOT-infect.acl:relcl-cell.dobj	LINEAR: coronavirus 2 ( SARS-CoV-2 ) ( 6 ) , which infects the cells	COUNT: 2
# PATH: sars-cov-2.appos-coronavirus.ROOT-infect.acl:relcl-cell.dobj	LINEAR: coronavirus 2 ( SARS-CoV-2 ) ( 6 ) , which infects the cells	COUNT: 2
# PATH: sars-cov-2.nsubj-infect.ROOT-airway.dobj	LINEAR: SARS-Cov-2 first predominantly infects lower airways	COUNT: 2
# PATH: SARS-CoV-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters the host cells	COUNT: 2
# PATH: sars-cov2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV2 infects lung alveolar epithelial cells	COUNT: 2
# PATH: sars-cov-2.nsubj-virus.ROOT-be.conj-evidence.attr-associate.acl-surface-exposed.advcl-mediate.conj-entry.dobj-cell.nmod	LINEAR: SARS-CoV-2 is an enveloped virus and there are ample evidences that its Spike protein ( S-protein ) is mainly associated with pathogenesis as it is surface-exposed and mediates entry into host cells	COUNT: 2
# PATH: sars-cov-2.nsubj-virus.ROOT-be.conj-evidence.attr-associate.acl-surface-exposed.advcl-mediate.conj-entry.dobj-cell.nmod	LINEAR: SARS-CoV-2 is an enveloped virus and there are ample evidences that its Spike protein ( S-protein ) is mainly associated with pathogenesis as it is surface-exposed and mediates entry into host cells	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-invade.xcomp-cell.dobj	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell receptor to invade human cells	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-invade.xcomp-cell.dobj	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell receptor to invade human cells	COUNT: 2
# PATH: sars-cov-2.nmod-entry.nsubjpass-cell.nmod	LINEAR: entry of SARS-CoV-2 into host cells	COUNT: 2
# PATH: sars-cov-2.nmod-enter.acl:relcl-cell.dobj	LINEAR: SARS-CoV-2 , which enters human target cells	COUNT: 2
# PATH: sars-cov-2.nsubj-use.ccomp-enter.xcomp-cell.dobj	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2 ) as a viral receptor to enter the target cell	COUNT: 2
# PATH: SARS-CoV-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters the cell	COUNT: 2
# PATH: sars-cov-2.nsubj-have.ROOT-potential.dobj-replicate.acl-cardiomyocyte.nmod	LINEAR: SARS-CoV-2 has the potential to directly replicate within cardiomyocytes	COUNT: 2
# PATH: sars-cov-2.nsubj-have.ROOT-potential.dobj-replicate.acl-cardiomyocyte.nmod	LINEAR: SARS-CoV-2 has the potential to directly replicate within cardiomyocytes	COUNT: 2
# PATH: sars-cov-2.conj-sars-cov.nsubj-interact.ROOT-enter.xcomp-cell.dobj	LINEAR: SARS-CoV-2 interact directly with angiotensin-converting enzyme 2 ( ACE2 ) to enter host target cells	COUNT: 2
# PATH: sars-cov-2.conj-sars-cov.nsubj-interact.ROOT-enter.xcomp-cell.dobj	LINEAR: SARS-CoV-2 interact directly with angiotensin-converting enzyme 2 ( ACE2 ) to enter host target cells	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-enter.xcomp-cell.dobj	LINEAR: SARS-CoV-2 uses a spike protein binding the angiotensin converting enzyme ( ACE2 ) to enter the cells	COUNT: 2
# PATH: sars-cov-2.nsubj-use.ccomp-enter.xcomp-cell.dobj	LINEAR: SARS-CoV-2 may use host receptor angiotensin-converting enzyme 2 ( ACE2 ) to enter the cells	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY 8:
# 	arg1:[e]COVID-19 activates the arg2:ATP $receptor
#
# MOST FREQUENT PATTERNS:
#
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: Enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 16
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 and SARS-CoV use angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 also uses human angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 and SARS-CoV use the angiotensin converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme II ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 also uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 11
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 might also use ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 also uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 also uses both ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 can use ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 binds to the angiotensin-converting enzyme 2 ( ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 binds to the angiotensin-converting enzyme 2 ( ACE2	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses receptor ACE2	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 4
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 4
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 also uses ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 binds to the Angiotensin-converting enzyme 2 ( ACE2	COUNT: 4
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 binds to the angiotensin I converting enzyme 2 ( ACE2	COUNT: 4
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 4
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , like SARS-CoV , uses the same receptor angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , like SARS-CoV ( Li et al. , 2003 ) , uses the angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: (ace)-2.dep-receptor.dobj	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 also uses the ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 use the ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 may use angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: 2.nummod-receptor.dobj-ace2.compound	LINEAR: 2 ( ACE2 ) receptor	COUNT: 3
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.nmod-ace2.compound	LINEAR: SARS-CoV-2 binds to the ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: (ace)-2.dep-receptor.dobj	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-receptor.nmod-cell.compound	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-receptor.nmod-cell.compound	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell	COUNT: 3
# PATH: 2.nummod-receptor.dobj-ace2.compound	LINEAR: 2 ( ACE2 ) receptor	COUNT: 3
# PATH: sars-cov-2.nsubj-employ.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 employs the SARS-CoV receptor ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-employ.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 employs ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-employ.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 employs the SARS-CoV receptor ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the receptor angiotensinconverting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 3
# PATH: 2.nummod-receptor.dobj-ace2.compound	LINEAR: 2 ( ACE2 ) receptor	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.nmod-ace2.compound	LINEAR: SARS-CoV-2 binds with the ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-receptor.nmod-cell.compound	LINEAR: SARS-CoV-2 uses the membrane protein Angiotensin I converting enzyme 2(ACE2 ) as a cell	COUNT: 3
# PATH: sars-cov-2.nsubj-bind.ROOT-receptor.nmod-ace2.compound	LINEAR: SARS-CoV-2 binds to the ACE2	COUNT: 3
# PATH: (ace)-2.dep-receptor.dobj	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: sars-cov-2.nsubj-enter.ROOT-bind.advcl-domain.nmod-enzyme.nmod-ace2.appos	LINEAR: SARS-CoV-2 enters human cells by binding to the extracellular domain of Angiotensin Converting Enzyme 2 ( ACE2	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 , much like the structurally similar and precedent SARS-CoV , uses the ACE2	COUNT: 2
# PATH: sars-cov-2.nsubj-utilize.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 utilizes ACE2	COUNT: 2
# PATH: SARS-CoV-2.nsubjpass-show.ROOT-use.xcomp-receptor.dobj-cell.compound	LINEAR: SARS-CoV-2 has been shown to use the same cell	COUNT: 2
# PATH: SARS-CoV-2.nsubjpass-show.ROOT-use.xcomp-receptor.dobj-cell.compound	LINEAR: SARS-CoV-2 has been shown to use the same cell	COUNT: 2
# PATH: sars-cov-2.nsubj-enter.ROOT-bind.advcl-domain.nmod-enzyme.nmod-ace2.appos	LINEAR: SARS-CoV-2 enters human cells by binding to the extracellular domain of Angiotensin Converting Enzyme 2 ( ACE2	COUNT: 2
# PATH: sars-cov-2.nsubj-require.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , as well as other corona viruses , requires the angiotensin-converting enzyme 2 ( ACE2	COUNT: 2
# PATH: ace2.compound-receptor.nmod-cell.compound	LINEAR: cell ACE2 receptors	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj	LINEAR: SARS-CoV-2 uses the angiotensin converting enzyme	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj	LINEAR: SARS-CoV-2 uses the angiotensin converting enzyme	COUNT: 2
# PATH: covid-19.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: COVID-19 uses the angiotensin converting enzyme II ( ACE2	COUNT: 2
# PATH: 2.nummod-enzyme.nmod-ace2.appos	LINEAR: enzyme 2 ( ACE2	COUNT: 2
# PATH: SARS-CoV-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 2
# PATH: sars-cov-2.conj-sars-cov.nsubj-interact.ROOT-enzyme.nmod-ace2.appos	LINEAR: SARS-CoV-2 interact directly with angiotensin-converting enzyme 2 ( ACE2	COUNT: 2
# PATH: sars-cov-2.conj-sars-cov.nsubj-interact.ROOT-enzyme.nmod-ace2.appos	LINEAR: SARS-CoV-2 interact directly with angiotensin-converting enzyme 2 ( ACE2	COUNT: 2
# PATH: sars-cov-2.nsubj-require.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , just like SARS-CoV , requires the angiotensinconverting enzyme 2 ( ACE2	COUNT: 2
# PATH: sars-cov-2.nsubj-recognize.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 also recognizes human ACE2	COUNT: 2
# PATH: ace2.nsubjpass-identify.advcl-surprising.ROOT-adapt.ccomp-bind.xcomp-ace2.dobj	LINEAR: ACE2 was identified as the receptor for SARS-CoV , it is not surprising that SARS-CoV has adapted itself to bind human ACE2	COUNT: 2
# PATH: ace2.nsubjpass-identify.advcl-surprising.ROOT-adapt.ccomp-bind.xcomp-ace2.dobj	LINEAR: ACE2 was identified as the receptor for SARS-CoV , it is not surprising that SARS-CoV has adapted itself to bind human ACE2	COUNT: 2
# PATH: sars-cov-2.nmod-receptor.xcomp-show.ROOT-enzyme.nsubjpass-ace2.appos	LINEAR: ACE2 ) has been shown to be a functional receptor for SARS-CoV-2	COUNT: 2
# PATH: sars-cov-2.nmod-receptor.xcomp-show.ROOT-enzyme.nsubjpass-ace2.appos	LINEAR: ACE2 ) has been shown to be a functional receptor for SARS-CoV-2	COUNT: 2
# PATH: ace2.nmod-invade.conj-belong.ROOT-covid-19.nsubj-both.cc:preconj	LINEAR: Both COVID-19 and SARS-CoV belong to the coronavirus family and both invade target cells through ACE2	COUNT: 2
#
#
#
# =================================================================
# =================================================================

# %% [markdown]
# ## Pattern: lemmas along dep path

# %%
collect(500, "lemmas")
# Out:
# QUERY 0:
# 	<>arg1:virus $infection $causes a <>arg2:condition .
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection-cause-disease	LINEAR: infections cause a debilitating disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: infection causes respiratory tract disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: infection in humans can cause a wide range of clinical manifestations , from mild febrile disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: infection of JEV can cause nervous system disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: Infection with LIV in humans can cause a neurological disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: Infection with SARS-CoV causes lower respiratory tract disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: Infection with MAdV-1 causes multisystemic disease	COUNT: 8
# PATH: infection-cause-disease	LINEAR: infection can cause severe lung disease	COUNT: 8
# PATH: infection-result-disease	LINEAR: infection can result in severe respiratory disease	COUNT: 6
# PATH: infection-result-disease	LINEAR: infection results in an acute , self-limiting and icteric disease	COUNT: 6
# PATH: infection-result-disease	LINEAR: infection in humans often results in a severe , life-threatening disease	COUNT: 6
# PATH: infection-result-disease	LINEAR: infection with encephalitic alphaviruses may result in severe neurologic disease	COUNT: 6
# PATH: infection-result-disease	LINEAR: Infection by LCMV can result in acute central nervous system disease	COUNT: 6
# PATH: infection-result-disease	LINEAR: infection of cattle with BoHV-1 generally results in inflammatory disease	COUNT: 6
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 4
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 4
# PATH: infection-characterize-be	LINEAR: infection is also characterized	COUNT: 4
# PATH: infection-characterize-be	LINEAR: infection in humans is characterized	COUNT: 4
# PATH: infection-associate-be	LINEAR: Infection with hMPV is associated	COUNT: 3
# PATH: infection-characterize-inflammation	LINEAR: infection in humans is characterized by extensive pulmonary inflammation	COUNT: 3
# PATH: infection-result-can	LINEAR: infection of humans can result	COUNT: 3
# PATH: ibv-infection	LINEAR: IBV infection	COUNT: 3
# PATH: infection-result-can	LINEAR: infection can result	COUNT: 3
# PATH: infection-associate-be	LINEAR: infection is associated	COUNT: 3
# PATH: infection-associate-be	LINEAR: infection is associated	COUNT: 3
# PATH: ibv-infection	LINEAR: IBV infection	COUNT: 3
# PATH: ibv-infection	LINEAR: IBV Infection	COUNT: 3
# PATH: infection-result-can	LINEAR: infection can results	COUNT: 3
# PATH: infection-characterize-inflammation	LINEAR: infections are characterized by inflammation	COUNT: 3
# PATH: infection-characterize-inflammation	LINEAR: infections are characterized by inflammation	COUNT: 3
# PATH: infection-cause-syndrome	LINEAR: infection , in domestic cats , causes a variable immunodeficiency syndrome	COUNT: 2
# PATH: virus-cause-disease	LINEAR: virus causes a lower respiratory tract disease	COUNT: 2
# PATH: infection-cause-myocarditis	LINEAR: infection causes myocarditis	COUNT: 2
# PATH: pedv-infection-cause-enteritis	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection-cause-illness	LINEAR: infection causes undifferentiated febrile illness	COUNT: 2
# PATH: infection-cause-spectrum-symptom-clinical	LINEAR: Infection with DENV can cause a spectrum of clinical	COUNT: 2
# PATH: pedv-infection-cause-enteritis	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection-cause-illness	LINEAR: infection causes illness	COUNT: 2
# PATH: disease-result-damage	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: disease-result-damage	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: bkv-establish-cause-number-disorder	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: bkv-establish-cause-number-disorder	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: infection-cause-syndrome	LINEAR: Infection of humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: infection-be	LINEAR: is a systemic infection	COUNT: 2
# PATH: infection-induce-disease	LINEAR: Infection of both susceptible and resistant mouse strains induces an early acute disease	COUNT: 2
# PATH: infection-cause-spectrum-symptom-clinical	LINEAR: infection causes a broad spectrum of clinical	COUNT: 2
# PATH: pedv-infection-characterize-be	LINEAR: PEDV is characterized	COUNT: 2
# PATH: infection-associate-onset-enteritis	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection-associate-onset-enteritis	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection-be	LINEAR: is an important systemic parvoviral infection	COUNT: 2
# PATH: infection-cause-spectrum-disease	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection-cause-spectrum-disease	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection-cause-can	LINEAR: infection by SFTSV can cause	COUNT: 2
# PATH: pneumonia-cause-however	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: pneumonia-cause-however	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: pedv-infection-characterize-be	LINEAR: PEDV infections are characterized	COUNT: 2
# PATH: infection-result-loss-focal	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection-result-loss-focal	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection-result-illness	LINEAR: Infection with CHIKV often results in acute illness	COUNT: 2
# PATH: infection-cause-myocarditis	LINEAR: infection of mice can cause myocarditis	COUNT: 2
# PATH: infection-cause-can	LINEAR: infection can cause	COUNT: 2
# PATH: infection-result-illness	LINEAR: Infection of ZV results in a self-limiting mild illness	COUNT: 2
# PATH: virus-cause-disease	LINEAR: virus causes disease	COUNT: 2
# PATH: infection-induce-disease	LINEAR: infection in dogs generally induces a multisystemic disease	COUNT: 2
# PATH: infection-cause-manifestation-neurologic	LINEAR: infection can also cause neurologic	COUNT: 2
# PATH: infection-cause-manifestation-neurologic	LINEAR: infection can also cause neurologic	COUNT: 2
# PATH: be-cause-characterize-be	LINEAR: is the major cause of lower respiratory tract infections in infants and is	COUNT: 2
# PATH: be-cause-characterize-be	LINEAR: is the major cause of lower respiratory tract infections in infants and is	COUNT: 2
# PATH: virus-induce-inflammation	LINEAR: virus , like MHV-3 infection in mice , can induce exaggerated inflammation	COUNT: 1
# PATH: MERS-CoV-induce-pneumonia	LINEAR: MERS-CoV induces acute pneumonia	COUNT: 1
# PATH: infection-cause-immunosuppression-progressive	LINEAR: infection causes progressive	COUNT: 1
# PATH: infection-cause-encephalitis-disorder-severe	LINEAR: infection can cause Japanese encephalitis ( JE ) with severe	COUNT: 1
# PATH: infection-produce-disease	LINEAR: infection with HHV-6 can produce a mononucleosis-like illness and , more rarely , severe disease	COUNT: 1
# PATH: infection-result-illness-febrile	LINEAR: Infection with MV typically results in an acute febrile	COUNT: 1
# PATH: brv-infection-component-pathogenesis-disease	LINEAR: BRV is a lytic infection and destruction of infected mucosal epithelial cells is an important component of disease	COUNT: 1
# PATH: disease-begin-progress-stage-infection-characterize-fever-shock	LINEAR: disease begins with flu-like symptoms and progresses rapidly to the final stages of viral hemorrhagic fever infection , which are characterized by fever , hemorrhage , and hypotensive shock	COUNT: 1
# PATH: pedv-infect-cause-atrophy-villi-result-diarrhea	LINEAR: PEDV infects the epithelium of the small intestine , an environment rich in proteases , and causes atrophy of the villi resulting in diarrhea	COUNT: 1
# PATH: infection-result-associate-gastroenteritis	LINEAR: infection results in respiratory tract complications with varying degree of severity and has been associated with gastroenteritis	COUNT: 1
# PATH: infect-human-develop-syndrome	LINEAR: infected with RVFV usually develop an acute febrile myalgic syndrome	COUNT: 1
# PATH: prrsv-increase-result-severity	LINEAR: PRRSV increases the susceptibility of the host to a wide range of viral and bacterial respiratory pathogens , resulting in increased severity	COUNT: 1
# PATH: MERS-CoV-cause-infection	LINEAR: MERS-CoV causes severe infection	COUNT: 1
# PATH: sars-cov-cause-pneumonia	LINEAR: SARS-CoV causes interstitial pneumonia	COUNT: 1
# PATH: virus-spread-characterize-be	LINEAR: is characterized by a rapid and extensive spread of the virus	COUNT: 1
# PATH: infection-represent-be	LINEAR: infection is mostly represented	COUNT: 1
# PATH: virus-ability-result-damage	LINEAR: results from overwhelming cytopathic damage due to the ability of Ebola virus	COUNT: 1
# PATH: mers-cov-infect-human-report-develop-illness	LINEAR: MERS-CoV have been reported to develop a severe acute respiratory illness	COUNT: 1
# PATH: JEV-invade-trigger-response-inflammatory	LINEAR: JEV invades the central nervous system , wherein virus replication triggers a massive inflammatory	COUNT: 1
# PATH: mcmv-cause-cause-disease	LINEAR: MCMV causes asymptomatic infection in adult immunocompetent mice , but experimental inoculation of neonates has caused lethal disease	COUNT: 1
# PATH: infection-lead-viremia-to	LINEAR: infection leads to	COUNT: 1
# PATH: fiv-pathogen-cause-degeneration-function-lead-disease	LINEAR: FIV is an important viral pathogen worldwide in the domestic cat ( Felis catus ) , causes a slow progressive degeneration of immune functions that eventually leads to a disease	COUNT: 1
# PATH: infection-cause-onset	LINEAR: infection causes a sudden onset	COUNT: 1
# PATH: infection-result-immunosuppression-severe	LINEAR: infection in young chickens results in severe	COUNT: 1
# PATH: prrsv-replicate-lead-infection-pneumonia	LINEAR: PRRSV replicates mainly in porcine alveolar macrophages ( PAMs ) and dendritic cells ( DCs ) and leads to persistent infection , interstitial pneumonia	COUNT: 1
# PATH: infection-cause-characterize-cascade-event-lead-inflammation-pulmonary	LINEAR: Infection of SARS-CoV causes severe acute respiratory syndrome ( SARS ) , which is an emerging infectious disease and characterized by a cascade of immunological events leading to pulmonary	COUNT: 1
# PATH: mhv-infection-cause-encephalitis	LINEAR: MHV infection causes encephalitis	COUNT: 1
# PATH: alphavirus-infection-induce-arthritis	LINEAR: alphavirus infections , such as those involving CHIKV , Ross River virus ( RRV ) , and Sindbis virus ( SINV ) , induce debilitating arthritis	COUNT: 1
# PATH: infection-characterize-atrophy-intestine-result-diarrhea	LINEAR: infection is characterized by severe villous atrophy in the small intestine that results in watery diarrhea	COUNT: 1
# PATH: virus-able-cross-stimulate-inflammation	LINEAR: virus is able to cross the blood-brain barrier and stimulate inflammation	COUNT: 1
# PATH: mnv-infection-result-replication-associate-diarrhea	LINEAR: MNV infection in immunocompromised mice lacking innate immunity factors such as STAT1 or interferon receptors can result in persistent or acute virus replication associated with severe diarrhea	COUNT: 1
# PATH: infection-result-severe-disease	LINEAR: infection results in severe and even fatal lung disease	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY 1:
# 	infected arg1:patients $usually $develop <>arg2:[entity]respiratory illness.
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection-characterize-be	LINEAR: Infection with PEDV is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: Infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is clinically characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infection is characterized	COUNT: 9
# PATH: infection-characterize-be	LINEAR: infections are characterized	COUNT: 9
# PATH: infection-sign-clinical	LINEAR: Clinical signs of CPV-2 infection	COUNT: 5
# PATH: infection-sign-clinical	LINEAR: Clinical signs in human infections	COUNT: 5
# PATH: infection-sign-clinical	LINEAR: clinical signs of respiratory infection	COUNT: 5
# PATH: infection-sign-clinical	LINEAR: clinical signs of BDV infection	COUNT: 5
# PATH: infection-sign-clinical	LINEAR: clinical signs of FPV infection	COUNT: 5
# PATH: patient-develop-pneumonia	LINEAR: patients who have pneumonic plague typically develop fulminant pneumonia	COUNT: 4
# PATH: disease-characterize-be	LINEAR: disease is characterized	COUNT: 4
# PATH: patient-develop-pneumonia	LINEAR: patients rapidly develop pneumonia	COUNT: 4
# PATH: disease-characterize-be	LINEAR: disease caused by these human coronaviruses , SARS is characterized	COUNT: 4
# PATH: patient-develop-pneumonia	LINEAR: Patients with severe cases usually develop pneumonia	COUNT: 4
# PATH: patient-develop-pneumonia	LINEAR: patients with BCC develop a life-threatening , sometimes necrotizing , pneumonia	COUNT: 4
# PATH: disease-characterize-be	LINEAR: disease in neonatal kids is characterized	COUNT: 4
# PATH: disease-characterize-be	LINEAR: disease is characterized	COUNT: 4
# PATH: patient-present-symptom	LINEAR: patients infected with SARS-CoV often present with symptoms	COUNT: 3
# PATH: rabbit-develop-sepsis	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit-develop-sepsis	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit-develop-sepsis	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: patient-develop-fever	LINEAR: patients develop rapid onset fever	COUNT: 3
# PATH: patient-present-symptom	LINEAR: Patients with severe MERS often present with pneumonic symptoms	COUNT: 3
# PATH: human-disease	LINEAR: disease in humans	COUNT: 3
# PATH: human-disease	LINEAR: disease in humans	COUNT: 3
# PATH: patient-develop-fever	LINEAR: patients develop fever	COUNT: 3
# PATH: human-disease	LINEAR: disease in humans	COUNT: 3
# PATH: patient-present-symptom	LINEAR: patients generally present with mild upper respiratory infection symptoms	COUNT: 3
# PATH: patient-develop-fever	LINEAR: patients usually develop fever	COUNT: 3
# PATH: human-infection	LINEAR: Infection in humans	COUNT: 2
# PATH: infection-symptom-clinical	LINEAR: clinical symptoms of MERS-CoV infection	COUNT: 2
# PATH: infection-cause-symptom	LINEAR: infection initially causes non-specific symptoms	COUNT: 2
# PATH: be-associate-disease	LINEAR: disease is associated	COUNT: 2
# PATH: animal-die	LINEAR: animals usually die	COUNT: 2
# PATH: case-infection	LINEAR: cases of COVID-19 infection	COUNT: 2
# PATH: disease-lead-fever	LINEAR: disease , immature schistosomula pass through the lung and can lead to fever	COUNT: 2
# PATH: case-infection	LINEAR: cases of human infection	COUNT: 2
# PATH: animal-develop-range-sign-clinical	LINEAR: animals may develop a wide range of clinical	COUNT: 2
# PATH: clinical-manifestation-evolve-picture-septic	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: clinical-manifestation-evolve-picture-septic	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: infant-have-symptom	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: infant-have-symptom	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: animal-die	LINEAR: animals usually die	COUNT: 2
# PATH: host-develop-diarrhea	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: host-develop-diarrhea	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: sepsis-sign-clinical	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: sepsis-sign-clinical	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: human-infection-cause-syndrome	LINEAR: humans typically causes an influenza-like syndrome	COUNT: 2
# PATH: human-infection-cause-syndrome	LINEAR: humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: patient-infection	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: infection-symptom	LINEAR: symptoms of rapidly-lethal infections	COUNT: 2
# PATH: human-infection	LINEAR: Infection in humans	COUNT: 2
# PATH: case-occur-dyspnea	LINEAR: cases , dyspnea and hypoxemia usually occur	COUNT: 2
# PATH: patient-infection	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: be-severe-infection	LINEAR: infection is usually more severe	COUNT: 2
# PATH: mouse-suckle-growth-characterize-infection	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: mouse-suckle-growth-characterize-infection	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: patient-clinic-progress-disease	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient-clinic-progress-disease	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: infection-cause-symptom	LINEAR: infection usually causes mild symptoms	COUNT: 2
# PATH: disease-lead-fever	LINEAR: disease , immature schistosomula pass through the lung , and can lead to fever	COUNT: 2
# PATH: be-severe-infection	LINEAR: infection is usually more severe	COUNT: 2
# PATH: be-disease	LINEAR: is usually a self-limited disease	COUNT: 2
# PATH: be-disease	LINEAR: is usually a self-limited disease	COUNT: 2
# PATH: mouse-infection	LINEAR: infection in immunocompetent adult mice	COUNT: 2
# PATH: animal-develop-range-sign-clinical	LINEAR: animals may develop a wide range of clinical	COUNT: 2
# PATH: patient-cause-pneumonia	LINEAR: Patients infected with COVID-19 typically present with fever , cough , dyspnea , and myalgia , and the infection may cause severe pneumonia	COUNT: 2
# PATH: patient-cause-pneumonia	LINEAR: Patients infected with COVID-19 typically present with fever , cough , dyspnea , and myalgia , and the infection may cause severe pneumonia	COUNT: 2
# PATH: infection-result-diarrhea	LINEAR: infections usually result in diarrhea	COUNT: 2
# PATH: be-associate-disease	LINEAR: is typically associated with acute cholestatic hepatic disease	COUNT: 2
# PATH: disease-manifest-infection	LINEAR: disease caused by the virus manifests in most cases as a lower respiratory tract infection	COUNT: 2
# PATH: disease-manifest-infection	LINEAR: disease caused by the virus manifests in most cases as a lower respiratory tract infection	COUNT: 2
# PATH: infection-symptom-clinical	LINEAR: clinical symptoms of norovirus infection	COUNT: 2
# PATH: infection-symptom	LINEAR: symptoms of calicivirus infection	COUNT: 2
# PATH: case-occur-dyspnea	LINEAR: cases , dyspnea occurs	COUNT: 2
# PATH: human-symptom	LINEAR: Symptoms in humans	COUNT: 2
# PATH: infection-result-diarrhea	LINEAR: infection results in profuse greenish , mucoid diarrhea	COUNT: 2
# PATH: human-symptom	LINEAR: Symptoms in humans	COUNT: 2
# PATH: mouse-infection	LINEAR: infection in immunocompetent mice	COUNT: 2
# PATH: cat-young-have-profuse-diarrhea	LINEAR: cats with cryptosporidiosis will have profuse , watery diarrhea	COUNT: 2
# PATH: cat-young-have-profuse-diarrhea	LINEAR: cats with cryptosporidiosis will have profuse , watery diarrhea	COUNT: 2
# PATH: people-manifest-feature-pneumonia	LINEAR: people commonly manifest features of pneumonia	COUNT: 1
# PATH: patient-exhibit-encephalopathy-encephalitis	LINEAR: Patients suffering from severe DENV infection often exhibit encephalopathy and encephalitis	COUNT: 1
# PATH: cat-show-sign-clinical	LINEAR: Cats with FIP show nonspecific clinical	COUNT: 1
# PATH: cat-have	LINEAR: Cats with signs from FIV often have	COUNT: 1
# PATH: infection-enteric	LINEAR: Enteric FCoV infection	COUNT: 1
# PATH: patient-develop-illness-respiratory	LINEAR: patients with MERS develop severe acute respiratory	COUNT: 1
# PATH: infection-stage-include-bleeding	LINEAR: infection usually include diffuse bleeding	COUNT: 1
# PATH: infection-asymptomatic-occur-sign-clinical	LINEAR: infection is usually asymptomatic , although nonspecific clinical	COUNT: 1
# PATH: patient-present-headache-severe	LINEAR: patients can present with severe	COUNT: 1
# PATH: patient-deteriorate-present-symptom	LINEAR: Patients infected with EVD rapidly deteriorate and commonly present with gastrointestinal symptoms	COUNT: 1
# PATH: rabbit-develop-course-disease	LINEAR: rabbits usually develop a chronic disease	COUNT: 1
# PATH: cat-infect-manifest-disease	LINEAR: Cats are primarily infected subclinically , but gastrointestinal disease	COUNT: 1
# PATH: marmoset-infection	LINEAR: marmosets with measles infection	COUNT: 1
# PATH: human-cause-onset-sudden	LINEAR: humans , VEEV infection causes a sudden	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY 2:
# 	a arg1:subset of patients $progress to arg2:hemorrhagic fever
#
# MOST FREQUENT PATTERNS:
#
# PATH: case-severe	LINEAR: Severe cases	COUNT: 12
# PATH: case-severe	LINEAR: Severe cases	COUNT: 12
# PATH: case-severe	LINEAR: Severe pediatric cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: case-severe	LINEAR: Severe cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: case-severe	LINEAR: Severe cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: case-severe	LINEAR: Severe cases	COUNT: 12
# PATH: case-severe	LINEAR: severe cases	COUNT: 12
# PATH: patient-severe	LINEAR: severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: patient-severe	LINEAR: Severe patients	COUNT: 7
# PATH: case-cause-pneumonia	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case-cause-pneumonia	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case-cause-pneumonia	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case-cause-pneumonia	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: disease-severe	LINEAR: Severe disease	COUNT: 5
# PATH: disease-severe	LINEAR: severe disease	COUNT: 5
# PATH: disease-severe	LINEAR: severe disease	COUNT: 5
# PATH: case-cause-pneumonia	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: disease-severe	LINEAR: severe disease	COUNT: 5
# PATH: disease-severe	LINEAR: severe disease	COUNT: 5
# PATH: patient-develop-failure-severe	LINEAR: patients develop severe	COUNT: 4
# PATH: patient-develop-failure-severe	LINEAR: patients can develop severe	COUNT: 4
# PATH: patient-develop-failure-severe	LINEAR: patients rapidly develop severe	COUNT: 4
# PATH: patient-develop-failure-severe	LINEAR: patients rapidly develop severe	COUNT: 4
# PATH: disease-progress-failure-respiratory	LINEAR: disease may progress into respiratory	COUNT: 3
# PATH: disease-progress-failure-respiratory	LINEAR: disease quickly progresses to respiratory	COUNT: 3
# PATH: disease-progress-failure-respiratory	LINEAR: disease quickly progresses to respiratory	COUNT: 3
# PATH: pneumonia-viral	LINEAR: viral pneumonia	COUNT: 3
# PATH: pneumonia-viral	LINEAR: viral pneumonia	COUNT: 3
# PATH: pneumonia-viral	LINEAR: Viral pneumonia	COUNT: 3
# PATH: disease-progress-case-severe	LINEAR: severe cases , the disease may progress	COUNT: 2
# PATH: patient-clinic-progress-disease	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient-clinic-progress-disease	LINEAR: clinic , COVID-19 patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: -PRON--progress-case-severe	LINEAR: severe cases , it can progress	COUNT: 2
# PATH: condition-develop-case-severe	LINEAR: severe cases , the conditions may develop	COUNT: 2
# PATH: condition-develop-case-severe	LINEAR: severe cases , the conditions may develop	COUNT: 2
# PATH: illness-severe	LINEAR: severe illness	COUNT: 2
# PATH: pneumonia-develop-progress-failure-respiratory	LINEAR: Pneumonia develops with primary infection , occurs rarely in children , and progresses to respiratory	COUNT: 2
# PATH: patient-develop-disease-severe	LINEAR: patients may develop severe	COUNT: 2
# PATH: disease-progress-pneumonia-viral	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease-progress-pneumonia-viral	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease-progress-result-failure-cardiac	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: disease-progress-result-failure-cardiac	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: Disease-progress-syndrome-and	LINEAR: Disease can progress to acute respiratory distress syndrome and	COUNT: 2
# PATH: Disease-progress-syndrome-and	LINEAR: Disease can progress to acute respiratory distress syndrome and	COUNT: 2
# PATH: patient-infection-severe	LINEAR: patients with severe	COUNT: 2
# PATH: pneumonia-develop-progress-failure-respiratory	LINEAR: Pneumonia develops rapidly and eventually progresses after 2 to 4 days into respiratory	COUNT: 2
# PATH: patient-infection-severe	LINEAR: Patients with severe	COUNT: 2
# PATH: case-develop-edema-pulmonary	LINEAR: cases often develop refractory pulmonary	COUNT: 2
# PATH: case-develop-edema-pulmonary	LINEAR: cases often develop refractory pulmonary	COUNT: 2
# PATH: illness-severe	LINEAR: Severe illnesses	COUNT: 2
# PATH: patient-progress-may	LINEAR: patients may progress	COUNT: 2
# PATH: can-result-complication-involvement-pulmonary	LINEAR: pulmonary involvement can result	COUNT: 2
# PATH: can-result-complication-involvement-pulmonary	LINEAR: pulmonary involvement can result	COUNT: 2
# PATH: patient-develop-failure-response-severe	LINEAR: Patients whose condition deteriorates to critical status primarily decompensate from a respiratory standpoint , but may also develop multi-organ failure ( respiratory failure , cardiac failure , renal failure , hypercoagulable state , thrombotic microangiopathy ) , as well as severe	COUNT: 2
# PATH: patient-develop-failure-response-severe	LINEAR: Patients whose condition deteriorates to critical status primarily decompensate from a respiratory standpoint , but may also develop multi-organ failure ( respiratory failure , cardiac failure , renal failure , hypercoagulable state , thrombotic microangiopathy ) , as well as severe	COUNT: 2
# PATH: pneumonia-severe	LINEAR: Severe pneumonia	COUNT: 2
# PATH: patient-progress-may	LINEAR: patients may progress	COUNT: 2
# PATH: disease-form-experience-suffer-complication-severe	LINEAR: experience a mild form of disease , but those with advanced age or underlying comorbidities may suffer severe	COUNT: 2
# PATH: disease-form-experience-suffer-complication-severe	LINEAR: experience a mild form of disease , but those with advanced age or underlying comorbidities may suffer severe	COUNT: 2
# PATH: -PRON--progress-case-severe	LINEAR: severe cases , it can progress	COUNT: 2
# PATH: patient-develop-disease-severe	LINEAR: patients of every age can develop severe	COUNT: 2
# PATH: patient-have-develop-lead-death	LINEAR: patients have mild symptoms such as fever , headache , cough , myalgia and anosmia , some develop acute respiratory distress syndrome , leading to death	COUNT: 2
# PATH: patient-have-develop-lead-death	LINEAR: patients have mild symptoms such as fever , headache , cough , myalgia and anosmia , some develop acute respiratory distress syndrome , leading to death	COUNT: 2
# PATH: disease-progress-case-severe	LINEAR: severe cases , the disease may progress	COUNT: 2
# PATH: patient-progress-develop	LINEAR: patients progress rapidly to develop	COUNT: 2
# PATH: patient-progress-develop	LINEAR: patients progress rapidly to develop	COUNT: 2
# PATH: disease-progressive	LINEAR: progressive local disease	COUNT: 2
# PATH: disease-progressive	LINEAR: progressive local disease	COUNT: 2
# PATH: -PRON--result-syndrome-failure-respiratory	LINEAR: it may result in adult respiratory distress syndrome and respiratory	COUNT: 2
# PATH: -PRON--result-syndrome-failure-respiratory	LINEAR: it may result in adult respiratory distress syndrome and respiratory	COUNT: 2
# PATH: disease-result-lymphadenopathy-generalize	LINEAR: results in disease that is less severe and commonly presents as nondescript , consisting of fever , myalgia , and generalized	COUNT: 2
# PATH: disease-result-lymphadenopathy-generalize	LINEAR: results in disease that is less severe and commonly presents as nondescript , consisting of fever , myalgia , and generalized	COUNT: 2
# PATH: patient-develop	LINEAR: Patients may develop	COUNT: 2
# PATH: disease-form-this	LINEAR: this form of the disease	COUNT: 2
# PATH: disease-form-this	LINEAR: this form of the disease	COUNT: 2
# PATH: disease-onset-begin-case-symptomatic	LINEAR: symptomatic cases , the onset of disease begins	COUNT: 2
# PATH: disease-onset-begin-case-symptomatic	LINEAR: symptomatic cases , the onset of disease begins	COUNT: 2
# PATH: disease-progress-plague-pneumonic-severe	LINEAR: disease may progress to severe	COUNT: 2
# PATH: disease-progress-plague-pneumonic-severe	LINEAR: disease may progress to severe	COUNT: 2
# PATH: patient-develop-pneumonia-severe	LINEAR: patients may develop severe	COUNT: 2
# PATH: patient-develop-pneumonia-severe	LINEAR: patients may develop severe	COUNT: 2
# PATH: may-progress-to-state-toxic	LINEAR: may progress to an increasingly toxic	COUNT: 2
# PATH: disease-progress-can	LINEAR: disease in this age group can progress	COUNT: 2
# PATH: patient-develop	LINEAR: patients develop	COUNT: 2
# PATH: disease-progress-can	LINEAR: disease can progress	COUNT: 2
# PATH: pneumonia-severe	LINEAR: Severe pneumonia	COUNT: 2
# PATH: may-progress-to-state-toxic	LINEAR: may progress to an increasingly toxic	COUNT: 2
# PATH: be-asymptomatic-cause-symptom-serious	LINEAR: is usually asymptomatic , cryptococcosis can cause serious	COUNT: 2
# PATH: be-asymptomatic-cause-symptom-serious	LINEAR: is usually asymptomatic , cryptococcosis can cause serious	COUNT: 2
# PATH: infection-develop-presentation-include-pharyngitis-disease	LINEAR: Infection usually develops within the first 3 months of transplantation , with a presentation that might include pharyngitis , tracheitis , bronchitis , pneumonitis , enteritis , hemorrhagic cystitis , or disseminated disease	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY 3:
# 	people with arg1:[e]asthma are $susceptible to arg2:[e]asthma
#
# MOST FREQUENT PATTERNS:
#
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are highly susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are highly susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: Cancer patients , particularly those under anticancer treatment , are potentially more susceptible for a severe infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to the infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: Cancer patients and immunocompromised hosts are particularly susceptible to lung infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are generally more susceptible to infections	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: Cancer patients are more susceptible to infections	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer patients are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: Cancer patients are potentially more susceptible to Coronavirus infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: Cancer patients are more susceptible to infections	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer may be as susceptible to active Mycobacterium tuberculous infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer are more susceptible to infection	COUNT: 20
# PATH: cancer-patient-susceptible-infection	LINEAR: cancer patients are more susceptible to infections	COUNT: 20
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd-subject-exacerbation-trigger-know-infection	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: patient-susceptible-infection	LINEAR: patients are more susceptible to infection	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients are more susceptible to infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: Patients with iatrogenic or disease related immune suppression are highly susceptible to infection	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: Patients who are immunocompromised such as due to steroids or organ and hematopoietic stem cell transplantation are highly susceptible to atypical viral infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients with compromised immune systems are more susceptible to viral infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients are more susceptible to infection	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients are also susceptible to nosocomial viral infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: Patients with hematologic malignancies , especially in the neutropenic state after aggressive chemotherapy or HSCT and HSCT recipients with GVHD , are particularly susceptible to invasive fungal infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients are more susceptible to bacterial , fungal , viral , and parasitic infections	COUNT: 10
# PATH: patient-susceptible-infection	LINEAR: patients with DAH are especially susceptible to pulmonary infections	COUNT: 10
# PATH: patient-risk-infection	LINEAR: Patients with liver cirrhosis or liver cancer are at high risk of SARS-CoV-2 infection	COUNT: 5
# PATH: infection-rsv	LINEAR: RSV infection	COUNT: 5
# PATH: patient-risk-infection	LINEAR: Patients with defective cell-mediated immunity are at risk of infections	COUNT: 5
# PATH: infection-rsv	LINEAR: RSV infection	COUNT: 5
# PATH: patient-risk-infection	LINEAR: Patients with primary adrenal insufficiency including Addison 's disease and congenital adrenal hyperplasia are at an increased risk of infections	COUNT: 5
# PATH: patient-risk-infection	LINEAR: Patients with prolonged neutropenia who have received intensive cytotoxic chemotherapy are at risk for invasive fungal infection	COUNT: 5
# PATH: patient-risk-infection	LINEAR: patients , especially those with neutropenia , are at increased risk of infection	COUNT: 5
# PATH: infection-rsv	LINEAR: RSV infection	COUNT: 5
# PATH: infection-rsv	LINEAR: RSV infection	COUNT: 5
# PATH: infection-rsv	LINEAR: RSV infection	COUNT: 5
# PATH: patient-risk-pneumonia	LINEAR: patients , including those with HIV/AIDS and patients taking immunosuppressants post-transplant , are at an increased risk for viral and fungal pneumonia	COUNT: 4
# PATH: patient-prone-infection	LINEAR: patients are also more prone to RSV infections	COUNT: 4
# PATH: patient-risk-pneumonia	LINEAR: Patients with immunodeficiency syndromes are also at risk of pneumonia	COUNT: 4
# PATH: patient-prone-infection	LINEAR: Patients with ESLD are prone to infections	COUNT: 4
# PATH: patient-risk-pneumonia	LINEAR: patients with associated CD4 + cell depletion not receiving appropriate prophylaxis are at high risk for Pneumocystis jiroveci pneumonia	COUNT: 4
# PATH: patient-risk-pneumonia	LINEAR: patients with a single LT may be at greater risk of pneumonia	COUNT: 4
# PATH: patient-prone-infection	LINEAR: patients , including not only those with HIV infection but also those who undergo small bowel transplantation for short bowel syndrome , are prone to CMV infection	COUNT: 4
# PATH: patient-prone-infection	LINEAR: patients are also prone to other community acquired and nosocomial infections	COUNT: 4
# PATH: ds-patient-susceptible-lower-infection	LINEAR: DS are highly susceptible to lower and higher respiratory tract infection	COUNT: 3
# PATH: ds-patient-susceptible-lower-infection	LINEAR: DS are highly susceptible to lower and higher respiratory tract infection	COUNT: 3
# PATH: ds-patient-susceptible-lower-infection	LINEAR: DS are highly susceptible to lower and higher respiratory tract infection	COUNT: 3
# PATH: cancer-patient-status-increase-risk-infection	LINEAR: cancer patients ( whether caused by the disease itself or the treatment ) increases their risk of infection	COUNT: 3
# PATH: cancer-patient-status-increase-risk-infection	LINEAR: cancer patients ( whether caused by the disease itself or the treatment ) increases their risk of infection	COUNT: 3
# PATH: cancer-patient-status-increase-risk-infection	LINEAR: cancer patients ( whether caused by the disease itself or the treatment ) increases their risk of infection	COUNT: 3
# PATH: infection-risk-patient	LINEAR: patients undergoing allogeneic stem cell transplantation are at a much higher risk of infection	COUNT: 3
# PATH: pneumonia-bacterial	LINEAR: bacterial pneumonia	COUNT: 3
# PATH: disease-patient-develop-form-aspergillosis	LINEAR: disease or milder forms of immunosuppression develop semi-invasive forms of aspergillosis	COUNT: 3
# PATH: disease-patient-develop-form-aspergillosis	LINEAR: disease or milder forms of immunosuppression develop semi-invasive forms of aspergillosis	COUNT: 3
# PATH: cancer-patient-be-risk-infection	LINEAR: cancer are at risk of serious infection	COUNT: 3
# PATH: infection-risk-patient	LINEAR: Patients with rheumatic and inflammatory bowel diseases ( IBDs ) may be at higher risk of infection	COUNT: 3
# PATH: pneumonia-bacterial	LINEAR: bacterial pneumonia	COUNT: 3
# PATH: disease-dentition-patient-likely-develop-pneumonia	LINEAR: disease are more likely to develop aspiration pneumonia	COUNT: 3
# PATH: disease-dentition-patient-likely-develop-pneumonia	LINEAR: disease are more likely to develop aspiration pneumonia	COUNT: 3
# PATH: disease-dentition-patient-likely-develop-pneumonia	LINEAR: disease are more likely to develop aspiration pneumonia	COUNT: 3
# PATH: disease-patient-develop-form-aspergillosis	LINEAR: disease or milder forms of immunosuppression can develop semi-invasive forms of aspergillosis	COUNT: 3
# PATH: infection-risk-patient	LINEAR: patients without prior exposure to varicella-zoster virus are at increased risk of severe infection	COUNT: 3
# PATH: cancer-patient-be-risk-infection	LINEAR: cancer patients who require surgery may be at risk of coronavirus infection	COUNT: 3
# PATH: cancer-patient-be-risk-infection	LINEAR: cancer are at the risk of SARS-CoV-2 infection	COUNT: 3
# PATH: pneumonia-bacterial	LINEAR: bacterial pneumonia	COUNT: 3
# PATH: illness-develop-infection	LINEAR: develop severe illness after infection	COUNT: 2
# PATH: illness-develop-infection	LINEAR: develop severe illness after infection	COUNT: 2
# PATH: patient-susceptible-sepsis	LINEAR: Patients with immunodeficiency due to human immunodeficiency virus ( HIV ) infection are highly susceptible to viral sepsis	COUNT: 2
# PATH: patient-vulnerable-infection	LINEAR: patients are more vulnerable to infection	COUNT: 2
# PATH: patient-risk-develop-hepatitis	LINEAR: patients are at higher risk for developing fulminant acute hepatitis	COUNT: 2
# PATH: patient-vulnerable-infection	LINEAR: patients are often vulnerable to opportunistic infections	COUNT: 2
# PATH: cancer-patient-risk-infection	LINEAR: Cancer patients are at an increased risk for these infections	COUNT: 2
# PATH: ibd-patient-risk-infection	LINEAR: IBD are at increased risk of infection	COUNT: 2
# PATH: ibd-patient-risk-infection	LINEAR: IBD are at increased risk of infection	COUNT: 2
# PATH: patient-risk-develop-hepatitis	LINEAR: patients are at risk for developing acute fulminant hepatitis	COUNT: 2
# PATH: patient-susceptible-bacterial-infection	LINEAR: patients are particularly susceptible to bacterial and candidal infections	COUNT: 2
# PATH: fibrosis-patient-susceptible-infection	LINEAR: fibrosis are particularly susceptible to chronic infection	COUNT: 2
# PATH: sinusitis-cause-bacteria	LINEAR: sinusitis caused by encapsulated bacteria	COUNT: 2
# PATH: infection-severity-increase-depletion-related-infection	LINEAR: infections are also related to lymphoid depletion and immunosuppression , which likely increase the severity of secondary infection	COUNT: 2
# PATH: patient-be-risk-infection	LINEAR: patients who are more heavily immunosuppressed and who are suffering from other immunologic and infectious complications of transplant are at higher risk for infection	COUNT: 2
# PATH: infection-cause-infection	LINEAR: infections frequently cause persistent infections	COUNT: 2
# PATH: patient-susceptible-sepsis	LINEAR: Patients with iron overload ( hemochromatosis ) are more susceptible to yersinial sepsis	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY 4:
# 	arg1:[e]paracetamol is $not useful for treating arg2:[e]asthma.
#
# MOST FREQUENT PATTERNS:
#
# PATH: corticosteroid-increase-influenza-infection	LINEAR: corticosteroids may increase the risk of mortality and morbidity ( e.g. secondary infections ) in severe influenza and other viral infections	COUNT: 2
# PATH: corticosteroid-increase-influenza-infection	LINEAR: corticosteroids may increase the risk of mortality and morbidity ( e.g. secondary infections ) in severe influenza and other viral infections	COUNT: 2
# PATH: ribavirin-consider-management-case-severe	LINEAR: ribavirin and IgIV can be considered for the management of severe	COUNT: 2
# PATH: ribavirin-effective-virus-sars	LINEAR: ribavirin is only marginally effective against the SARS	COUNT: 2
# PATH: antiviral-option-limited-be-prove-effective-occur-disease	LINEAR: antiviral treatment options are limited because no parenteral drug is available and no drug has been proved to be effective once life-threatening disease	COUNT: 2
# PATH: antiviral-option-limited-be-prove-effective-occur-disease	LINEAR: antiviral treatment options are limited because no parenteral drug is available and no drug has been proved to be effective once life-threatening disease	COUNT: 2
# PATH: ribavirin-cidofovir-agent	LINEAR: agents ( such as cidofovir , foscarnet , and ribavirin	COUNT: 2
# PATH: ribavirin-cidofovir-agent	LINEAR: agents ( such as cidofovir , foscarnet , and ribavirin	COUNT: 2
# PATH: ribavirin-effective-virus-sars	LINEAR: ribavirin is only marginally effective against the SARS	COUNT: 2
# PATH: of-therapy-efficacy-effect-compromise-treatment-infection	LINEAR: infection after liver transplantation is often compromised by enhanced adverse effects and limited efficacy of	COUNT: 2
# PATH: ribavirin-consider-management-case-severe	LINEAR: ribavirin with or without immunoglobulin can be considered for the management of severe	COUNT: 2
# PATH: corticosteroid-therapy-sufficient-think-disease	LINEAR: disease , it is increasingly thought that corticosteroid	COUNT: 2
# PATH: corticosteroid-therapy-sufficient-think-disease	LINEAR: disease , it is increasingly thought that corticosteroid	COUNT: 2
# PATH: of-therapy-efficacy-effect-compromise-treatment-infection	LINEAR: infection after LT is compromised by enhanced adverse effects and limited efficacy of	COUNT: 2
# PATH: antiviral-available-practice-treatment-pneumonia	LINEAR: antivirals available in clinical practice for the treatment of pneumonia	COUNT: 2
# PATH: corticosteroid-therapy-effective-%-form-ttp	LINEAR: corticosteroid therapy is effective in 56 % of purely hematological forms of TTP	COUNT: 2
# PATH: corticosteroid-therapy-effective-%-form-ttp	LINEAR: corticosteroid therapy is effective in 56 % of purely hematological forms of TTP	COUNT: 2
# PATH: antiviral-have-induce-rejection-organ	LINEAR: Antivirals themselves have significant side effects , and their use may induce organ	COUNT: 2
# PATH: antiviral-have-induce-rejection-organ	LINEAR: Antivirals themselves have significant side effects , and their use may induce organ	COUNT: 2
# PATH: antiviral-available-practice-treatment-pneumonia	LINEAR: antivirals available in clinical practice for the treatment of pneumonia	COUNT: 2
# PATH: -PRON--be-agent-patient-active-tuberculosis	LINEAR: it is not an appropriate agent in patients with active or latent tuberculosis	COUNT: 1
# ...
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-Cov-2 enters the cell	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters the pulmonary cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters target cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters human cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters human target cells	COUNT: 16
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 enters human target cells	COUNT: 16
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 invades target cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 invades cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 invades host cells	COUNT: 8
# PATH: sars-cov-2-invade-cell	LINEAR: SARS-CoV-2 invades host cells	COUNT: 8
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV preferentially infects respiratory epithelial cells	COUNT: 6
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV infects cells	COUNT: 6
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV infects unciliated bronchial epithelial cells	COUNT: 6
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV and SARS-CoV infect human primary T cells	COUNT: 6
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV , but not SARS-CoV , can infect both CD4 and CD8 T cells	COUNT: 6
# PATH: mers-cov-infect-cell	LINEAR: MERS-CoV infects unciliated bronchial epithelial cells	COUNT: 6
# PATH: sars-cov-2-use-enter-cell	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2 ) as the receptor to enter host cells	COUNT: 5
# PATH: sars-cov-2-use-enter-cell	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2 ) as a viral receptor to enter the target cell	COUNT: 5
# PATH: sars-cov-2-use-enter-cell	LINEAR: SARS-CoV-2 may use host receptor angiotensin-converting enzyme 2 ( ACE2 ) to enter the cells	COUNT: 5
# PATH: sars-cov-2-use-enter-cell	LINEAR: SARS-CoV-2 uses Angiotensin converting enzyme)-2 ( ACE2 ) as a viral receptor to enter host cells	COUNT: 5
# PATH: sars-cov-2-use-enter-cell	LINEAR: SARS-CoV-2 and SARS-CoV use the angiotensin converting enzyme 2 ( ACE2 ) to enter 65 target cells	COUNT: 5
# PATH: MERS-CoV-enter-cell	LINEAR: MERS-CoV enters cells	COUNT: 4
# PATH: sars-cov-2-entry-cell	LINEAR: entry of SARS-CoV-2 into host cells	COUNT: 4
# PATH: MERS-CoV-enter-cell	LINEAR: MERS-CoV enters host cells	COUNT: 4
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 4
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 4
# PATH: sars-cov-2-entry-cell	LINEAR: Entry of SARS-CoV-2 into a host cell	COUNT: 4
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 4
# PATH: sars-cov-2-entry-cell	LINEAR: entry into target cells by SARS-CoV-2	COUNT: 4
# PATH: sars-cov-2-entry-cell	LINEAR: SARS-CoV-2 entry into the host cells	COUNT: 4
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 4
# PATH: MERS-CoV-enter-cell	LINEAR: MERS-CoV enters the host cell	COUNT: 4
# PATH: MERS-CoV-enter-cell	LINEAR: MERS-CoV enters the host cell	COUNT: 4
# PATH: sars-cov-2-infect-tract	LINEAR: SARS-CoV-2 infects the GI tract	COUNT: 3
# PATH: sars-cov-2-infect-tract	LINEAR: SARS-CoV-2 infects the GI tract	COUNT: 3
# PATH: sars-cov-infect-cell	LINEAR: SARS-CoV infects human host cells	COUNT: 3
# PATH: sars-cov-infect-cell	LINEAR: SARS-CoV infects epithelial cells	COUNT: 3
# PATH: sars-cov-2-infect-human	LINEAR: SARS-CoV-2 infects humans	COUNT: 3
# PATH: sars-cov-2-infection	LINEAR: infection , SARS-CoV and SARS-CoV-2	COUNT: 3
# PATH: sars-cov-infect-cell	LINEAR: SARS-CoV primarily infects epithelial cells	COUNT: 3
# PATH: sars-cov-2-infection	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: sars-cov-2-enter-infect-cell	LINEAR: SARS-CoV-2 enter and infect target host cells	COUNT: 3
# PATH: sars-cov2-protein-report-form-channel-associate-pathogenesis	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: sars-cov2-protein-report-form-channel-associate-pathogenesis	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: sars-cov2-protein-report-form-channel-associate-pathogenesis	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: 2-coronavirus-invade-cell	LINEAR: coronavirus 2 , which invades a cell	COUNT: 3
# PATH: sars-cov-2-enter-infect-cell	LINEAR: SARS-CoV-2 enters into and infects host cells	COUNT: 3
# PATH: sars-cov-2-enter-infect-cell	LINEAR: SARS-CoV-2 enters into and infects host cells	COUNT: 3
# PATH: sars-cov-2-infection	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: sars-cov-2-infect-human	LINEAR: SARS-CoV-2 infects humans	COUNT: 3
# PATH: sars-cov-2-infect-human	LINEAR: SARS-CoV-2 infects humans	COUNT: 3
# PATH: 2-coronavirus-invade-cell	LINEAR: coronavirus 2 , which invades cells	COUNT: 3
# PATH: 2-coronavirus-invade-cell	LINEAR: coronavirus 2 , which invades cells	COUNT: 3
# PATH: sars-cov-2-infect-tract	LINEAR: Sars-CoV-2 infects the respiratory tract	COUNT: 3
# PATH: sars-cov-2-bind-receptor-cell	LINEAR: SARS-CoV-2 binds to the ACE2 receptor on ciliated bronchial epithelial cells	COUNT: 2
# PATH: sars-cov-2-infect-airway	LINEAR: SARS-Cov-2 first predominantly infects lower airways	COUNT: 2
# PATH: sars-cov-2-recognize-receptor-allow-infect-cell	LINEAR: SARS-CoV-2 recognizes the human Angiotensin Converting Enzyme 2 ( hACE2 ) as a cellular receptor that allows it to infect different host cells	COUNT: 2
# PATH: sars-cov-2-recognize-receptor-allow-infect-cell	LINEAR: SARS-CoV-2 recognizes the human Angiotensin Converting Enzyme 2 ( hACE2 ) as a cellular receptor that allows it to infect different host cells	COUNT: 2
# PATH: sars-cov-2-bind-receptor-cell	LINEAR: SARS-CoV-2 binds to the ACE2 receptor on ciliated bronchial epithelial cells	COUNT: 2
# PATH: 2-enzyme-use-infect-cell	LINEAR: use angiotensin-converting enzyme 2 as the cellular receptor to infect host cells	COUNT: 2
# PATH: sars-cov-2-enter-cell	LINEAR: SARS-CoV-2 , which enters host cells	COUNT: 2
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: coronavirus 2 ( SARS-CoV-2 ) ( 6 ) , which infects the cells	COUNT: 2
# PATH: sars-cov-2-coronavirus-infect-cell	LINEAR: coronavirus 2 ( SARS-CoV-2 ) ( 6 ) , which infects the cells	COUNT: 2
# PATH: sars-cov-2-infect-airway	LINEAR: SARS-Cov-2 first predominantly infects lower airways	COUNT: 2
# PATH: sars-cov-2-use-receptor-entry-cell	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2 ) as the receptor for entry into host cells	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY 8:
# 	arg1:[e]COVID-19 activates the arg2:ATP $receptor
#
# MOST FREQUENT PATTERNS:
#
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: Enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: 2-enzyme-ace2	LINEAR: enzyme 2 ( ACE2	COUNT: 24
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 and SARS-CoV use angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 also uses human angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 may use angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 and SARS-CoV use the angiotensin converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme II ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses angiotensin converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 also uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 14
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 can use ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses receptor ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 might also use ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 also uses ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 also uses both ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 12
# PATH: sars-cov-2-use-ace2	LINEAR: SARS-CoV-2 also uses ACE2	COUNT: 12
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the angiotensin-converting enzyme 2 ( ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the angiotensin-converting enzyme 2 ( ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds with the ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the Angiotensin-converting enzyme 2 ( ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 can bind to human angiotensin converting enzyme 2 ( ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the angiotensin I converting enzyme 2 ( ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the ACE2	COUNT: 9
# PATH: sars-cov-2-bind-receptor-ace2	LINEAR: SARS-CoV-2 binds to the ACE2	COUNT: 9
# PATH: ace2-receptor	LINEAR: ACE2 receptor	COUNT: 6
# PATH: ace2-receptor	LINEAR: ACE2 receptor	COUNT: 6
# PATH: ace2-receptor	LINEAR: receptor , ACE2	COUNT: 6
# PATH: ace2-receptor	LINEAR: ACE2 receptor	COUNT: 6
# PATH: ace2-receptor	LINEAR: ACE2 receptor	COUNT: 6
# PATH: ace2-receptor	LINEAR: ACE2 receptor	COUNT: 6
# PATH: sars-cov-2-use-receptor-ace2	LINEAR: SARS-CoV-2 also uses the ACE2	COUNT: 5
# PATH: sars-cov-2-use-receptor-ace2	LINEAR: SARS-CoV-2 use the ACE2	COUNT: 5
# PATH: sars-cov-2-use-receptor-ace2	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 5
# PATH: sars-cov-2-use-receptor-ace2	LINEAR: SARS-CoV-2 and SARS-CoV use the same receptor , ACE2	COUNT: 5
# PATH: sars-cov-2-use-receptor-ace2	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 5
# PATH: 2-receptor-ace2	LINEAR: 2 ( ACE2 ) receptor	COUNT: 4
# PATH: 2-receptor-ace2	LINEAR: 2 ( ACE2 ) receptor	COUNT: 4
# PATH: sars-cov-2-employ-ace2	LINEAR: SARS-CoV-2 employs the SARS-CoV receptor ACE2	COUNT: 4
# PATH: sars-cov-2-employ-ace2	LINEAR: SARS-CoV-2 employs ACE2	COUNT: 4
# PATH: sars-cov-2-employ-ace2	LINEAR: SARS-CoV-2 employs the SARS-CoV receptor ACE2	COUNT: 4
# PATH: 2-receptor-ace2	LINEAR: 2 ( ACE2 ) receptor	COUNT: 4
# PATH: 2-receptor-ace2	LINEAR: 2 ( ACE2 ) receptor	COUNT: 4
# PATH: sars-cov-2-employ-ace2	LINEAR: SARS-CoV-2 and SARS-CoV employ ACE2	COUNT: 4
# PATH: SARS-CoV-2-use-receptor-ace2	LINEAR: SARS-CoV-2 , much like the structurally similar and precedent SARS-CoV , uses the ACE2	COUNT: 3
# PATH: sars-cov-2-require-enzyme-ace2	LINEAR: SARS-CoV-2 , as well as other corona viruses , requires the angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 , like SARS-CoV , uses the same receptor angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 , like SARS-CoV ( Li et al. , 2003 ) , uses the angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: (ace)-2-receptor	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: SARS-CoV-2-use-receptor-ace2	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-receptor-ace2	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-ace2	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: (ace)-2-receptor	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: sars-cov-2-require-enzyme-ace2	LINEAR: SARS-CoV-2 , just like SARS-CoV , requires the angiotensinconverting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-receptor-cell	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell	COUNT: 3
# PATH: SARS-CoV-2-use-receptor-cell	LINEAR: SARS-CoV-2 , which is the virus causing coronavirus disease 2019 ( COVID-19 ) , uses the angiotensin-converting enzyme 2 ( ACE2 ) as a cell	COUNT: 3
# PATH: sars-cov-2-require-enzyme-ace2	LINEAR: SARS-CoV-2 similarly to SARS-CoV requires angiotensin-converting enzyme 2 ( AcE2	COUNT: 3
# PATH: ace2-protein	LINEAR: ACE2 protein	COUNT: 3
# PATH: ace2-protein	LINEAR: ACE2 protein	COUNT: 3
# PATH: SARS-CoV-2-use-enzyme-ace2	LINEAR: SARS-CoV-2 uses the receptor angiotensinconverting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-ace2	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-ace2	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 3
# PATH: SARS-CoV-2-use-receptor-cell	LINEAR: SARS-CoV-2 uses the membrane protein Angiotensin I converting enzyme 2(ACE2 ) as a cell	COUNT: 3
# PATH: (ace)-2-receptor	LINEAR: receptor , angiotensin converting enzyme (ACE)-2	COUNT: 3
# PATH: ace2-protein	LINEAR: ACE2 protein	COUNT: 3
# PATH: sars-cov-2-utilize-receptor-enzyme-ace2	LINEAR: SARS-CoV-2 utilizes the same receptor of SARS-CoV , which is angiotensin converting enzyme II ( ACE2	COUNT: 2
#
#
#
# =================================================================
# =================================================================
