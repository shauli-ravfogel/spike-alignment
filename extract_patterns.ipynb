# %%
# %load_ext autoreload
# %autoreload 2
import bert
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import spike_queries
import spacy
from typing import List
from collections import defaultdict
import tqdm

# %%
def load_results(fname):
    
    with open(fname, "r", encoding = "utf-8") as f:
        sents = f.readlines()
    
    sents = [s.strip().split("\t")[-1] for s in sents]
    original, results = sents[0], sents[1:]
    return original, results


def get_spike_results_arguments_representations(model, spike_results, layers):
    
    sents = spike_results["sentence_text"].tolist()
    arg1_idx_start = spike_results["arg1_first_index"].to_numpy().astype(int)
    arg2_idx_start = spike_results["arg2_first_index"].to_numpy().astype(int)
    arg1_idx_end = spike_results["arg1_last_index"].to_numpy().astype(int)
    arg2_idx_end = spike_results["arg2_last_index"].to_numpy().astype(int)
    
    arg1_rep = []
    arg2_rep = []
    
    for s, arg1_start, arg2_start, arg1_end, arg2_end in zip(sents, arg1_idx_start, arg2_idx_start, arg1_idx_end, arg2_idx_end):
        #idx_to_mask = [arg1_start, arg2_start, arg1_end, arg2_end]
        H, _, _, orig2tok = model.encode(s, layers = layers)

        h1, h2 = H[orig2tok[arg1_start]:orig2tok[arg1_end] + 1], H[orig2tok[arg2_start]:orig2tok[arg2_end] + 1]
        
        h1 = np.mean(h1, axis = 0)
        h2 = np.mean(h2, axis = 0)
        
        arg1_rep.append(h1)
        arg2_rep.append(h2)
        
    arg1_mean = np.mean(arg1_rep, axis = 0)
    arg2_mean = np.mean(arg2_rep, axis = 0)
        
    return arg1_mean, arg2_mean
    


def main(filename, layers = [-1]):
    
    
    query, results1 = load_results(filename)
    spike_results = spike_queries.perform_query(query, dataset_name = "covid19", num_results = 50, query_type = "syntactic")
    spike_results = spike_results[spike_results['sentence_text'].notnull()]
    arg1_rep, arg2_rep = get_spike_results_arguments_representations(model, spike_results, layers)
        
    first, first_ind1, first_ind2 = spike_results["sentence_text"].tolist()[-1], int(spike_results["arg1_first_index"].tolist()[-1]), int(spike_results["arg2_first_index"].tolist()[-1])
    
    alignments = []
    for s in results1:
        H, tokenized_text, tok_to_orig_map, orig2tok = model.encode(s, layers = layers)
        sims_arg1 = cosine_similarity([arg1_rep], H[1:-2])[0]
        sims_arg2 = cosine_similarity([arg2_rep], H[1:-2])[0]
        arg1_ind = np.argmax(sims_arg1) + 1
        
        sims_arg2[np.argmax(sims_arg1)] = -1
        arg2_ind = np.argmax(sims_arg2) + 1
        #print(arg1_ind, arg2_ind)
        if arg1_ind not in tok_to_orig_map or arg2_ind not in tok_to_orig_map:
            #print("ERROR")
            continue
        alignments.append((s, tok_to_orig_map[arg1_ind], tok_to_orig_map[arg2_ind]))
    
    return alignments

# %%
model = bert.BertEncoder("cuda", "scibert")
# Out:
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# Model name 'allenai/scibert_scivocab_uncased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'allenai/scibert_scivocab_uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/vocab.txt from cache at /home/shauli/.cache/torch/transformers/e3debd8fbdf40874753724814ee0520f612b577b26c8755bca485103b47cd3bc.60287becc5ab96d85a4bf377eb90feaf3b9c80d3b23e84311dccd3588f56d4fb
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/added_tokens.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/special_tokens_map.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/tokenizer_config.json from cache at None
# loading weights file https://cdn.huggingface.co/allenai/scibert_scivocab_uncased/pytorch_model.bin from cache at /home/shauli/.cache/torch/transformers/54e18c298451d3195ba8359e7a3fa2bc04c70c730c5b6744928278e67940eacb.7587182ea55c40bf7fd0961c1176c31fa22558da2bf20c199874fa5a8ecb4613

# %%
alignments1 = main("results6.txt", layers = [-1])
alignments1 = alignments1[:500]

# %%
len(alignments1)
# Out:
# 500

# %% [markdown]
# ## Parse

# %%
def parse_results(sentences: List[str]):
    
    #nlp = spacy.load("en_core_sci_sm")
    nlp = spacy.load("en_core_sci_lg")
    
    docs = [spacy.tokens.Doc(vocab=nlp.vocab, words = sentence.split(" ")) for sentence in sentences]
    for name, proc in nlp.pipeline:
        print(name)
        for i,doc in enumerate(tqdm.tqdm(docs)):
            docs[i] = proc(doc)
    return docs



def get_ancestors(tok):
    
    parents = []
    
    while tok.head != tok:
    
        parents.append(tok.head)
        tok = tok.head
        
    
    return parents
    
def get_path_between_tokens(tok1, tok2):
    
    path1 = get_ancestors(tok1)
    path2 = get_ancestors(tok2)
    #print(path1, path2)
    
    lowest_ancestor = None
    for tok in path1:
        if tok in path2:
            lowest_ancestor = tok
            break

    
    path = [tok1] + path1[:path1.index(lowest_ancestor)+1] + path2[::-1][path2.index(lowest_ancestor):] + [tok2]
    return path

# %%
sents = [s for s,ind1,ind2 in alignments1]

# %%
docs = parse_results(sents)
# Out:
#   9%|▊         | 43/500 [00:00<00:01, 422.52it/s]
# tagger
# 100%|██████████| 500/500 [00:01<00:00, 446.00it/s]
#   8%|▊         | 39/500 [00:00<00:01, 384.74it/s]
# parser
# 100%|██████████| 500/500 [00:01<00:00, 386.21it/s]
#   9%|▉         | 46/500 [00:00<00:00, 456.34it/s]
# ner
# 100%|██████████| 500/500 [00:01<00:00, 455.34it/s]

# %%
docs[0][0].head
# Out:
# injury

# %%
get_ancestors(docs[0][6])
# Out:
# []

# %%
w1 = docs[0][3]
w2 = docs[0][6]
print(w1,w2)
get_path_between_tokens(w1, w2)
# Out:
# is manifestation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-24d0394f730e> in <module>
#       2 w2 = docs[0][6]
#       3 print(w1,w2)
# ----> 4 get_path_between_tokens(w1, w2)
#
# <ipython-input-22-2472718e7790> in get_path_between_tokens(tok1, tok2)
#      37             break
#      38
# ---> 39     path = [tok1] + path1[:path1.index(lowest_ancestor)+1] + path2[::-1][path2.index(lowest_ancestor):] + [tok2]
#      40     return path
#
# ValueError: None is not in list

# %%
from spacy import displacy
displacy.render(docs[0], style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a222c6a1d1014478956df43e3caf89ee-0" class="displacy" width="3025" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Acute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">kidney</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">injury</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">possible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">manifestation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">severe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">forms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">COVID-19 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">conferring</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">mortality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">7 .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-0" stroke-width="2px" d="M70,439.5 C70,264.5 385.0,264.5 385.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-2" stroke-width="2px" d="M420,439.5 C420,89.5 1095.0,89.5 1095.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-3" stroke-width="2px" d="M595,439.5 C595,177.0 1090.0,177.0 1090.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-4" stroke-width="2px" d="M770,439.5 C770,264.5 1085.0,264.5 1085.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a222c6a1d1014478956df43e3caf89ee-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a222c6a1d1014478956df43e3caf89ee-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.

# %%
paths_lemmas = []
paths_deps = []
paths_lemmas_deps = []

for doc, (sent, idx1, idx2) in zip(docs, alignments1):
        print("doc is {}".format(doc))
        print("idx are: {} and {}".format(idx1, idx2))

        tok1, tok2 = doc[idx1], doc[idx2]
        path = get_path_between_tokens(tok1, tok2)
    
        print([tok.ent_iob_ for tok in path])
        print([tok.lemma_ for tok in path])
        print([tok.ent_type_ for tok in path])
        paths_lemmas.append("-".join([tok.lemma_ for tok in path]))
        paths_deps.append("-".join([tok.dep_ for tok in path]))
        paths_lemmas_deps.append("-".join([tok.lemma_+"."+tok.dep_ for tok in path]))
        print("------------------------------------")
# Out:
# doc is Acute kidney injury is a possible manifestation in severe forms of COVID-19 , conferring a high mortality 7 .
# idx are: 2 and 8
# ['I', 'B', 'O', 'B']
# ['injury', 'manifestation', 'form', 'severe']
# ['ENTITY', 'ENTITY', '', 'ENTITY']
# ------------------------------------
# doc is Coagulation dysfunction is one of the major causes for death in patients with severe COVID-19 [ 4 ] .
# idx are: 9 and 11
# ['B', 'O', 'O', 'B', 'B']
# ['death', 'cause', 'cause', 'death', 'patient']
# ['ENTITY', '', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Hypoxia is the most common manifestation of patients with COVID-19 , especially in severely or critically ill patients .
# idx are: 0 and 7
# ['B', 'O', 'B', 'B']
# ['hypoxia', 'be', 'manifestation', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Early-onset pneumonia is a common and severe complication that is related to aspiration in patients with GBS .
# idx are: 1 and 14
# ['B', 'O', 'B', 'B', 'B']
# ['pneumonia', 'be', 'complication', 'aspiration', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Barotrauma is a common complication in patients with SARS .
# idx are: 0 and 6
# ['B', 'O', 'B', 'B']
# ['barotrauma', 'be', 'complication', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is COVID-19 infection is associated with several cardiac complications with high rates of adverse outcomes .
# idx are: 1 and 2
# ['I', 'B', 'B', 'O']
# ['infection', 'associate', 'associate', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is COVID-19 infection is associated with several cardiac complications with high rates of adverse outcomes .
# idx are: 1 and 2
# ['I', 'B', 'B', 'O']
# ['infection', 'associate', 'associate', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is AKI is one of the common complications with COVID-19 , and is associated with increased morbidity and mortality .
# idx are: 0 and 1
# ['B', 'O', 'O', 'O']
# ['AKI', 'one', 'one', 'be']
# ['ENTITY', '', '', '']
# ------------------------------------
# doc is Spontaneous pneumothorax is a specific and potentially life-threatening complication in SARS patients .
# idx are: 1 and 11
# ['B', 'B', 'B', 'B']
# ['pneumothorax', 'complication', 'complication', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is COVID-19 pneumonia may lead to acute respiratory distress syndrome and severe respiratory failure ( 1 ) .
# idx are: 1 and 2
# ['I', 'O', 'O', 'O']
# ['pneumonia', 'lead', 'lead', 'may']
# ['ENTITY', '', '', '']
# ------------------------------------
# doc is Pneumonia is the most frequent and serious complication of COVID-19 , due to excessive host immune response causing an acute respiratory distress syndrome .
# idx are: 0 and 8
# ['B', 'O', 'B', 'O']
# ['pneumonia', 'be', 'covid-19', 'of']
# ['ENTITY', '', 'ENTITY', '']
# ------------------------------------
# doc is Acute respiratory distress syndrome developing in patients with COVID-19 pneumonia is associated with a high mortality rate and is the main cause of death in patients with SRAS-Cov-2 infection [ 1 ] .
# idx are: 9 and 28
# ['I', 'B', 'B', 'I', 'B', 'B', 'I']
# ['pneumonia', 'patient', 'develop', 'syndrome', 'associate', 'patient', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Pneumonia is a life-threatening complication of COVID-19 infection 10 .
# idx are: 0 and 7
# ['B', 'O', 'B', 'I']
# ['pneumonia', 'be', 'complication', 'infection']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is ARDS and shock are common complications that can lead to death in COVID-19 patients .
# idx are: 2 and 13
# ['B', 'B', 'O', 'B', 'B']
# ['shock', 'ards', 'be', 'death', 'patient']
# ['ENTITY', 'ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Multiorgan injury , which significantly increases mortality , is often evident in patients with COVID-19 .
# idx are: 1 and 12
# ['I', 'O', 'O', 'B']
# ['injury', 'evident', 'evident', 'patient']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Acute IH is a significant complication of high-dose IVIg infusion .
# idx are: 1 and 9
# ['I', 'B', 'B', 'B']
# ['ih', 'complication', 'complication', 'infusion']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Multiorgan failure and disseminated intravascular coagulation ( DIC ) are also frequently observed during COVID-19 infection .
# idx are: 7 and 15
# ['B', 'I', 'I', 'O', 'O', 'I']
# ['dic', 'coagulation', 'failure', 'observe', 'observe', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Acute Respiratory Distress Syndrome ( ARDS ) is one of the commonest complications developing in patients with COVID-19 [ 6 ] .
# idx are: 5 and 15
# ['B', 'I', 'O', 'O', 'B']
# ['ards', 'syndrome', 'one', 'develop', 'patient']
# ['ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Cardiac injury is a common condition among the hospitalized patients with COVID-19 .
# idx are: 1 and 9
# ['I', 'O', 'B', 'B']
# ['injury', 'be', 'condition', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is DIC is a severe complication in COVID-19 patients and it has been related to poor prognosis and increased mortality ( 71.4 % of patient who die of COVID-19 ) ( 2 ) .
# idx are: 0 and 7
# ['B', 'O', 'B', 'B', 'B']
# ['dic', 'be', 'complication', 'complication', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is AKI occurs frequently among patients with Covid-19 disease .
# idx are: 0 and 7
# ['B', 'O', 'B', 'I']
# ['AKI', 'occur', 'patient', 'disease']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is AKI occurs frequently among patients with Covid-19 disease .
# idx are: 0 and 7
# ['B', 'O', 'B', 'I']
# ['AKI', 'occur', 'patient', 'disease']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is HTN is a comorbid condition which has been reported to be associated with increased mortality in patients with COVID-19 infection .
# idx are: 14 and 19
# ['B', 'B', 'B', 'B', 'B', 'I']
# ['mortality', 'associate', 'associate', 'mortality', 'patient', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is AKI is a common consequence of COVID-19 , either due to ATN or hypotension .
# idx are: 0 and 1
# ['B', 'O', 'O', 'O']
# ['AKI', 'consequence', 'consequence', 'be']
# ['ENTITY', '', '', '']
# ------------------------------------
# doc is Acute respiratory distress is one of the major causes of mortality associated with COVID-19 disease .
# idx are: 14 and 3
# ['I', 'B', 'B', 'O', 'O', 'O', 'O']
# ['disease', 'associate', 'mortality', 'cause', 'one', 'one', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '', '', '', '']
# ------------------------------------
# doc is Acute respiratory distress is one of the major causes of mortality associated with COVID-19 disease .
# idx are: 14 and 3
# ['I', 'B', 'B', 'O', 'O', 'O', 'O']
# ['disease', 'associate', 'mortality', 'cause', 'one', 'one', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '', '', '', '']
# ------------------------------------
# doc is RSV-induced ARDS is very uncommon but can be lethal in immunocompetent patients .
# idx are: 1 and 11
# ['B', 'O', 'B', 'B']
# ['ards', 'uncommon', 'lethal', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute respiratory distress syndrome , which is a type of respiratory failure characterized by a rapid onset of generalized inflammation in the lungs , is the leading cause of mortality of patients with COVID-19 .
# idx are: 19 and 31
# ['I', 'O', 'O', 'I', 'O', 'I', 'O', 'B', 'B']
# ['inflammation', 'onset', 'characterize', 'failure', 'type', 'syndrome', 'be', 'mortality', 'patient']
# ['ENTITY', '', '', 'ENTITY', '', 'ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is A significant proportion of patients with COVID-19 may develop shock and multiorgan failure 1 , 5 .
# idx are: 9 and 4
# ['B', 'O', 'B', 'B']
# ['shock', 'develop', 'proportion', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute respiratory distress syndrome ( ARDS ) is a major complication of COVID pneumonia in patients with severe disease .
# idx are: 13 and 15
# ['B', 'B', 'B', 'B']
# ['pneumonia', 'complication', 'pneumonia', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is The most common fatal complication of COVID-19 is acute respiratory distress syndrome ( ARDS ) .
# idx are: 4 and 5
# ['B', 'I', 'B', 'O']
# ['complication', 'syndrome', 'covid-19', 'of']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Pneumonia is a common presentation in COVID-19 infected patients , with hypoxemic ARF .
# idx are: 0 and 8
# ['B', 'O', 'B', 'B']
# ['pneumonia', 'be', 'presentation', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is AKI is a possible manifestation of COVID-19 , and its occurrence usually indicates a severe disease with high mortality rate .
# idx are: 0 and 15
# ['B', 'B', 'O', 'B']
# ['AKI', 'manifestation', 'indicate', 'disease']
# ['ENTITY', 'ENTITY', '', 'ENTITY']
# ------------------------------------
# doc is Acute heart failure can be the primary presenting manifestation of COVID-19 infection .
# idx are: 2 and 11
# ['I', 'B', 'B', 'I']
# ['failure', 'manifestation', 'manifestation', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Life-threatening dengue shock syndrome ( DSS ) is more likely to occur after a second DENV infection [ 1 , 2 ] .
# idx are: 3 and 16
# ['I', 'O', 'O', 'I']
# ['syndrome', 'likely', 'occur', 'infection']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Liver damage is a common feature in severe COVID-19 patients .
# idx are: 1 and 9
# ['I', 'O', 'O', 'B']
# ['damage', 'feature', 'feature', 'patient']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is In severe cases , COVID-19 can be complicated by an acute respiratory distress syndrome [ 1 ] .
# idx are: 1 and 2
# ['B', 'B', 'O', 'O', 'B']
# ['severe', 'case', 'complicate', 'complicate', 'case']
# ['ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Acute kidney injury is one of the complications or preexisting conditions of MERS-CoV infection .
# idx are: 2 and 13
# ['I', 'O', 'B', 'I']
# ['injury', 'be', 'complication', 'infection']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute myocardial injury has been reported as the most common cardiac manifestation of COVID -19 and is reported in 8 -12 % of patients .
# idx are: 2 and 23
# ['I', 'O', 'O', 'B']
# ['injury', 'report', '%', 'patient']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is GLILD is a severe inflammatory complication of CVID with high mortality .
# idx are: 4 and 1
# ['B', 'I', 'I', 'O']
# ['inflammatory', 'complication', 'complication', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Thrombotic coagulopathy is common in critically ill patients suffering from COVID-19 , with associated high rates of respiratory failure requiring prolonged periods of mechanical ventilation .
# idx are: 0 and 7
# ['B', 'I', 'O', 'O', 'B']
# ['thrombotic', 'coagulopathy', 'common', 'common', 'patient']
# ['ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Acute kidney injury ( AKI ) can be a manifestation of COVID-19 patients .
# idx are: 4 and 12
# ['B', 'I', 'B', 'B', 'B']
# ['aki', 'injury', 'manifestation', 'manifestation', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Invasive pulmonary aspergillosis is a complication in critically ill patients with acute respiratory distress syndrome , especially those with severe influenza pneumonia .
# idx are: 3 and 9
# ['O', 'B', 'B', 'B']
# ['be', 'complication', 'complication', 'patient']
# ['', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Invasive pulmonary aspergillosis is a complication in critically ill patients with acute respiratory distress syndrome , especially those with severe influenza pneumonia .
# idx are: 3 and 9
# ['O', 'B', 'B', 'B']
# ['be', 'complication', 'complication', 'patient']
# ['', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is COVID-19-associated coagulopathy is common in patients with COVID-19 , causing high rates of thrombotic complications that increase the morbidity and mortality .
# idx are: 2 and 5
# ['O', 'O', 'O', 'B']
# ['be', 'common', 'common', 'patient']
# ['', '', '', 'ENTITY']
# ------------------------------------
# doc is COVID-19-associated coagulopathy is common in patients with COVID-19 , causing high rates of thrombotic complications that increase the morbidity and mortality .
# idx are: 2 and 5
# ['O', 'O', 'O', 'B']
# ['be', 'common', 'common', 'patient']
# ['', '', '', 'ENTITY']
# ------------------------------------
# doc is One important complication associated with COVID-19 disease and a potential differential diagnosis in sudden respiratory distress is pulmonary embolism ( PE ) .
# idx are: 2 and 6
# ['B', 'I', 'B', 'I']
# ['complication', 'embolism', 'associate', 'disease']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute pulmonary embolism is an uncharacteristic presentation in patients with COVID-19 .
# idx are: 2 and 8
# ['I', 'I', 'I', 'B']
# ['embolism', 'presentation', 'presentation', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Cardiac arrhythmias are a common manifestation in patients with COVID-19 .
# idx are: 1 and 7
# ['I', 'O', 'B', 'B', 'B']
# ['arrhythmia', 'be', 'manifestation', 'manifestation', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is VZV pneumonia is a common complication of VZV septicemia in children with a mortality rate of 9 - 50 % .
# idx are: 1 and 10
# ['B', 'B', 'B', 'B']
# ['pneumonia', 'complication', 'complication', 'child']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is VZV pneumonia is a common complication of VZV septicemia in children with a mortality rate of 9 - 50 % .
# idx are: 1 and 10
# ['B', 'B', 'B', 'B']
# ['pneumonia', 'complication', 'complication', 'child']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Introduction : cytokine storm syndrome ( CSS ) is a serious complication of COVID-19 patients .
# idx are: 4 and 14
# ['I', 'B', 'O', 'B', 'B']
# ['syndrome', 'complication', 'introduction', 'complication', 'patient']
# ['ENTITY', 'ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is High prevalence of acute pulmonary embolism ( APE ) has been recently reported in patients admitted with COVID-19-related pneumonia [ 5 ] .
# idx are: 18 and 14
# ['I', 'B', 'B', 'O', 'O', 'B']
# ['pneumonia', 'admit', 'patient', 'report', 'report', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Diffuse thrombosis is emerging as an important contributor to adverse outcomes in patients with COVID-19 .
# idx are: 1 and 12
# ['I', 'O', 'I', 'B']
# ['thrombosis', 'emerge', 'outcome', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is ALF is a rare but potentially life threatening adverse effect of IvAm .
# idx are: 0 and 1
# ['B', 'I', 'I', 'O']
# ['ALF', 'life', 'life', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Primary viral pneumonia ( PVP ) is a rare complication of seasonal influenza [ 2 ] .
# idx are: 2 and 12
# ['I', 'B', 'B', 'I']
# ['pneumonia', 'complication', 'complication', 'influenza']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial superinfection is a common complication of viral lower respiratory tract infection , particularly in adults .
# idx are: 0 and 11
# ['B', 'B', 'B', 'B', 'I']
# ['bacterial', 'superinfection', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is RSV is a cause of serious disease in BMT recipients .
# idx are: 0 and 6
# ['B', 'O', 'O', 'I']
# ['rsv', 'cause', 'cause', 'disease']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is MIBE is a rare but fatal complication that affects individuals with defective cellular immunity and typically occurs months after infection .
# idx are: 6 and 19
# ['B', 'O', 'O', 'B']
# ['complication', 'be', 'occur', 'infection']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is While respiratory failure is the most serious complication in patients with COVID-19 , a considerable number of patients develop acute circulatory failure [ 1 ] .
# idx are: 2 and 9
# ['I', 'O', 'O', 'B', 'B']
# ['failure', 'be', 'be', 'complication', 'patient']
# ['ENTITY', '', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Isolated severe liver injury is rare and usually accompanied by shock , respiratory failure , cardiac insufficiency , and/or renal insufficiency in patients with critical-type COVID-19 .
# idx are: 3 and 22
# ['I', 'B', 'B', 'B']
# ['injury', 'rare', 'shock', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Established myocarditis is a relatively rare sequelae of COVID-19 infection .
# idx are: 1 and 9
# ['B', 'B', 'B', 'I']
# ['myocarditis', 'sequelae', 'sequelae', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is SSI is a very common and life-threatening infection during ICU stays .
# idx are: 7 and 9
# ['I', 'O', 'B', 'B']
# ['infection', 'be', 'stay', 'icu']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial pneumonia is a common complication of respiratory virus infection that leads to increased morbidity and mortality ( 9 ) .
# idx are: 1 and 9
# ['I', 'B', 'B', 'I']
# ['pneumonia', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Pneumonia is one of the main hallmarks of severe COVID-19 , with high risks of severe hypoxemia and acute respiratory distress syndrome .
# idx are: 0 and 8
# ['B', 'O', 'B', 'B']
# ['pneumonia', 'be', 'covid-19', 'severe']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is AKI is not uncommon in patients with COVID-19 ( 8) .
# idx are: 0 and 5
# ['B', 'O', 'O', 'B']
# ['AKI', 'uncommon', 'uncommon', 'patient']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Severe bronchiolitis is one of the major outcomes of RSV infection .
# idx are: 1 and 10
# ['I', 'O', 'B', 'I']
# ['bronchiolitis', 'one', 'outcome', 'infection']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute kidney injury is a common complication in patients with sepsis .
# idx are: 10 and 8
# ['B', 'B', 'B', 'B', 'B']
# ['sepsis', 'patient', 'complication', 'complication', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is The most serious complication from COVID-19 is death often from acute respiratory distress syndrome ( ARDS ) [ 1 ] .
# idx are: 3 and 4
# ['B', 'O', 'O', 'B', 'O']
# ['complication', 'be', 'be', 'complication', 'from']
# ['ENTITY', '', '', 'ENTITY', '']
# ------------------------------------
# doc is ILD is a rare but potentially fatal complication of RTX therapy .
# idx are: 0 and 10
# ['B', 'B', 'B', 'B']
# ['ILD', 'complication', 'complication', 'therapy']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Idiopathic ( noninfectious ) interstitial pneumonia is a complication reported in most allogeneic HSCT studies , with a high mortality rate .
# idx are: 5 and 6
# ['I', 'B', 'B', 'O']
# ['pneumonia', 'complication', 'complication', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Recent studies suggest that severe COVID-19 pneumonia may be associated with a coagulopathic state and an increased risk of venous thromboembolism [ 2 ] .
# idx are: 6 and 4
# ['I', 'B', 'B', 'I', 'B']
# ['pneumonia', 'associate', 'associate', 'pneumonia', 'severe']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Patients with severe COVID-19 infection are at risk of acute respiratory distress syndrome and death .
# idx are: 4 and 0
# ['I', 'B', 'B', 'B', 'B']
# ['infection', 'patient', 'risk', 'risk', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Furthermore , bacterial superinfection of primary viral pneumonia is a common complication .
# idx are: 7 and 6
# ['I', 'B', 'B', 'I', 'B']
# ['pneumonia', 'superinfection', 'superinfection', 'pneumonia', 'viral']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is RV infection in patients with chronic obstructive pulmonary disease may cause mortality [ 2 ] .
# idx are: 11 and 1
# ['B', 'O', 'O', 'I']
# ['mortality', 'cause', 'cause', 'infection']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Lung injury has been reported as the major outcome of COVID-19 infection .
# idx are: 1 and 11
# ['I', 'O', 'B', 'I']
# ['injury', 'report', 'outcome', 'infection']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is S-OIV pneumonia is a complication of S-OIV infection and can cause serious illness .
# idx are: 1 and 7
# ['B', 'B', 'B', 'I']
# ['pneumonia', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is ARF is a common complication caused by Bothrops snakebite with relevant morbidity and mortality .
# idx are: 0 and 1
# ['B', 'B', 'B', 'O']
# ['arf', 'complication', 'complication', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Respiratory bacterial superinfection of influenza represents a common complication with high mortality [ 15 , 18 , 25 , 29 , 30 ] .
# idx are: 4 and 8
# ['B', 'I', 'O', 'O', 'B']
# ['influenza', 'superinfection', 'represent', 'represent', 'complication']
# ['ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Viral myocarditis can be the cause of cardiogenic shock in the ICU setting .
# idx are: 8 and 12
# ['I', 'B', 'B', 'O']
# ['shock', 'cause', 'cause', 'set']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Respiratory failure is the major complication of SARS .
# idx are: 1 and 7
# ['I', 'O', 'O', 'B']
# ['failure', 'be', 'of', 'sars']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is CMV pneumonitis is a lifethreatening complication seen in allograft recipients with a mortality of 80 - 90 % .
# idx are: 0 and 9
# ['B', 'I', 'B', 'O', 'B']
# ['cmv', 'pneumonitis', 'complication', 'see', 'recipient']
# ['ENTITY', 'ENTITY', 'ENTITY', '', 'ENTITY']
# ------------------------------------
# doc is HAdV pneumonia in pediatric patients can progress rapidly to multi-organ failure .
# idx are: 1 and 4
# ['I', 'O', 'I', 'B']
# ['pneumonia', 'progress', 'pneumonia', 'patient']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Severe COVID-19 causes cytokine release syndrome and is associated with high mortality .
# idx are: 0 and 11
# ['B', 'B', 'O', 'B', 'I']
# ['severe', 'covid-19', 'cause', 'associate', 'mortality']
# ['ENTITY', 'ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial superinfection is a potential and serious complication of viral lower respiratory tract infection , particularly with influenza .
# idx are: 0 and 13
# ['B', 'B', 'B', 'B', 'I']
# ['bacterial', 'superinfection', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Infection is a common complication in patients after acute CNS injury .
# idx are: 0 and 6
# ['B', 'B', 'B', 'B']
# ['infection', 'complication', 'complication', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Multi-organ failure is the most lethal complication of SARS-CoV-2 infection 1 .
# idx are: 1 and 9
# ['I', 'B', 'B', 'I']
# ['failure', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is COVID-19 pneumonia is common in adults and rare in children ( 11 ) .
# idx are: 1 and 2
# ['I', 'O', 'O', 'O']
# ['pneumonia', 'common', 'common', 'be']
# ['ENTITY', '', '', '']
# ------------------------------------
# doc is acute mesenteric ischemia ( AMI ) has been reported in severe COVID-19 patients ( 2 ) .
# idx are: 2 and 12
# ['I', 'O', 'O', 'B']
# ['ischemia', 'report', 'report', 'patient']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Acute bilateral interstitial pneumonia is the major cause of morbidity and mortality in COVID-19 .
# idx are: 3 and 12
# ['I', 'O', 'B', 'O']
# ['pneumonia', 'cause', 'covid-19', 'in']
# ['ENTITY', '', 'ENTITY', '']
# ------------------------------------
# doc is The most feared complication of COVID-19 is the development of acute respiratory distress syndrome ( ARDS ) 2 .
# idx are: 15 and 4
# ['B', 'I', 'B', 'B', 'O']
# ['ards', 'syndrome', 'development', 'covid-19', 'of']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Shock might be an uncommon but life threatening complication of a SARS-CoV-2 infection .
# idx are: 0 and 12
# ['B', 'O', 'B', 'I']
# ['shock', 'be', 'complication', 'infection']
# ['ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Pulmonary hemorrhage is a known complication of influenza-related pneumonia .
# idx are: 1 and 8
# ['I', 'B', 'B', 'I']
# ['hemorrhage', 'complication', 'complication', 'pneumonia']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial and fungal infections are common complications of viral pneumonia , especially in critically ill patients .
# idx are: 9 and 15
# ['I', 'B', 'B', 'B']
# ['pneumonia', 'complication', 'complication', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial superinfection is a common and potentially severe complication of influenza .
# idx are: 10 and 2
# ['B', 'B', 'B', 'O']
# ['influenza', 'complication', 'complication', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is Bacterial superinfection is a common and potentially severe complication of influenza .
# idx are: 10 and 2
# ['B', 'B', 'B', 'O']
# ['influenza', 'complication', 'complication', 'be']
# ['ENTITY', 'ENTITY', 'ENTITY', '']
# ------------------------------------
# doc is CVC-related bloodstream infection is a known complication among critically ill patients .
# idx are: 2 and 10
# ['I', 'B', 'B', 'B']
# ['infection', 'complication', 'complication', 'patient']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Sepsis is a major cause of death in children with SCD .
# idx are: 0 and 8
# ['B', 'O', 'O', 'B']
# ['sepsis', 'be', 'in', 'child']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is CAP is a common and potentially serious infection associated with significant morbidity .
# idx are: 0 and 7
# ['B', 'O', 'O', 'B']
# ['CAP', 'be', 'be', 'infection']
# ['ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Influenza vaccination triggering rhabdomyolysis is an extremely rare event and has occurred in adults on statin therapy [ 16 ] .
# idx are: 3 and 0
# ['B', 'B', 'B', 'B']
# ['rhabdomyolysis', 'event', 'rhabdomyolysis', 'influenza']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Thrombosis , which often leads to hemorrhage , is a common clinical complication of severe influenza .
# idx are: 0 and 14
# ['B', 'I', 'B', 'B']
# ['thrombosis', 'complication', 'influenza', 'severe']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Bacterial superinfection is one of the major concerns with primary viral-associated bronchiolitis .
# idx are: 0 and 11
# ['B', 'B', 'O', 'O', 'I']
# ['bacterial', 'superinfection', 'one', 'concern', 'bronchiolitis']
# ['ENTITY', 'ENTITY', '', '', 'ENTITY']
# ------------------------------------
# doc is Prolonged thrombocytopenia is a rare but potentially devastating complication of DHF .
# idx are: 0 and 10
# ['B', 'B', 'B', 'B', 'B']
# ['prolonged', 'thrombocytopenia', 'complication', 'complication', 'DHF']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Shock syndrome is a dangerous complication of dengue infection and is associated with high mortality [ 35 ] .
# idx are: 0 and 8
# ['B', 'I', 'B', 'B', 'I']
# ['shock', 'syndrome', 'complication', 'complication', 'infection']
# ['ENTITY', 'ENTITY', 'ENTITY', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Acute respiratory distress syndrome is one of the main clinical manifestations in severe COVID-19 patients , and pulmonary contusion is common in emergency trauma patients .
# idx are: 17 and 14
# ['B', 'I', 'O', 'I', 'B']
# ['pulmonary', 'contusion', 'one', 'manifestation', 'patient']
# ['ENTITY', 'ENTITY', '', 'ENTITY', 'ENTITY']
# ------------------------------------
# doc is Covid-19 is a respiratory infection with a significant impact on the hematopoietic system and hemostasis leading to several cardiovascular complications .
# idx are: 4 and 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-7beee35168c1> in <module>
#       8
#       9         tok1, tok2 = doc[idx1], doc[idx2]
# ---> 10         path = get_path_between_tokens(tok1, tok2)
#      11
#      12         print([tok.ent_iob_ for tok in path])
#
# <ipython-input-22-2472718e7790> in get_path_between_tokens(tok1, tok2)
#      37             break
#      38
# ---> 39     path = [tok1] + path1[:path1.index(lowest_ancestor)+1] + path2[::-1][path2.index(lowest_ancestor):] + [tok2]
#      40     return path
#
# ValueError: None is not in list

# %%
from collections import Counter
c = Counter(paths_lemmas_deps)
items = list(c.items())
items = sorted(items, key = lambda pair: -pair[1])

# %%
items[:50]
# Out:
# [('infection.nmod-patient.nsubj-risk.ROOT-risk.ROOT-patient.nsubj', 5),
#  ('infection.nsubj-complication.ROOT-complication.ROOT-patient.nmod', 5),
#  ('infection.nsubjpass-associate.ROOT-associate.ROOT-be.auxpass', 4),
#  ('injury.nsubj-be.ROOT-condition.attr-patient.nmod', 3),
#  ('injury.nsubjpass-report.ROOT-%.nmod-patient.nmod', 3),
#  ('be.cop-complication.ROOT-complication.ROOT-patient.nmod', 3),
#  ('pneumonia.nsubj-be.ROOT-complication.attr-patient.nmod', 3),
#  ('pneumonia.nsubjpass-associate.ROOT-associate.ROOT-be.auxpass', 3),
#  ('pneumonia.nsubj-complication.ROOT-complication.ROOT-patient.nmod', 3),
#  ('pneumonia.nsubj-cause.ROOT-morbidity.nmod-patient.nmod', 3),
#  ('pneumonia.nsubj-be.ROOT-complication.attr-infection.nmod', 2),
#  ('AKI.nsubj-occur.ROOT-patient.nmod-disease.nmod', 2),
#  ('disease.nmod-associate.acl-mortality.nmod-cause.nmod-one.ROOT-one.ROOT-be.cop',
#   2),
#  ('be.cop-common.ROOT-common.ROOT-patient.nmod', 2),
#  ('pneumonia.nsubj-complication.ROOT-complication.ROOT-child.nmod', 2),
#  ('syndrome.nsubj-complication.dep-introduction.ROOT-complication.dep-patient.nmod',
#   2),
#  ('bacterial.amod-superinfection.nsubj-complication.ROOT-complication.ROOT-infection.nmod',
#   2),
#  ('pneumonia.nsubj-complication.ROOT-complication.ROOT-infection.nmod', 2),
#  ('pneumonia.nsubj-complication.ROOT-complication.ROOT-be.cop', 2),
#  ('arf.nsubj-complication.ROOT-complication.ROOT-be.cop', 2),
#  ('failure.nsubj-complication.ROOT-complication.ROOT-infection.nmod', 2),
#  ('pneumonia.nsubj-common.ROOT-common.ROOT-be.cop', 2),
#  ('influenza.nmod-complication.ROOT-complication.ROOT-be.cop', 2),
#  ('sepsis.nsubjpass-observe.ROOT-%.nmod-patient.nmod', 2),
#  ('injury.nsubj-common.ROOT-common.ROOT-patient.nmod', 2),
#  ('pneumonia.nsubj-cause.ROOT-cause.ROOT-be.cop', 2),
#  ('severe.amod-covid-19.nsubj-lead.ROOT-lead.ROOT-can.aux', 2),
#  ('sepsis.nsubj-problem.conj-infection.ROOT-problem.conj-patient.nmod', 2),
#  ('shock.nmod-associate.ROOT-associate.ROOT-patient.nmod', 2),
#  ('death.nmod-cause.ccomp-cause.ccomp-death.nmod-patient.nmod', 2),
#  ('pneumonia.nmod-patient.nmod-syndrome.dobj-cause.ROOT-syndrome.dobj-patient.nmod',
#   2),
#  ('infection.nsubj-complication.ROOT-complication.ROOT-be.cop', 2),
#  ('ILD.dobj-develop.advcl-risk.ROOT-be.cop-patient.nsubj', 2),
#  ('circi.nsubj-common.ROOT-common.ROOT-patient.nmod', 2),
#  ('infection.nmod-manifestation.nsubj-manifestation.nsubj-infection.nmod-of.case',
#   2),
#  ('be.cop-cause.ROOT-cause.ROOT-patient.nmod', 2),
#  ('meningitis.nsubj-finding.ROOT-finding.ROOT-infection.nmod', 2),
#  ('event.conj-syndrome.nsubj-be.ROOT-cause.pobj-patient.nmod', 2),
#  ('pneumonia.nsubj-be.cop-feature.ROOT-covid-19.nmod-severe.amod', 2),
#  ('complication.nsubj-failure.ROOT-complication.nsubj-patient.nmod', 2),
#  ('exacerbation.nsubj-responsible.ROOT-morbidity.nmod-patient.nmod', 2),
#  ('bacteremia.nmod-cause.attr-cause.attr-bacteremia.nmod-patient.nmod', 2),
#  ('injury.nsubj-manifestation.ROOT-form.nmod-severe.amod', 1),
#  ('death.nmod-cause.nmod-cause.nmod-death.nmod-patient.nmod', 1),
#  ('hypoxia.nsubj-be.ROOT-manifestation.attr-patient.nmod', 1),
#  ('pneumonia.nsubj-be.cop-complication.ROOT-aspiration.nmod-patient.nmod', 1),
#  ('barotrauma.nsubj-be.ROOT-complication.attr-patient.nmod', 1),
#  ('AKI.nsubj-one.ROOT-one.ROOT-be.cop', 1),
#  ('pneumothorax.nsubj-complication.ROOT-complication.ROOT-patient.nmod', 1),
#  ('pneumonia.nsubj-lead.ROOT-lead.ROOT-may.aux', 1)]
