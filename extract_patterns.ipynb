# %%
# %load_ext autoreload
# %autoreload 2
import bert
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import spike_queries
import spacy
from typing import List
from collections import defaultdict
import tqdm
from termcolor import colored
from collections import Counter
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
def load_results(fname):
    
    with open(fname, "r", encoding = "utf-8") as f:
        sents = f.readlines()
    
    sents = [s.strip().split("\t")[-1] for s in sents]
    original, results = sents[0], sents[1:]
    return original, results


def get_spike_results_arguments_representations(model, spike_results, layers):
    
    sents = spike_results["sentence_text"].tolist()
    arg1_idx_start = spike_results["arg1_first_index"].to_numpy().astype(int)
    arg2_idx_start = spike_results["arg2_first_index"].to_numpy().astype(int)
    arg1_idx_end = spike_results["arg1_last_index"].to_numpy().astype(int)
    arg2_idx_end = spike_results["arg2_last_index"].to_numpy().astype(int)
    
    arg1_rep = []
    arg2_rep = []
    
    for s, arg1_start, arg2_start, arg1_end, arg2_end in zip(sents, arg1_idx_start, arg2_idx_start, arg1_idx_end, arg2_idx_end):
        #idx_to_mask = [arg1_start, arg2_start, arg1_end, arg2_end]
        H, _, _, orig2tok = model.encode(s, layers = layers)

        h1, h2 = H[orig2tok[arg1_start]:orig2tok[arg1_end] + 1], H[orig2tok[arg2_start]:orig2tok[arg2_end] + 1]
        
        h1 = np.mean(h1, axis = 0)
        h2 = np.mean(h2, axis = 0)
        
        arg1_rep.append(h1)
        arg2_rep.append(h2)
        
    arg1_mean = np.mean(arg1_rep, axis = 0)
    arg2_mean = np.mean(arg2_rep, axis = 0)
        
    return arg1_mean, arg2_mean
    


def main(filename, layers = [-1], num = 500):
    
    
    query, results1 = load_results(filename)
    results1 = results1[:num]
    
    spike_results = spike_queries.perform_query(query, dataset_name = "covid19", num_results = 250, query_type = "syntactic")
    spike_results = spike_results[spike_results['sentence_text'].notnull()]
    arg1_rep, arg2_rep = get_spike_results_arguments_representations(model, spike_results, layers)
        
    first, first_ind1, first_ind2 = spike_results["sentence_text"].tolist()[-1], int(spike_results["arg1_first_index"].tolist()[-1]), int(spike_results["arg2_first_index"].tolist()[-1])
    
    alignments = []
    
    for s in results1:
                    
        H, tokenized_text, tok_to_orig_map, orig2tok = model.encode(s, layers = layers)
        sims_arg1 = cosine_similarity([arg1_rep], H[1:-2])[0]
        sims_arg2 = cosine_similarity([arg2_rep], H[1:-2])[0]
        arg1_ind = np.argmax(sims_arg1) + 1
        
        sims_arg2[np.argmax(sims_arg1)] = -1
        arg2_ind = np.argmax(sims_arg2) + 1
        #print(arg1_ind, arg2_ind)
        if arg1_ind not in tok_to_orig_map or arg2_ind not in tok_to_orig_map:
            #print("ERROR")
            continue
        alignments.append((s, tok_to_orig_map[arg1_ind], tok_to_orig_map[arg2_ind]))
            
    return query, spike_results, alignments

# %%
model = bert.BertEncoder("cuda", "scibert")
# Out:
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# Model name 'allenai/scibert_scivocab_uncased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'allenai/scibert_scivocab_uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/vocab.txt from cache at /home/shauli/.cache/torch/transformers/e3debd8fbdf40874753724814ee0520f612b577b26c8755bca485103b47cd3bc.60287becc5ab96d85a4bf377eb90feaf3b9c80d3b23e84311dccd3588f56d4fb
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/added_tokens.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/special_tokens_map.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/tokenizer_config.json from cache at None
# loading weights file https://cdn.huggingface.co/allenai/scibert_scivocab_uncased/pytorch_model.bin from cache at /home/shauli/.cache/torch/transformers/54e18c298451d3195ba8359e7a3fa2bc04c70c730c5b6744928278e67940eacb.7587182ea55c40bf7fd0961c1176c31fa22558da2bf20c199874fa5a8ecb4613

# %% [markdown]
# ## Parse

# %%
def parse_results(sentences: List[str]):
    
    #nlp = spacy.load("en_core_sci_sm")
    nlp = spacy.load("en_core_sci_lg")
    
    docs = [spacy.tokens.Doc(vocab=nlp.vocab, words = sentence.split(" ")) for sentence in sentences]
    for name, proc in nlp.pipeline:
        for i,doc in enumerate(docs):
            docs[i] = proc(doc)
    return docs



def get_ancestors(tok):
    
    parents = [tok]
    
    while tok.head != tok:
    
        parents.append(tok.head)
        tok = tok.head
        
    
    return parents
    
def get_path_between_tokens(tok1, tok2, doc):
    
    path1 = get_ancestors(tok1)
    path2 = get_ancestors(tok2)
    #print(path1, path2)
    
    lowest_ancestor = None
    for tok in path1:
        if tok in path2:
            lowest_ancestor = tok
            break

    path1 =  path1[:path1.index(lowest_ancestor)+1]
    path2 =  path2[:path2.index(lowest_ancestor)+1]
    
    linear_path_before = [tok1 if tok1.i < tok2.i else tok2]
    linear_path_after = [tok1 if tok1.i > tok2.i else tok2]
    linear_path_between =  [t for t in doc if t.i < max(tok1.i, tok2.i) and t.i > min(tok1.i, tok2.i)]
    
    linear_path = linear_path_before + linear_path_between + linear_path_after
    linear_path_str = [t.text for t in linear_path]
    linear_path_str[0] = colored(linear_path_str[0], "red")
    linear_path_str[-1] = colored(linear_path_str[-1], "blue")
    
    linear_path_str = " ".join(linear_path_str)
    
    path = {"ancestor": lowest_ancestor, "path1": path1, "path2": path2, "tok1": tok1, "tok2": tok2, "linear_path": linear_path,
           "linear_path_str": linear_path_str}
    return path

# %%
#from spacy import displacy
#displacy.render(doc, style='dep', jupyter=True)

# %%
def regularize(path1: List[str], path2: List[str]):

    #print("path1", path1)
    #print("path2", path2)
    
    
    path1[-1] = color.BOLD + path1[-1] + color.END
    path2[0] = colored(path2[0], "blue")
    path1[0] = colored(path1[0], "red")
        
    path = path1 + path2[::-1][1:]

    return path
        

def get_paths(docs, alignments, path_type = "lemmas-deps"):

    paths_lemmas = []
    paths_deps = []
    paths_lemmas_deps = []    
    i = 0
    linear_paths = []
    
    for doc, (sent, idx1, idx2) in zip(docs, alignments):
        
        tok1, tok2 = doc[idx1], doc[idx2]
        
        try:
            path_dict = get_path_between_tokens(tok1, tok2, doc)
        except: continue #TODO: check the "None" error.
            
        linear_paths.append(path_dict["linear_path_str"])
    
        tok1_2ances = path_dict["path1"]
        tok2_2ances = path_dict["path2"]
        
        
        lemmas1 = [tok.lemma_ for tok in tok1_2ances]
        lemmas2 = [tok.lemma_ for tok in tok2_2ances]
        deps1 = [tok.dep_ for tok in tok1_2ances]
        deps2 = [tok.dep_ for tok in tok2_2ances]
        
        lemmas = regularize(lemmas1, lemmas2)
        deps = regularize(deps1, deps2)
        zipped = "-".join([lemma+"."+dep for lemma, dep in zip(lemmas, deps)])
        paths_lemmas_deps.append(zipped)
        paths_lemmas.append("-".join(lemmas))
        paths_deps.append("-".join(deps))
        
        i += 1
    
    paths = None
    
    if path_type == "lemmas-deps":
        
        paths =  paths_lemmas_deps

    elif path_type == "lemmas":
        
        paths = path_lemmas
    
    elif path_type == "deps":
        
        paths = path_deps
    
    else:
        
        raise Exception("Unknown type")
    
    return paths, linear_paths

# %%
def sort_by_freq(paths, linear_paths):
    
    together = zip(paths, linear_paths)
    counts = []
    
    for p, p_lin in zip(paths, linear_paths):
        
        counts.append(paths.count(p))

    paths_linpaths_counts = zip(paths, linear_paths, counts)    
    paths_linpaths_counts = sorted(paths_linpaths_counts, key = lambda pair: -pair[-1])
    
    paths, linear_paths, counts = list(zip(*paths_linpaths_counts))
    return paths, linear_paths, counts

# %% [markdown]
# # Collect Paths

# %%
fnames = ["results{}.txt".format(i) for i in range(1,11)]
for fname in fnames:
    query, spike_results, alignments = main(fname, layers = [-1], num = 400)    
    sents = [s for s,ind1,ind2 in alignments]
    docs = parse_results(sents)
    
    paths, linear_paths = get_paths(docs, alignments, "lemmas-deps")
    paths, linear_paths, counts = sort_by_freq(paths, linear_paths)
    
    df = pd.DataFrame({"paths": paths, "linear_paths": linear_paths})
    
    print(color.BOLD + "QUERY:\n\t" + query + color.END )
    print(color.BOLD + "\nMOST FREQUENT PATTERNS:\n" + color.END)
    for i in range(50):
        
        print("PATH: "+ paths[i] + "\tLINEAR: " + linear_paths[i] +"\tCOUNT: " + str(counts[i]))
        
    print("\n\n")
    print("=================================================================")
    print("=================================================================")
# Out:
# QUERY:
# 	<>arg1:virus $infection $causes a <>arg2:condition .
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection can result in severe respiratory disease	COUNT: 5
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection results in an acute , self-limiting and icteric disease	COUNT: 5
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection in humans often results in a severe , life-threatening disease	COUNT: 5
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: infection with encephalitic alphaviruses may result in severe neurologic disease	COUNT: 5
# PATH: infection.nsubj-result.ROOT-disease.nmod	LINEAR: Infection by LCMV can result in acute central nervous system disease	COUNT: 5
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infections cause a debilitating disease	COUNT: 4
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infection causes respiratory tract disease	COUNT: 4
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: infection of JEV can cause nervous system disease	COUNT: 4
# PATH: infection.nsubj-cause.ROOT-disease.dobj	LINEAR: Infection with LIV in humans can cause a neurological disease	COUNT: 4
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: Infection with hMPV is	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infections are	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is	COUNT: 3
# PATH: infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: infection , in domestic cats , causes a variable immunodeficiency syndrome	COUNT: 2
# PATH: infection.nsubj-cause.ROOT	LINEAR: infection causes	COUNT: 2
# PATH: pedv.compound-infection.nsubj-cause.ROOT-enteritis.dobj	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-illness.dobj	LINEAR: infection causes undifferentiated febrile illness	COUNT: 2
# PATH: infection.nsubj-systemic.ROOT-characterize.dep-hemorrhage.nmod	LINEAR: infection in birds is systemic , characterized by hemorrhage	COUNT: 2
# PATH: infection.nsubj-systemic.ROOT-characterize.dep-hemorrhage.nmod	LINEAR: infection in birds is systemic , characterized by hemorrhage	COUNT: 2
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 2
# PATH: infection.nsubj-fatal.ROOT-die.conj-disorder.nmod	LINEAR: infection is often fatal , and animals die from central nervous system disorders	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-symptom.nmod-clinical.amod	LINEAR: Infection with DENV can cause a spectrum of clinical	COUNT: 2
# PATH: pedv.compound-infection.nsubj-cause.ROOT-enteritis.dobj	LINEAR: PEDV infections cause acute , severe atrophic enteritis	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-illness.dobj	LINEAR: infection causes illness	COUNT: 2
# PATH: disease.ROOT-result.acl-damage.nmod	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: disease.ROOT-result.acl-damage.nmod	LINEAR: disease characterized by severe clinical manifestations of the lower respiratory tract , resulting in diffuse alveolar damage	COUNT: 2
# PATH: bkv.nsubj-establish.ROOT-cause.conj-number.dobj-disorder.nmod	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: bkv.nsubj-establish.ROOT-cause.conj-number.dobj-disorder.nmod	LINEAR: BKV establishes infection in the kidney and the urinary tract , and its activation causes a number of disorders	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: Infection of humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: infection.ROOT-be.cop	LINEAR: is a systemic infection	COUNT: 2
# PATH: infection.nsubj-fatal.ROOT-die.conj-disorder.nmod	LINEAR: infection is often fatal , and animals die from central nervous system disorders	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-symptom.nmod-clinical.amod	LINEAR: infection causes a broad spectrum of clinical	COUNT: 2
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 2
# PATH: infection.nmod-associate.ROOT-onset.nsubjpass-enteritis.nmod	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection.nmod-associate.ROOT-onset.nsubjpass-enteritis.nmod	LINEAR: enteritis is associated with infection	COUNT: 2
# PATH: infection.nsubj-result.ROOT-can.aux	LINEAR: infection of humans can	COUNT: 2
# PATH: infection.nsubj-result.ROOT-can.aux	LINEAR: infection can	COUNT: 2
# PATH: infection.ROOT-be.cop	LINEAR: is an important systemic parvoviral infection	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-disease.nmod	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-spectrum.dobj-disease.nmod	LINEAR: infection causes a wide spectrum of diseases	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-can.aux	LINEAR: infection by SFTSV can	COUNT: 2
# PATH: pneumonia.dobj-cause.ROOT-however.advmod	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: pneumonia.dobj-cause.ROOT-however.advmod	LINEAR: However , SARS-CoV-2 causes pneumonia	COUNT: 2
# PATH: infection.nsubj-result.ROOT-loss.nmod-focal.amod	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection.nsubj-result.ROOT-loss.nmod-focal.amod	LINEAR: Infection of the brain with the JHM strain of MHV ( JHMV ) results in focal	COUNT: 2
# PATH: infection.nsubj-cause.ROOT	LINEAR: infection of mice can cause	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-can.aux	LINEAR: infection can	COUNT: 2
# PATH: virus.nsubj-induce.ROOT-inflammation.dobj	LINEAR: virus , like MHV-3 infection in mice , can induce exaggerated inflammation	COUNT: 1
# PATH: MERS-CoV.nsubj-induce.ROOT-pneumonia.dobj	LINEAR: MERS-CoV induces acute pneumonia	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-immunosuppression.dobj-progressive.amod	LINEAR: infection causes progressive	COUNT: 1
# PATH: infection.nsubj-cause.ROOT-encephalitis.dobj-disorder.nmod-severe.amod	LINEAR: infection can cause Japanese encephalitis ( JE ) with severe	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	infected arg1:patients $usually $develop <>arg2:[entity]respiratory illness.
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: Infection with PEDV is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: Infection is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 7
# PATH: infection.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: infection is	COUNT: 7
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients who have pneumonic plague typically develop fulminant pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients rapidly develop pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: Patients with severe cases usually develop pneumonia	COUNT: 4
# PATH: patient.nsubj-develop.ROOT-pneumonia.dobj	LINEAR: patients with BCC develop a life-threatening , sometimes necrotizing , pneumonia	COUNT: 4
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: rabbit.nsubj-develop.ccomp-sepsis.dobj	LINEAR: rabbits usually develop sepsis	COUNT: 3
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: Clinical signs of CPV-2 infection	COUNT: 3
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: Clinical signs in human infections	COUNT: 3
# PATH: infection.nmod-sign.nsubj-clinical.amod	LINEAR: clinical signs of respiratory infection	COUNT: 3
# PATH: patient.nsubj-present.ROOT-symptom.nmod	LINEAR: patients infected with SARS-CoV often present with symptoms	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-fever.dobj	LINEAR: patients develop rapid onset fever	COUNT: 2
# PATH: human.nmod-infection.nsubj	LINEAR: Infection in humans	COUNT: 2
# PATH: disease.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: disease is	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-symptom.dobj	LINEAR: infection initially causes non-specific symptoms	COUNT: 2
# PATH: animal.nsubj-die.ROOT	LINEAR: animals usually die	COUNT: 2
# PATH: disease.ROOT-lead.conj-fever.nmod	LINEAR: disease , immature schistosomula pass through the lung and can lead to fever	COUNT: 2
# PATH: clinical.amod-manifestation.nsubj-evolve.ROOT-picture.nmod-septic.amod	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: clinical.amod-manifestation.nsubj-evolve.ROOT-picture.nmod-septic.amod	LINEAR: clinical manifestations of inhalational anthrax generally evolve to a fulminant septic	COUNT: 2
# PATH: infant.nsubj-have.ROOT-symptom.dobj	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: infant.nsubj-have.ROOT-symptom.dobj	LINEAR: Infants with myocarditis usually have symptoms	COUNT: 2
# PATH: animal.nsubj-die.ROOT	LINEAR: animals usually die	COUNT: 2
# PATH: patient.nsubj-present.ROOT-symptom.nmod	LINEAR: Patients with severe MERS often present with pneumonic symptoms	COUNT: 2
# PATH: host.nsubj-develop.ROOT-diarrhea.dobj	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: host.nsubj-develop.ROOT-diarrhea.dobj	LINEAR: hosts usually develop self-limiting diarrhea	COUNT: 2
# PATH: sepsis.nmod-sign.dobj-clinical.amod	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: sepsis.nmod-sign.dobj-clinical.amod	LINEAR: clinical signs of sepsis	COUNT: 2
# PATH: human.nmod-infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: humans typically causes an influenza-like syndrome	COUNT: 2
# PATH: human.nmod-disease.dobj	LINEAR: disease in humans	COUNT: 2
# PATH: human.nmod-disease.dobj	LINEAR: disease in humans	COUNT: 2
# PATH: human.nmod-infection.nsubj-cause.ROOT-syndrome.dobj	LINEAR: humans with SARS-CoV typically causes an influenza-like syndrome	COUNT: 2
# PATH: patient.nsubj-infection.nmod	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: human.nmod-infection.nsubj	LINEAR: Infection in humans	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-fever.dobj	LINEAR: patients develop fever	COUNT: 2
# PATH: disease.nsubjpass-characterize.ROOT-be.auxpass	LINEAR: disease in neonatal kids is	COUNT: 2
# PATH: patient.nsubj-infection.nmod	LINEAR: Patients with symptomatic EPEC infection	COUNT: 2
# PATH: be.cop-severe.ROOT-infection.nsubj	LINEAR: infection is	COUNT: 2
# PATH: mouse.conj-suckle.nmod-growth.nmod-characterize.ROOT-infection.nsubjpass	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: mouse.conj-suckle.nmod-growth.nmod-characterize.ROOT-infection.nsubjpass	LINEAR: infection is characterized by retarded growth , ruffled fur , soft feces or diarrhea , rectal prolapse , and moderate mortality in older suckling or recently weaned mice	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: infection.nsubj-cause.ROOT-symptom.dobj	LINEAR: infection usually causes mild symptoms	COUNT: 2
# PATH: disease.ROOT-lead.conj-fever.nmod	LINEAR: disease , immature schistosomula pass through the lung , and can lead to fever	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	a arg1:subset of patients $progress to arg2:hemorrhagic fever
#
# MOST FREQUENT PATTERNS:
#
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: Severe pediatric cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: Severe cases	COUNT: 8
# PATH: case.nsubj-severe.amod	LINEAR: severe cases	COUNT: 8
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: patient.nsubj-severe.amod	LINEAR: Severe patients	COUNT: 6
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-cause.ROOT-pneumonia.dobj	LINEAR: cases , infection can cause pneumonia	COUNT: 5
# PATH: case.nmod-severe.amod	LINEAR: severe cases	COUNT: 4
# PATH: case.nmod-severe.amod	LINEAR: severe cases	COUNT: 4
# PATH: case.nmod-severe.amod	LINEAR: severe cases	COUNT: 4
# PATH: case.nmod-severe.amod	LINEAR: severe cases	COUNT: 4
# PATH: pneumonia.nsubj-severe.amod	LINEAR: Severe pneumonia	COUNT: 3
# PATH: pneumonia.nsubj-severe.amod	LINEAR: Severe pneumonia	COUNT: 3
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 3
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 3
# PATH: pneumonia.nsubj-severe.amod	LINEAR: Severe pneumonia	COUNT: 3
# PATH: disease.nmod-severe.amod	LINEAR: severe disease	COUNT: 3
# PATH: disease.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , the disease	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-subset.nmod-case.nmod-severe.amod	LINEAR: severe cases , the disease	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-subset.nmod-case.nmod-severe.amod	LINEAR: severe cases , the disease	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: patient.conj-clinic.ROOT-progress.conj-disease.nsubj	LINEAR: patients most commonly present with fever , cough and dyspnea , and from there the disease	COUNT: 2
# PATH: -PRON-.nsubj-progress.ROOT-case.nmod-severe.amod	LINEAR: severe cases , it	COUNT: 2
# PATH: pneumonia.nsubj-develop.ROOT-progress.conj-failure.nmod-respiratory.amod	LINEAR: Pneumonia develops with primary infection , occurs rarely in children , and progresses to respiratory	COUNT: 2
# PATH: patient.nsubj-develop.ROOT-disease.dobj-severe.amod	LINEAR: patients may develop severe	COUNT: 2
# PATH: disease.nsubj-progress.advcl-pneumonia.nmod-viral.amod	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease.nsubj-progress.advcl-pneumonia.nmod-viral.amod	LINEAR: disease progresses to viral	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-result.conj-failure.nmod-cardiac.amod	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: disease.nsubj-progress.ROOT-result.conj-failure.nmod-cardiac.amod	LINEAR: disease progresses very slowly , but can result in cardiac	COUNT: 2
# PATH: pneumonia.nmod-those.appos-infection.nmod-severe.amod	LINEAR: pneumonia , especially those due to rapid-onset severe	COUNT: 2
# PATH: pneumonia.nmod-those.appos-infection.nmod-severe.amod	LINEAR: pneumonia , especially those due to rapid-onset severe	COUNT: 2
# PATH: Disease.nsubj-progress.ROOT-syndrome.nmod-acute.amod	LINEAR: Disease can progress to acute	COUNT: 2
# PATH: Disease.nsubj-progress.ROOT-syndrome.nmod-acute.amod	LINEAR: Disease can progress to acute	COUNT: 2
# PATH: patient.nsubj-infection.nmod-severe.amod	LINEAR: patients with severe	COUNT: 2
# PATH: pneumonia.nsubj-develop.ROOT-progress.conj-failure.nmod-respiratory.amod	LINEAR: Pneumonia develops rapidly and eventually progresses after 2 to 4 days into respiratory	COUNT: 2
# PATH: patient.nsubj-infection.nmod-severe.amod	LINEAR: Patients with severe	COUNT: 2
# PATH: case.nsubj-develop.ROOT-edema.dobj-pulmonary.amod	LINEAR: cases often develop refractory pulmonary	COUNT: 2
# PATH: case.nsubj-develop.ROOT-edema.dobj-pulmonary.amod	LINEAR: cases often develop refractory pulmonary	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	people with arg1:[e]asthma are $susceptible to arg2:[e]asthma
#
# MOST FREQUENT PATTERNS:
#
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: copd.nmod-subject.conj-exacerbation.dobj-trigger.xcomp-know.ROOT-infection.nsubjpass	LINEAR: Infection with RV is known to trigger acute exacerbations and subjects with COPD	COUNT: 14
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are highly susceptible to infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are highly susceptible to infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to the infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are generally more susceptible to infections	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer may be as susceptible to active Mycobacterium tuberculous infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 8
# PATH: cancer.nmod-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 8
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infection	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infections	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients with iatrogenic or disease related immune suppression are highly susceptible to infection	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients who are immunocompromised such as due to steroids or organ and hematopoietic stem cell transplantation are highly susceptible to atypical viral infections	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are more susceptible to infection	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: patients are also susceptible to nosocomial viral infections	COUNT: 7
# PATH: patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Patients with hematologic malignancies , especially in the neutropenic state after aggressive chemotherapy or HSCT and HSCT recipients with GVHD , are particularly susceptible to invasive fungal infections	COUNT: 7
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients , particularly those under anticancer treatment , are potentially more susceptible for a severe infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients and immunocompromised hosts are particularly susceptible to lung infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are more susceptible to infections	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: cancer patients are more susceptible to infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are potentially more susceptible to Coronavirus infection	COUNT: 6
# PATH: cancer.compound-patient.nsubj-susceptible.ROOT-infection.nmod	LINEAR: Cancer patients are more susceptible to infections	COUNT: 6
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with liver cirrhosis or liver cancer are at high risk of SARS-CoV-2 infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with defective cell-mediated immunity are at risk of infections	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with primary adrenal insufficiency including Addison 's disease and congenital adrenal hyperplasia are at an increased risk of infections	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: Patients with prolonged neutropenia who have received intensive cytotoxic chemotherapy are at risk for invasive fungal infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-infection.nmod	LINEAR: patients , especially those with neutropenia , are at increased risk of infection	COUNT: 5
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients , including those with HIV/AIDS and patients taking immunosuppressants post-transplant , are at an increased risk for viral and fungal pneumonia	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: Patients with immunodeficiency syndromes are also at risk of pneumonia	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients with associated CD4 + cell depletion not receiving appropriate prophylaxis are at high risk for Pneumocystis jiroveci pneumonia	COUNT: 4
# PATH: patient.nsubj-risk.ROOT-pneumonia.nmod	LINEAR: patients with a single LT may be at greater risk of pneumonia	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# PATH: cancer.nmod-patient.nsubj-susceptible.ccomp-infection.nmod	LINEAR: cancer are more susceptible to infection	COUNT: 4
# PATH: patient.nsubj-prone.ROOT-infection.nmod	LINEAR: patients are also more prone to RSV infections	COUNT: 3
# PATH: ds.nmod-patient.nsubj-susceptible.ROOT-lower.nmod-infection.dep	LINEAR: DS are highly susceptible to lower and higher respiratory tract infection	COUNT: 3
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	arg1:[e]paracetamol is $not useful for treating arg2:[e]asthma.
#
# MOST FREQUENT PATTERNS:
#
# PATH: corticosteroid.nsubj-increase.ROOT-influenza.nmod-infection.conj	LINEAR: corticosteroids may increase the risk of mortality and morbidity ( e.g. secondary infections ) in severe influenza and other viral infections	COUNT: 2
# PATH: corticosteroid.nsubj-increase.ROOT-influenza.nmod-infection.conj	LINEAR: corticosteroids may increase the risk of mortality and morbidity ( e.g. secondary infections ) in severe influenza and other viral infections	COUNT: 2
# PATH: ribavirin.nsubjpass-consider.ccomp-management.nmod-case.nmod-severe.amod	LINEAR: ribavirin and IgIV can be considered for the management of severe	COUNT: 2
# PATH: ribavirin.nsubj-effective.ROOT-virus.nmod-sars.compound	LINEAR: ribavirin is only marginally effective against the SARS	COUNT: 2
# PATH: antiviral.amod-option.nsubjpass-limited.ROOT-be.advcl-prove.conj-effective.xcomp-occur.advcl-disease.nsubj	LINEAR: antiviral treatment options are limited because no parenteral drug is available and no drug has been proved to be effective once life-threatening disease	COUNT: 2
# PATH: antiviral.amod-option.nsubjpass-limited.ROOT-be.advcl-prove.conj-effective.xcomp-occur.advcl-disease.nsubj	LINEAR: antiviral treatment options are limited because no parenteral drug is available and no drug has been proved to be effective once life-threatening disease	COUNT: 2
# PATH: ribavirin.conj-cidofovir.nmod-agent.nmod	LINEAR: agents ( such as cidofovir , foscarnet , and ribavirin	COUNT: 2
# PATH: ribavirin.conj-cidofovir.nmod-agent.nmod	LINEAR: agents ( such as cidofovir , foscarnet , and ribavirin	COUNT: 2
# PATH: ribavirin.nsubj-effective.ROOT-virus.nmod-sars.compound	LINEAR: ribavirin is only marginally effective against the SARS	COUNT: 2
# PATH: of.case-therapy.nmod-efficacy.conj-effect.nmod-compromise.ROOT-treatment.nsubjpass-infection.nmod	LINEAR: infection after liver transplantation is often compromised by enhanced adverse effects and limited efficacy of	COUNT: 2
# PATH: ribavirin.nsubjpass-consider.ccomp-management.nmod-case.nmod-severe.amod	LINEAR: ribavirin with or without immunoglobulin can be considered for the management of severe	COUNT: 2
# PATH: corticosteroid.compound-therapy.nsubj-sufficient.ccomp-think.ROOT-disease.nmod	LINEAR: disease , it is increasingly thought that corticosteroid	COUNT: 2
# PATH: corticosteroid.compound-therapy.nsubj-sufficient.ccomp-think.ROOT-disease.nmod	LINEAR: disease , it is increasingly thought that corticosteroid	COUNT: 2
# PATH: of.case-therapy.nmod-efficacy.conj-effect.nmod-compromise.ROOT-treatment.nsubjpass-infection.nmod	LINEAR: infection after LT is compromised by enhanced adverse effects and limited efficacy of	COUNT: 2
# PATH: corticosteroid.compound-therapy.nsubj-effective.ROOT-%.nmod-form.nmod-ttp.nmod	LINEAR: corticosteroid therapy is effective in 56 % of purely hematological forms of TTP	COUNT: 2
# PATH: corticosteroid.compound-therapy.nsubj-effective.ROOT-%.nmod-form.nmod-ttp.nmod	LINEAR: corticosteroid therapy is effective in 56 % of purely hematological forms of TTP	COUNT: 2
# PATH: antiviral.nsubj-have.ROOT-induce.conj-rejection.dobj-organ.compound	LINEAR: Antivirals themselves have significant side effects , and their use may induce organ	COUNT: 2
# PATH: antiviral.nsubj-have.ROOT-induce.conj-rejection.dobj-organ.compound	LINEAR: Antivirals themselves have significant side effects , and their use may induce organ	COUNT: 2
# PATH: -PRON-.nsubj-be.ROOT-agent.nsubj-patient.nmod-active.nmod-tuberculosis.dep	LINEAR: it is not an appropriate agent in patients with active or latent tuberculosis	COUNT: 1
# PATH: steroid.nsubj-sufficient.acl:relcl-suppress.advcl-inflammation.dobj	LINEAR: steroids alone are not sufficient for suppressing inflammation	COUNT: 1
# PATH: ribavirin.nsubj-useful.ROOT-treat.advcl-infection.dobj-sars.compound	LINEAR: ribavirin may not be useful for treating SARS	COUNT: 1
# PATH: therapy.nsubjpass-recommend.ROOT-treatment.nmod-sars-cov-2.nmod-of.case	LINEAR: therapy is not recommended in the clinical treatment of	COUNT: 1
# PATH: steroid.nsubjpass-recommend.ROOT-infection.nmod	LINEAR: steroids are not recommended in COVID-19 infection	COUNT: 1
# PATH: corticosteroid.nsubj-fail.conj-die.ROOT-patient.nsubj	LINEAR: Patients with PCP typically die due to refractory hypoxemia from severe respiratory failure , and corticosteroids	COUNT: 1
# PATH: steroid.nsubj-effective.ROOT-treatment.nmod-infection.nmod	LINEAR: steroids are not effective for the treatment of lung injury or shock in adults ' SARS-CoV-2 infection	COUNT: 1
# PATH: corticosteroid.nsubjpass-recommend.ccomp-delay.ROOT-clearance.dobj-virus.compound	LINEAR: Corticosteroids in the treatment of SARS-CoV-2 pneumonia are not usually recommended ; they may delay virus	COUNT: 1
# PATH: ribavirin.nsubj-available.conj-infection.nmod	LINEAR: ribavirin is available for CVB3 infection	COUNT: 1
# PATH: drug.nsubj-license.ROOT-treatment.nmod-infection.nmod-cmv.compound	LINEAR: Drugs currently licensed for the treatment of systemic CMV	COUNT: 1
# PATH: agent.pobj-of.prep-Most.nsubj-effective.ROOT-use.conj-progression.nmod-disease.nmod	LINEAR: agents are mildly effective and slow-acting , and therefore , should not be used as the only treatment modality due to the rapid progression of disease	COUNT: 1
# PATH: antiviral.nsubj-have.ROOT-case.nmod-infection.nmod-influenza.compound	LINEAR: antivirals such as NA inhibitors and M2 blockers have limited efficacy in severe cases of influenza	COUNT: 1
# PATH: treatment.nsubj-ineffective.conj-be.ROOT-low.acomp-in.prep-child.pobj	LINEAR: children , and the treatment	COUNT: 1
# PATH: corticosteroid.nmod-use.nsubj-cause.ROOT-suppression.dobj-host.compound	LINEAR: corticosteroids in the treatment of COVID-19 can cause host	COUNT: 1
# PATH: interferon.nmod-use.nsubj-treat.acl-dengue.dobj	LINEAR: interferon to treat dengue	COUNT: 1
# PATH: ribavirin.conj-trial.nmod-observe.ROOT-consider.conj-be.xcomp-drug.attr-of.prep-choice.pobj-for.prep-influenza.pobj	LINEAR: ribavirin is currently not considered to be a drug of choice for influenza	COUNT: 1
# PATH: aciclovir.compound-monotherapy.nmod-efficacy.nsubjpass-hamper.ROOT-encephalitis.nmod	LINEAR: encephalitis , the efficacy of aciclovir	COUNT: 1
# PATH: acyclovir.nsubj-have.advcl-efficacy.dobj-prevent.acl-disease.dobj	LINEAR: acyclovir has had certain efficacy for preventing CMV disease	COUNT: 1
# PATH: fam.nsubj-therapy.advcl-argue.ROOT-use.advcl-prophylaxis.nmod-survival.nmod	LINEAR: FAM is standard therapy for established BOS , recent data argue strongly against using azithromycin as prophylaxis against BOS due to decreased survival	COUNT: 1
# PATH: drug.nsubj-have.ROOT-available.advcl-infection.nmod-influenza.compound	LINEAR: influenza infections ( e.g. , M2 and neuraminidase inhibitors ) , these drugs	COUNT: 1
# PATH: treatment.nsubjpass-limit.ROOT-response.nmod-therapy.nmod-suppression.nmod-immune.amod	LINEAR: treatment is frequently limited by insufficient response to therapy or side effects of immune	COUNT: 1
# PATH: ribavirin.nsubj-demonstrate.advcl-be.ROOT-treatment.nsubj-cchf.nmod	LINEAR: CCHF , though ribavirin	COUNT: 1
# PATH: biologic.amod-therapy.nsubj-provide.advcl-option.dobj-UC.nmod	LINEAR: biologic therapies provide a valuable treatment option in UC	COUNT: 1
# PATH: ribavirin.appos-therapy.nsubjpass-use.conj-be.ROOT-vaccine.nsubj-prevent.acl-rsv.dobj	LINEAR: RSV , and the only accepted therapy ( ribavirin	COUNT: 1
# PATH: treatment.nsubjpass-use.ROOT-resistance.nmod-association.appos-shedding.nmod-virus.nmod	LINEAR: Treatment with M2 inhibitors , such as amantadine , is generally not used in transplant recipients because of widespread resistance , the association with prolonged shedding of virus	COUNT: 1
# PATH: zanamivir.nsubj-induce.ROOT-be.ccomp-benefit.attr-prove.acl-treatment.nmod	LINEAR: treatment outside of these specific circumstances , as it comes at a cost and may be associated with side effects ; for example , zanamivir	COUNT: 1
# PATH: antiviral.amod-therapy.nsubj-specific.amod	LINEAR: Specific antiviral	COUNT: 1
# PATH: corticosteroid.nsubj-be.ROOT-choice.attr-patient.nmod-infection.nmod	LINEAR: corticosteroids may not be a standard choice in patients with influenza A infection	COUNT: 1
# PATH: be.auxpass-contraindicate.ccomp-cirrhosis.nmod	LINEAR: is contraindicated in advanced cirrhosis	COUNT: 1
# PATH: ribavirin.nsubj-induce.ROOT-effective.advcl-c.nmod-hepatitis.compound	LINEAR: hepatitis C , ribavirin	COUNT: 1
# PATH: cidofovir.nsubj-remain.ROOT-treatment.attr-death.nmod-report.acl-secondary.xcomp-infection.nmod	LINEAR: cidofovir remains an imperfect treatment , with deaths reported secondary to disseminated adenoviral infection	COUNT: 1
# PATH: agent.nsubj-have.ROOT-efficacy.dobj-pneumonia.nmod-bacterial.amod	LINEAR: agents have limited efficacy in advanced bacterial	COUNT: 1
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	arg1:[e]stroke is a $complication of :[e]COVID-19 arg2:infection
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nmod-patient.nsubj	LINEAR: Patients with severe COVID-19 infection	COUNT: 5
# PATH: infection.nsubj-complication.ROOT-patient.nmod	LINEAR: Infection is a common complication in patients	COUNT: 5
# PATH: infection.nsubj-complication.ROOT-patient.nmod	LINEAR: infection is a known complication among critically ill patients	COUNT: 5
# PATH: infection.nmod-patient.nsubj	LINEAR: Patients with invasive GAS infection	COUNT: 5
# PATH: infection.nsubj-complication.ROOT-patient.nmod	LINEAR: infection ( varicella ) is an uncommon but severe complication in SCT patients	COUNT: 5
# PATH: infection.nsubj-complication.ROOT-patient.nmod	LINEAR: infection is a common complication in ICU patients	COUNT: 5
# PATH: disease.ROOT-be.cop	LINEAR: is a novel respiratory disease	COUNT: 5
# PATH: disease.ROOT-be.cop	LINEAR: is a novel respiratory disease	COUNT: 5
# PATH: infection.nmod-patient.nsubj	LINEAR: Patients with COVID-19 infection	COUNT: 5
# PATH: infection.nmod-patient.nsubj	LINEAR: Patients with COVID-19 infection	COUNT: 5
# PATH: infection.nmod-patient.nsubj	LINEAR: patients with COVID-19 infection	COUNT: 5
# PATH: disease.ROOT-be.cop	LINEAR: is a highly contagious disease	COUNT: 5
# PATH: infection.nsubj-complication.ROOT-patient.nmod	LINEAR: infection is the most frequent infectious complication in lung transplant patients	COUNT: 5
# PATH: disease.ROOT-be.cop	LINEAR: is an infectious disease	COUNT: 5
# PATH: disease.ROOT-be.cop	LINEAR: is an acute infectious disease	COUNT: 5
# PATH: death.nmod-patient.nmod	LINEAR: death in patients	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is	COUNT: 3
# PATH: injury.nsubj-be.ROOT-condition.attr-patient.nmod	LINEAR: injury is a common condition among the hospitalized patients	COUNT: 3
# PATH: be.cop-complication.ROOT-patient.nmod	LINEAR: is a complication in critically ill patients	COUNT: 3
# PATH: be.cop-complication.ROOT-patient.nmod	LINEAR: is a complication in critically ill patients	COUNT: 3
# PATH: infection.ROOT-be.cop	LINEAR: is a respiratory infection	COUNT: 3
# PATH: pneumonia.nsubj-be.ROOT-complication.attr-patient.nmod	LINEAR: Pneumonia is the most common infectious complication in multiple trauma patients	COUNT: 3
# PATH: pneumonia.nsubj-be.ROOT-complication.attr-patient.nmod	LINEAR: Pneumonia is the most common infectious complication in multiple trauma patients	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-be.auxpass	LINEAR: infection is	COUNT: 3
# PATH: death.nmod-patient.nmod	LINEAR: death in patients	COUNT: 3
# PATH: death.nmod-patient.nmod	LINEAR: death in patients	COUNT: 3
# PATH: be.cop-complication.ROOT-patient.nmod	LINEAR: is a common complication of APSCT in patients	COUNT: 3
# PATH: pneumonia.nmod-patient.nmod	LINEAR: patients with COVID-19 pneumonia	COUNT: 3
# PATH: pneumonia.nmod-patient.nmod	LINEAR: patients with COVID-19 pneumonia	COUNT: 3
# PATH: pneumonia.nmod-patient.nmod	LINEAR: patients with communityacquired pneumonia	COUNT: 3
# PATH: infection.ROOT-be.cop	LINEAR: is a systemic infection	COUNT: 3
# PATH: pneumonia.nsubj-cause.ROOT-morbidity.nmod-patient.nmod	LINEAR: pneumonia is a major cause of morbidity and mortality in patients	COUNT: 3
# PATH: pneumonia.nsubj-cause.ROOT-morbidity.nmod-patient.nmod	LINEAR: pneumonia is a major cause of morbidity and mortality in patients	COUNT: 3
# PATH: injury.nsubj-be.ROOT-condition.attr-patient.nmod	LINEAR: injury is a common condition among the hospitalized patients	COUNT: 3
# PATH: injury.nsubj-be.ROOT-condition.attr-patient.nmod	LINEAR: injury is a common condition among the hospitalized patients	COUNT: 3
# PATH: pneumonia.nsubj-cause.ROOT-morbidity.nmod-patient.nmod	LINEAR: pneumonia is an important cause of morbidity and mortality in patients	COUNT: 3
# PATH: pneumonia.nsubj-be.ROOT-complication.attr-patient.nmod	LINEAR: Pneumonia is a frequent infectious complication in patients	COUNT: 3
# PATH: infection.ROOT-be.cop	LINEAR: is a respiratory infection	COUNT: 3
# PATH: AKI.nsubj-occur.ROOT-patient.nmod-disease.nmod	LINEAR: AKI occurs frequently among patients with Covid-19 disease	COUNT: 2
# PATH: AKI.nsubj-occur.ROOT-patient.nmod-disease.nmod	LINEAR: AKI occurs frequently among patients with Covid-19 disease	COUNT: 2
# PATH: disease.nmod-associate.acl-mortality.nmod-cause.nmod-one.ROOT-be.cop	LINEAR: is one of the major causes of mortality associated with COVID-19 disease	COUNT: 2
# PATH: disease.nmod-associate.acl-mortality.nmod-cause.nmod-one.ROOT-be.cop	LINEAR: is one of the major causes of mortality associated with COVID-19 disease	COUNT: 2
# PATH: be.cop-common.ROOT-patient.nmod	LINEAR: is common in patients	COUNT: 2
# PATH: be.cop-common.ROOT-patient.nmod	LINEAR: is common in patients	COUNT: 2
# PATH: pneumonia.nsubj-complication.ROOT-child.nmod	LINEAR: pneumonia is a common complication of VZV septicemia in children	COUNT: 2
# PATH: pneumonia.nsubj-complication.ROOT-child.nmod	LINEAR: pneumonia is a common complication of VZV septicemia in children	COUNT: 2
# PATH: bacterial.amod-superinfection.nsubj-complication.ROOT-infection.nmod	LINEAR: Bacterial superinfection is a common complication of viral lower respiratory tract infection	COUNT: 2
# PATH: pneumonia.nsubj-complication.ROOT-infection.nmod	LINEAR: pneumonia is a common complication of respiratory virus infection	COUNT: 2
# PATH: pneumonia.nsubjpass-severe.amod	LINEAR: severe COVID-19 pneumonia	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	the recommended arg1:[w]quarantine period is arg2:14 :[w]days
#
# MOST FREQUENT PATTERNS:
#
# PATH: quarantine.xcomp-for.prep-day.pobj-14.nummod	LINEAR: quarantined for 14	COUNT: 4
# PATH: quarantine.xcomp-for.prep-day.pobj-14.nummod	LINEAR: quarantined for 14	COUNT: 4
# PATH: quarantine.xcomp-for.prep-day.pobj-14.nummod	LINEAR: quarantined for 14	COUNT: 4
# PATH: vaccination.compound-protocol.nsubj-be.ROOT-administration.attr-single.amod	LINEAR: vaccination protocol in this situation would be a single	COUNT: 4
# PATH: vaccination.compound-protocol.nsubj-be.ROOT-administration.attr-single.amod	LINEAR: vaccination protocol in this situation would be a single	COUNT: 4
# PATH: vaccination.compound-protocol.nsubj-be.ROOT-administration.attr-single.amod	LINEAR: vaccination protocol in this situation would be a single	COUNT: 4
# PATH: vaccination.compound-protocol.nsubj-be.ROOT-administration.attr-single.amod	LINEAR: vaccination protocol in this situation would be a single	COUNT: 4
# PATH: quarantine.xcomp-for.prep-day.pobj-14.nummod	LINEAR: quarantine for 14	COUNT: 4
# PATH: quarantine.compound-period.dobj-a.det	LINEAR: a 22-day quarantine	COUNT: 3
# PATH: quarantine.compound-period.dobj-a.det	LINEAR: a 14-day quarantine	COUNT: 3
# PATH: be.auxpass-require.ROOT	LINEAR: are required	COUNT: 3
# PATH: be.auxpass-require.ROOT	LINEAR: are required	COUNT: 3
# PATH: be.auxpass-isolate.ROOT-week.nmod-3.nummod	LINEAR: be isolated for at least 3	COUNT: 3
# PATH: be.auxpass-isolate.ROOT-week.nmod-3.nummod	LINEAR: be isolated for at least 3	COUNT: 3
# PATH: be.auxpass-isolate.ROOT-week.nmod-3.nummod	LINEAR: be isolated for at least 3	COUNT: 3
# PATH: quarantine.compound-period.dobj-a.det	LINEAR: a week-long quarantine	COUNT: 3
# PATH: be.auxpass-require.ROOT	LINEAR: are required	COUNT: 3
# PATH: quarantine.ROOT-for.prep-day.pobj-30.nummod	LINEAR: quarantined for at least 30	COUNT: 3
# PATH: quarantine.ROOT-for.prep-day.pobj-30.nummod	LINEAR: quarantined for at least 30	COUNT: 3
# PATH: quarantine.ROOT-for.prep-day.pobj-30.nummod	LINEAR: quarantined for at least 30	COUNT: 3
# PATH: quarantine.compound-period.nsubjpass-extend.ROOT-week.npadvmod-three.nummod	LINEAR: quarantine period should be extended up to three	COUNT: 2
# PATH: quarantine.pobj-of.prep-length.nsubj-be.ccomp-day.attr-14.nummod	LINEAR: quarantine should be at least 14	COUNT: 2
# PATH: quarantine.pobj-of.prep-length.nsubj-be.ccomp-day.attr-14.nummod	LINEAR: quarantine should be at least 14	COUNT: 2
# PATH: quarantine.compound-period.nsubjpass-extend.ROOT-week.npadvmod-three.nummod	LINEAR: quarantine period should be extended up to three	COUNT: 2
# PATH: quarantine.compound-period.nsubj	LINEAR: quarantine period	COUNT: 2
# PATH: quarantine.compound-period.nsubj-be.ROOT-day.attr-30.nummod	LINEAR: quarantine period is typically 30	COUNT: 2
# PATH: quarantine.nsubjpass-a.det	LINEAR: a 14-day quarantine	COUNT: 2
# PATH: quarantine.compound-period.pobj	LINEAR: quarantine period	COUNT: 2
# PATH: quarantine.nsubj-a.det	LINEAR: A 14-day quarantine	COUNT: 2
# PATH: quarantine.pobj-of.prep-day.dobj-14.nummod	LINEAR: 14 days of centralized quarantine	COUNT: 2
# PATH: be.auxpass-suspend.ROOT-for.prep-day.pobj-21.nummod	LINEAR: be suspended for up to 21	COUNT: 2
# PATH: time.attr-be.acl:relcl-day.nmod-14.nummod	LINEAR: 14 days , which is the longest predicted incubation time	COUNT: 2
# PATH: quarantine.nsubj-a.det	LINEAR: A 14‐day quarantine	COUNT: 2
# PATH: quarantine.compound-period.dobj-prolong.xcomp-to.prep-week.pobj-three.nummod	LINEAR: quarantine period to three	COUNT: 2
# PATH: quarantine.ROOT-for.prep-day.pobj-14.nummod	LINEAR: quarantined for 14	COUNT: 2
# PATH: quarantine.compound-period.dobj-prolong.xcomp-to.prep-week.pobj-three.nummod	LINEAR: quarantine period to three	COUNT: 2
# PATH: time.attr-be.acl:relcl-day.nmod-14.nummod	LINEAR: 14 days , which is the longest predicted incubation time	COUNT: 2
# PATH: quarantine.pobj-of.prep-duration.dobj-approximate.ROOT-value.nsubj-these.det	LINEAR: These values approximate the duration of quarantine	COUNT: 2
# PATH: quarantine.pobj-of.prep-duration.dobj-approximate.ROOT-value.nsubj-these.det	LINEAR: These values approximate the duration of quarantine	COUNT: 2
# PATH: infection.compound-period.nsubj-be.conj-day.attr-4.nummod	LINEAR: infection period is 4	COUNT: 2
# PATH: infection.compound-period.nsubj-be.conj-day.attr-4.nummod	LINEAR: infection period is 4	COUNT: 2
# PATH: number.dobj-make.acl-order.pobj-in.prep-fall.ROOT-under.prep-hour.pobj-8.nummod-12.compound	LINEAR: 12 - 8 hours in order to make the reproduction number	COUNT: 2
# PATH: number.dobj-make.acl-order.pobj-in.prep-fall.ROOT-under.prep-hour.pobj-8.nummod-12.compound	LINEAR: 12 - 8 hours in order to make the reproduction number	COUNT: 2
# PATH: quarantine.nsubjpass-extend.ROOT-day.nmod-21.nummod	LINEAR: quarantine may be extended for up to 21	COUNT: 2
# PATH: quarantine.amod-period.dobj-of.prep-day.pobj-14.nummod	LINEAR: quarantine period of 14	COUNT: 2
# PATH: quarantine.nsubjpass-of.prep-day.pobj-14.nummod	LINEAR: quarantine of 14	COUNT: 2
# PATH: quarantine.amod-period.dobj-of.prep-day.pobj-9.nummod	LINEAR: quarantine period of 9	COUNT: 2
# PATH: transmission.nsubj-occur.ROOT-wait.parataxis-day.nsubjpass-62.nummod	LINEAR: transmission may still occur : if the surveillance sensitivity is only 40 % , then 62	COUNT: 2
# PATH: quarantine.compound-period.nsubj-be.ROOT-day.attr-30.nummod	LINEAR: Quarantine period for all felid species is typically 30	COUNT: 2
# PATH: quarantine.dobj-of.prep-day.pobj-14.nummod	LINEAR: quarantine of 14	COUNT: 2
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	arg1:[e]COVID-19 $infects arg2:cells
#
# MOST FREQUENT PATTERNS:
#
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects lung alveolar epithelial cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects ACE2positive cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects human epithelial cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 can infect cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects host cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects host cell	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-COV-2 infects human cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 mainly infects type II alveolar epithelial cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects host cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 primarily infects cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects human lung alveolar epithelial cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 may infect circulating immune cells	COUNT: 14
# PATH: sars-cov-2.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 infects mammalian cells	COUNT: 14
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters human cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters respiratory epithelial cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters human cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters the cell	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-Cov-2 enters the cell	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-Cov-2 enters the cell	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters the pulmonary cells	COUNT: 11
# PATH: sars-cov-2.nsubj-enter.ROOT-cell.dobj	LINEAR: SARS-CoV-2 enters cells	COUNT: 11
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 invades target cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 invades cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 mainly invades alveolar epithelial cells	COUNT: 7
# PATH: sars-cov-2.nsubj-invade.ROOT-cell.dobj	LINEAR: SARS-CoV-2 invades host cells	COUNT: 7
# PATH: sars-cov-2.nsubj-infect.ccomp-cell.dobj	LINEAR: SARS-CoV-2 infects cells	COUNT: 3
# PATH: mers-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: MERS-CoV infects cells	COUNT: 3
# PATH: mers-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: MERS-CoV infects unciliated bronchial epithelial cells	COUNT: 3
# PATH: sars-cov-2.appos-coronavirus.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 3
# PATH: sars-cov-2.appos-coronavirus.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 3
# PATH: sars-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV infects human host cells	COUNT: 3
# PATH: sars-cov-2.nsubj-infect.ccomp-cell.dobj	LINEAR: SARS-CoV-2 infects immune cells	COUNT: 3
# PATH: sars-cov-2.nsubj-infect.ccomp-cell.dobj	LINEAR: SARS-CoV-2 infects host cells	COUNT: 3
# PATH: sars-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV infects epithelial cells	COUNT: 3
# PATH: sars-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV primarily infects epithelial cells	COUNT: 3
# PATH: sars-cov-2.nsubj-enter.ROOT-infect.conj-cell.dobj	LINEAR: SARS-CoV-2 enter and infect target host cells	COUNT: 3
# PATH: sars-cov2.nsubj-protein.nsubjpass-report.ROOT-form.xcomp-channel.dobj-associate.acl:relcl-pathogenesis.nmod	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: sars-cov2.nsubj-protein.nsubjpass-report.ROOT-form.xcomp-channel.dobj-associate.acl:relcl-pathogenesis.nmod	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: sars-cov2.nsubj-protein.nsubjpass-report.ROOT-form.xcomp-channel.dobj-associate.acl:relcl-pathogenesis.nmod	LINEAR: SARS-CoV2 is an enveloped virus and E proteins present in them are reported to form ion channels , which is mainly associated with pathogenesis	COUNT: 3
# PATH: sars-cov-2.appos-coronavirus.nsubj-infect.ROOT-cell.dobj	LINEAR: SARS-CoV-2 ) infects host cells	COUNT: 3
# PATH: sars-cov-2.nsubj-enter.ROOT-infect.conj-cell.dobj	LINEAR: SARS-CoV-2 enters into and infects host cells	COUNT: 3
# PATH: sars-cov-2.nsubj-enter.ROOT-infect.conj-cell.dobj	LINEAR: SARS-CoV-2 enters into and infects host cells	COUNT: 3
# PATH: mers-cov.nsubj-infect.ROOT-cell.dobj	LINEAR: MERS-CoV infects unciliated bronchial epithelial cells	COUNT: 3
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	arg1:[e]COVID-19 activates the arg2:ATP $receptor
#
# MOST FREQUENT PATTERNS:
#
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: 2.nummod-enzyme.dobj-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 15
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 and SARS-CoV use angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 also uses human angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 and SARS-CoV use the angiotensin converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme II ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin-converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses angiotensin converting enzyme 2 ( ACE2	COUNT: 10
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 might also use ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 also uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 also uses both ACE2	COUNT: 8
# PATH: sars-cov-2.nsubj-use.ccomp-ace2.dobj	LINEAR: SARS-CoV-2 uses the SARS-CoV receptor ACE2	COUNT: 8
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: ace2.compound-receptor.nmod	LINEAR: ACE2 receptor	COUNT: 4
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , like SARS-CoV , uses the same receptor angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 , like SARS-CoV ( Li et al. , 2003 ) , uses the angiotensin converting enzyme 2 ( ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 uses the angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 can use ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 also uses the ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-receptor.dobj-ace2.compound	LINEAR: SARS-CoV-2 use the ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ccomp-enzyme.dobj-ace2.appos	LINEAR: SARS-CoV-2 may use angiotensin-converting enzyme 2 ( ACE2	COUNT: 3
# PATH: 2.nummod-receptor.dobj-ace2.compound	LINEAR: 2 ( ACE2	COUNT: 3
# PATH: sars-cov-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses receptor ACE2	COUNT: 3
# PATH: SARS-CoV-2.nsubj-use.ROOT-ace2.dobj	LINEAR: SARS-CoV-2 uses the ACE2	COUNT: 3
# PATH: 2.nummod-receptor.dobj-ace2.compound	LINEAR: 2 ( ACE2	COUNT: 3
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 3
# PATH: 2.nummod-enzyme.appos-ace2.appos	LINEAR: 2 ( ACE2	COUNT: 3
#
#
#
# =================================================================
# =================================================================
# QUERY:
# 	low blood oxygen arg1:levels are a $risk factor in arg2:[e]COVID-19 infection
#
# MOST FREQUENT PATTERNS:
#
# PATH: infection.nmod-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 5
# PATH: infection.nmod-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 5
# PATH: infection.nmod-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 5
# PATH: infection.nmod-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 5
# PATH: infection.nmod-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 5
# PATH: pneumonia.dobj-develop.acl-infection.nmod-sars-cov-2.nmod	LINEAR: pneumonia after infection with SARS-COV-2	COUNT: 3
# PATH: patient.nsubj-risk.ccomp-covid-19.nmod	LINEAR: patients older than 66 years of age are at increased risk of COVID-19	COUNT: 3
# PATH: obesity.nsubj-represent.ROOT-risk.dobj-infection.nmod-covid-19.amod	LINEAR: Obesity represents a higher risk of severe COVID-19	COUNT: 3
# PATH: obesity.nsubj-represent.ROOT-risk.dobj-infection.nmod-covid-19.amod	LINEAR: Obesity represents a higher risk of severe COVID-19	COUNT: 3
# PATH: obesity.nsubj-represent.ROOT-risk.dobj-infection.nmod-covid-19.amod	LINEAR: Obesity represents a higher risk of severe COVID-19	COUNT: 3
# PATH: infection.nsubj-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: patient.nsubj-risk.ccomp-covid-19.nmod	LINEAR: patients in Italy and Spain with severe Vit D deficiency may be at higher risk of severe COVID-19	COUNT: 3
# PATH: patient.nmod-covid-19.amod	LINEAR: COVID-19 patients	COUNT: 3
# PATH: pneumonia.dobj-develop.acl-infection.nmod-sars-cov-2.nmod	LINEAR: pneumonia after infection with SARS-COV-2	COUNT: 3
# PATH: pneumonia.dobj-develop.acl-infection.nmod-sars-cov-2.nmod	LINEAR: pneumonia after infection with SARS-COV-2	COUNT: 3
# PATH: patient.nmod-covid-19.amod	LINEAR: COVID-19 patients	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-low.advcl-prevalence.nsubj-case.nmod-covid-19.amod	LINEAR: COVID-19 cases was low in current reports , COVID-19 infection	COUNT: 3
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 3
# PATH: infection.nsubj-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 3
# PATH: infection.nmod-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-low.advcl-prevalence.nsubj-case.nmod-covid-19.amod	LINEAR: COVID-19 cases is low , COVID-19 infection	COUNT: 3
# PATH: infection.nsubjpass-associate.ROOT-low.advcl-prevalence.nsubj-case.nmod-covid-19.amod	LINEAR: COVID-19 cases is low , COVID-19 infection	COUNT: 3
# PATH: patient.nsubj-risk.ccomp-covid-19.nmod	LINEAR: patients with a history of diabetes and hypertension are at increased risk of severe COVID-19	COUNT: 3
# PATH: infection.nsubj-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 3
# PATH: infection.nsubj-covid-19.amod	LINEAR: COVID-19 infection	COUNT: 3
# PATH: infection.nmod-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 3
# PATH: infection.nsubj-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: patient.nmod-covid-19.amod	LINEAR: COVID-19 patients	COUNT: 3
# PATH: infection.nsubj-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: infection.nmod-rsv.compound	LINEAR: RSV infection	COUNT: 3
# PATH: infection.nmod-sars-cov-2.compound	LINEAR: SARS-CoV-2 infection	COUNT: 3
# PATH: obesity.conj-age.nsubj-factor.ccomp-associate.acl-risk.nmod-death.nmod-patient.nmod-hospitalize.acl-covid-19.nmod	LINEAR: obesity and more advanced illness are factors associated to an increased risk of death among patients hospitalized with COVID-19	COUNT: 2
# PATH: obesity.conj-age.nsubj-factor.ccomp-associate.acl-risk.nmod-death.nmod-patient.nmod-hospitalize.acl-covid-19.nmod	LINEAR: obesity and more advanced illness are factors associated to an increased risk of death among patients hospitalized with COVID-19	COUNT: 2
# PATH: patient.nsubj-have.ccomp-susceptible.conj-infection.nmod-sars-cov-2.compound	LINEAR: patients with pulmonary fibrosis , heart failure , and virus infection have a higher risk and are more susceptible to SARS-CoV-2	COUNT: 2
# PATH: patient.nsubj-have.ccomp-susceptible.conj-infection.nmod-sars-cov-2.compound	LINEAR: patients with pulmonary fibrosis , heart failure , and virus infection have a higher risk and are more susceptible to SARS-CoV-2	COUNT: 2
# PATH: disease.nsubj-appear.ROOT-risk.xcomp-form.nmod-covid-19.nmod	LINEAR: diseases including lung disease , cardiovascular disease , and immunosuppression appear to be at higher risk for severe forms of the COVID-19	COUNT: 2
# PATH: disease.nsubj-appear.ROOT-risk.xcomp-form.nmod-covid-19.nmod	LINEAR: diseases including lung disease , cardiovascular disease , and immunosuppression appear to be at higher risk for severe forms of the COVID-19	COUNT: 2
# PATH: pneumonia.nmod-covid-19.amod	LINEAR: COVID-19 pneumonia	COUNT: 2
# PATH: infection.nsubj-covid-19.compound	LINEAR: COVID-19 infection	COUNT: 2
# PATH: age.nsubj-factor.ccomp-death.nmod-patient.nmod-covid-19.nmod	LINEAR: age and an elevated NLR were high risk factors for death in patients with COVID-19	COUNT: 2
# PATH: disease.nmod-covid-19.amod	LINEAR: COVID-19 disease	COUNT: 2
# PATH: clinical.amod-outcome.nmod-associate.conj-be.ROOT-hadv-55.nsubj	LINEAR: HAdV-55 was the most prevalent type and might be associated with severe clinical	COUNT: 2
# PATH: clinical.amod-outcome.nmod-associate.conj-be.ROOT-hadv-55.nsubj	LINEAR: HAdV-55 was the most prevalent type and might be associated with severe clinical	COUNT: 2
# PATH: patient.nsubj-covid-19.nmod	LINEAR: patients with severe COVID-19	COUNT: 2
# PATH: infection.nmod-covid-19.compound	LINEAR: COVID-19 infection	COUNT: 2
# PATH: liver.compound-injury.nsubjpass-associate.ccomp-outcome.nmod-patient.nmod-infection.nmod-covid-19.amod	LINEAR: liver injury is associated with severe outcomes in patients with COVID-19	COUNT: 2
# PATH: liver.compound-injury.nsubjpass-associate.ccomp-outcome.nmod-patient.nmod-infection.nmod-covid-19.amod	LINEAR: liver injury is associated with severe outcomes in patients with COVID-19	COUNT: 2
# PATH: inflammation.conj-injury.nsubj-association.ROOT-patient.nmod-hospitalize.acl-covid-19.nmod	LINEAR: inflammation is a relatively common association among patients hospitalized with COVID-19	COUNT: 2
# PATH: inflammation.conj-injury.nsubj-association.ROOT-patient.nmod-hospitalize.acl-covid-19.nmod	LINEAR: inflammation is a relatively common association among patients hospitalized with COVID-19	COUNT: 2
#
#
#
# =================================================================
# =================================================================
