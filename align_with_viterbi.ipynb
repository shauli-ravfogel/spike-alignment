# %%
# %load_ext autoreload
# %autoreload 2
import bert
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import spike_queries
from termcolor import colored
import random
from collections import Counter, defaultdict
from viterbi_trellis import ViterbiTrellis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
def load_results(fname):
    
    with open(fname, "r", encoding = "utf-8") as f:
        sents = f.readlines()
    
    sents = [s.strip().split("\t")[-1] for s in sents]
    original, results = sents[0], sents[1:]
    return original, results


def get_spike_results_arguments_representations(model, spike_results, layers):
    
    sents = spike_results["sentence_text"].tolist()
    arg1_idx_start = spike_results["arg1_first_index"].to_numpy().astype(int)
    arg2_idx_start = spike_results["arg2_first_index"].to_numpy().astype(int)
    arg1_idx_end = spike_results["arg1_last_index"].to_numpy().astype(int)
    arg2_idx_end = spike_results["arg2_last_index"].to_numpy().astype(int)
    
    arg1_rep = []
    arg2_rep = []
    
    for s, arg1_start, arg2_start, arg1_end, arg2_end in zip(sents, arg1_idx_start, arg2_idx_start, arg1_idx_end, arg2_idx_end):
        #idx_to_mask = [arg1_start, arg2_start, arg1_end, arg2_end]
        H, _, _, orig2tok = model.encode(s, layers = layers)

        h1, h2 = H[orig2tok[arg1_start]:orig2tok[arg1_end] + 1], H[orig2tok[arg2_start]:orig2tok[arg2_end] + 1]
        
        h1 = np.mean(h1, axis = 0)
        h2 = np.mean(h2, axis = 0)
        
        arg1_rep.append(h1)
        arg2_rep.append(h2)
        
    arg1_mean = np.mean(arg1_rep, axis = 0)
    arg2_mean = np.mean(arg2_rep, axis = 0)
        
    return arg1_mean, arg2_mean
    

def print_sentence_nicely(sentence: str, ind1, ind2):
    
    arg1_sign = "**"
    arg2_sign = "++"
    arg1_color, arg2_color = "red", "blue"
    
    if not ind2 > ind1: 
        ind1, ind2 = ind2, ind1
        arg1_sign, arg2_sign = arg2_sign, arg1_sign
        arg1_color, arg2_color = arg2_color, arg1_color
        
    splitted = sentence.split(" ")
    before_arg1 = " ".join(splitted[:ind1])
    arg1 = splitted[ind1]
    arg2 = splitted[ind2]
    between = " ".join(splitted[ind1 + 1: ind2])
    suffix = " ".join(splitted[ind2+1:])
    
    return before_arg1 +  " " + arg1_sign + colored(arg1, arg1_color) + arg1_sign + " " + between + " " + arg2_sign + colored(arg2, arg2_color) + arg2_sign + " " + suffix



def main(filename, layers = [-1], num_results_to_print = 75):
    
    
    query, results1 = load_results(filename)
    spike_results = spike_queries.perform_query(query, dataset_name = "covid19", num_results = 100, query_type = "syntactic")
    spike_results = spike_results[spike_results['sentence_text'].notnull()]
    arg1_rep, arg2_rep = get_spike_results_arguments_representations(model, spike_results, layers)
    
    #print(color.BOLD + "QUERY" + color.END + ":\n{}".format(query))
    
    first, first_ind1, first_ind2 = spike_results["sentence_text"].tolist()[-1], int(spike_results["arg1_first_index"].tolist()[-1]), int(spike_results["arg2_first_index"].tolist()[-1])
    #print(color.BOLD + "\nFIRST SPIKE RESULT" + color.END + ":\n{}".format(print_sentence_nicely(first, first_ind1, first_ind2)))
    #print(color.BOLD + "\nAUGMENTATION RESULTS:\n" + color.END)
    
    representations = []
    mappings_to_orig = []
    mappings_to_tok = []
    tokenized_txts = []
    orig_sents = []
    
    for i,s in enumerate(results1):
        H, tokenized_text, tok_to_orig_map, orig2tok = model.encode(s, layers = layers)
        orig_sents.append(s)
        representations.append(H)
        mappings_to_orig.append(tok_to_orig_map)
        mappings_to_tok.append(orig2tok) 
        tokenized_txts.append(tokenized_text)
        
        if i > num_results_to_print: break
    
    return query, (arg1_rep, arg2_rep), (representations, mappings_to_orig, mappings_to_tok, tokenized_txts, orig_sents)


def get_between_tokens_similarity(padded_representations):
    
    num_sents, seq_len, bert_dim = padded_representations.shape
    padded_representations = padded_representations.reshape((num_sents*seq_len, bert_dim))
    sims = cosine_similarity(padded_representations, padded_representations)
    sims = sims.reshape((num_sents, seq_len, num_sents, seq_len))
    
    return sims

def get_between_token_similarity_prev_sentence(padded_representations):
    
    num_sents, seq_len, bert_dim = padded_representations.shape
    padded_representations = padded_representations.reshape((num_sents*seq_len, bert_dim))    
    padded_representations /= np.linalg.norm(padded_representations, keepdims = True, axis=1)
    padded_representations = padded_representations.reshape((num_sents, seq_len, bert_dim))
    tuples = list(zip(padded_representations, padded_representations[1:]))
    sims = np.array([tup[0].dot(tup[1].T) for tup in tuples])
    sims = sims.reshape(((num_sents-1)*seq_len, seq_len))
    return sims

def get_similarity_to_arguments(padded_representations, arg1, arg2):
    num_sents, seq_len, bert_dim = padded_representations.shape
    padded_representations = padded_representations.reshape((num_sents*seq_len, bert_dim))
    #print(padded_representations.shape)
    sims = cosine_similarity([arg1_rep, arg2_rep], padded_representations)
    sims = sims.reshape((2, num_sents, seq_len))
    return sims

# %%
model = bert.BertEncoder("cuda", "scibert")
# Out:
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/config.json from cache at /home/shauli/.cache/torch/transformers/199e28e62d2210c23d63625bd9eecc20cf72a156b29e2a540d4933af4f50bda1.4b6b9f5d813f7395e7ea533039e02deb1723d8fd9d8ba655391a01a69ad6223d
# Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 31090
# }
#
# Model name 'allenai/scibert_scivocab_uncased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'allenai/scibert_scivocab_uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/vocab.txt from cache at /home/shauli/.cache/torch/transformers/e3debd8fbdf40874753724814ee0520f612b577b26c8755bca485103b47cd3bc.60287becc5ab96d85a4bf377eb90feaf3b9c80d3b23e84311dccd3588f56d4fb
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/added_tokens.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/special_tokens_map.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/allenai/scibert_scivocab_uncased/tokenizer_config.json from cache at None
# loading weights file https://cdn.huggingface.co/allenai/scibert_scivocab_uncased/pytorch_model.bin from cache at /home/shauli/.cache/torch/transformers/54e18c298451d3195ba8359e7a3fa2bc04c70c730c5b6744928278e67940eacb.7587182ea55c40bf7fd0961c1176c31fa22558da2bf20c199874fa5a8ecb4613

# %%
from viterbi_trellis import ViterbiTrellis
grid = [[(i,j) for j in range(seq_len)] for i in range(num_sents)]
ARG_IND = 1

def state_score_func(sent_ind_tok_ind: tuple, alpha: float = 2,alpha2=1, arg_ind: int = ARG_IND):
    
    sent_ind, tok_ind = sent_ind_tok_ind
    return -alpha*sims_args[arg_ind][sent_ind][tok_ind] + alpha2*sims_args[1 if arg_ind==0 else 0][sent_ind][tok_ind]

def transition_score_func(sent_ind_tok_ind_source, sent_ind_tok_ind_dest):
    
    sent_ind_source, tok_ind_source = sent_ind_tok_ind_source
    sent_ind_dest, tok_ind_dest = sent_ind_tok_ind_dest
        
    return -sims_token[sent_ind_source,tok_ind_source,sent_ind_dest,tok_ind_dest]

def run_multiple_random_hmms(num_sents, n = 10):
    
    sent2captures = defaultdict(list)
    
    for i in range(n):
        
        ordering = list(range(num_sents))
        random.shuffle(ordering)
        grid_ordered = [x for _,x in sorted(zip(ordering,grid))]
        #print(grid_ordered[0][:6])

        new2orig = {i:grid_ordered[i][0][0] for i in range(len(grid_ordered))}
        
        v = ViterbiTrellis(grid_ordered, state_score_func, transition_score_func)
        best_path = v.viterbi_best_path()
        for j, token_ind in enumerate(best_path):
            
            sent_ind = new2orig[j]
            sent2captures[sent_ind].append(token_ind)
    
    return sent2captures

    for sentind in sent2captures.keys():
        counter = Counter(sent2captures[sentind])
        print(counter.most_common(2))

# %%
for q in range(1,10):
    
    # collect representations of arguments & results
    
    fname = "results{}.txt".format(q)
    query, (arg1_rep, arg2_rep), (representations, mappings_to_orig, mappings_to_tok, tokenized_txts, orig_sents)  = main(fname, layers = [-1])
    for i in range(len(representations)): # zero cls, ., sep
        representations[i][0][:] = np.random.rand()
        representations[i][-1][:] = np.random.rand()
        representations[i][-2][:] = np.random.rand()
    
    
    _, (arg1_rep0, arg2_rep0), (representations0, _, _, _, _)  = main(fname, layers = [0])
    for i in range(len(representations0)): # zero cls, ., sep
        representations0[i][0][:] = np.random.rand()
        representations0[i][-1][:] = np.random.rand()
        representations0[i][-2][:] = np.random.rand()
    
    # pad and collect similarit matrices
    
    pad_width = max([len(s) for s in representations])
    padded_representations = np.array([np.concatenate([r, -np.ones((pad_width-len(r), 768))]) for r in representations])
    padded_representations0 = np.array([np.concatenate([r, -np.ones((pad_width-len(r), 768))]) for r in representations0])

    num_sents, seq_len, bert_dim = padded_representations.shape
    num_tokens = num_sents * seq_len
    sims_token = get_between_tokens_similarity(padded_representations)
    sims_args = get_similarity_to_arguments(padded_representations, arg1_rep, arg2_rep)
    sims_token0 = get_between_tokens_similarity(padded_representations0)
        
    # run viterbi, naive
    
    grid = [[(i,j) for j in range(seq_len)] for i in range(num_sents)]
    v = ViterbiTrellis(grid, state_score_func, lambda x,y: 0)
    best_path_naive = v.viterbi_best_path()
    
    # run viterbi, with state transition cost
    
    sent2captures = run_multiple_random_hmms(num_sents,n=100)
    
    # evaluate
    print()
    print()
    print(color.BOLD+color.BLUE+"QUERY {}: {}".format(q, query)+color.END)
    print(color.BOLD+"==========================================================="+color.END)
    print(color.BOLD+"==========================================================="+color.END)

    for sent_ind,j_naive,orig_sent,tok2orig in zip(sorted(sent2captures.keys()),best_path_naive,orig_sents,mappings_to_orig):    
        if sent_ind > 15: break
            
        print(orig_sent)
        for k, (j, freq) in enumerate(Counter(sent2captures[sent_ind]).most_common(4)):
            if j in tok2orig:
              
                print(color.BOLD+color.GREEN+"ARG{}, option {}: {}".format(ARG_IND+1,k, orig_sent.split(" ")[tok2orig[j]])+color.END)
        #print("ARG1 NAIVE: {}".format(orig_sent.split(" ")[tok2orig[j_naive]]))
        if j_naive in tok2orig:
             print(color.BOLD+color.PURPLE+"ARG{}, naive: {}".format(ARG_IND+1,orig_sent.split(" ")[tok2orig[j_naive]])+color.END)
    
        else:
            print("none")
    
        print("---------------------------------------------")
# Out:
# (4620, 768)
#
#
# QUERY 1: <>arg1:virus $infection $causes a <>arg2:condition .
# ===========================================================
# ===========================================================
# Hepatotropic virus , like MHV-3 infection in mice , can induce exaggerated inflammation in the liver and cause life-threatening viral FH .
# ARG2, option 0: inflammation
# ARG2, option 1: can
# ARG2, option 2: in
# ARG2, naive: inflammation
# ---------------------------------------------
# In humans , CHIKV infections cause a debilitating disease with acute febrile illness and long-term polyarthralgia .
# ARG2, option 0: disease
# ARG2, option 1: illness
# ARG2, option 2: and
# ARG2, option 3: acute
# ARG2, naive: disease
# ---------------------------------------------
# MERS-CoV induces acute pneumonia similar to that caused by SARS-CoV , and is sometimes accompanied with renal failure ( Danielsson and Catchpole , 2012 ; Zaki et al. , 2012 ) .
# ARG2, option 0: pneumonia
# ARG2, option 1: acute
# ARG2, option 2: is
# ARG2, option 3: induces
# ARG2, naive: pneumonia
# ---------------------------------------------
# FIV infection causes progressive immunosuppression that results in the development of the acquired immunodeficiency syndrome ( AIDS ) in cats , which , similar to human HIV infection , increases susceptibility to secondary and opportunistic infections .
# ARG2, option 0: progressive
# ARG2, option 1: in
# ARG2, option 2: immunosuppression
# ARG2, option 3: causes
# ARG2, naive: immunosuppression
# ---------------------------------------------
# In humans , JEV infection can cause Japanese encephalitis ( JE ) with severe central nervous system disorders .
# ARG2, option 0: severe
# ARG2, option 1: disorders
# ARG2, option 2: In
# ARG2, option 3: can
# ARG2, naive: disorders
# ---------------------------------------------
# In immunocompetent adults , primary infection with HHV-6 can produce a mononucleosis-like illness and , more rarely , severe disease , including encephalitis [ Stoeckle , 2000 ] .
# ARG2, option 0: disease
# ARG2, option 1: illness
# ARG2, option 2: encephalitis
# ARG2, option 3: In
# ARG2, naive: disease
# ---------------------------------------------
# Infection with MV typically results in an acute febrile illness and rash due to viral replication first in mono-and lymphocytic cells , and then in a variety of tissues ( Katz 1995 ) .
# ARG2, option 0: illness
# ARG2, option 1: acute
# ARG2, option 2: Infection
# ARG2, option 3: an
# ARG2, naive: rash
# ---------------------------------------------
# BRV is a lytic infection and destruction of infected mucosal epithelial cells is an important component of disease pathogenesis .
# ARG2, option 0: disease
# ARG2, option 1: is
# ARG2, option 2: mucosal
# ARG2, naive: disease
# ---------------------------------------------
# FIV infection , in domestic cats , causes a variable immunodeficiency syndrome characterized by recurrent gingivitis-stomatitis , cachexia , wasting , neurology , and an increased incidence of tumor development [ 1 , 4 , 48 , 76 ] .
# ARG2, option 0: syndrome
# ARG2, option 1: a
# ARG2, option 2: by
# ARG2, option 3: and
# ARG2, naive: syndrome
# ---------------------------------------------
# Adenovirus infection can result in severe respiratory disease in lung transplant recipients , including rapidly progressive , necrotizing and potentially fatal pneumonia , as well as development of chronic lung disease with fibrosis and bronchiectasis ( Liu et al. 2010 ) .
# ARG2, option 0: disease
# ARG2, option 1: severe
# ARG2, option 2: pneumonia
# ARG2, option 3: in
# ARG2, naive: disease
# ---------------------------------------------
# Filovirusinduced disease begins with flu-like symptoms and progresses rapidly to the final stages of viral hemorrhagic fever infection , which are characterized by fever , hemorrhage , and hypotensive shock ( Groseth et al. , 2007 ; Zampieri et al. , 2007 ) .
# ARG2, option 0: disease
# ARG2, option 1: and
# ARG2, option 2: symptoms
# ARG2, option 3: hemorrhage
# ARG2, naive: disease
# ---------------------------------------------
# PEDV infects the epithelium of the small intestine , an environment rich in proteases , and causes atrophy of the villi resulting in diarrhea and dehydration .
# ARG2, option 0: diarrhea
# ARG2, option 1: atrophy
# ARG2, option 2: causes
# ARG2, option 3: in
# ARG2, naive: atrophy
# ---------------------------------------------
# In humans , coronavirus infection results in respiratory tract complications with varying degree of severity and has been associated with gastroenteritis .
# ARG2, option 0: complications
# ARG2, option 1: gastroenteritis
# ARG2, option 2: In
# ARG2, option 3: respiratory
# ARG2, naive: complications
# ---------------------------------------------
# Humans infected with RVFV usually develop an acute febrile myalgic syndrome ; however , a small percentage of patients have a lethal illness that results in hepatic damage , hemorrhagic fever-like illness , encephalitis and/or retinal vasculitis [ 8 ] .
# ARG2, option 0: syndrome
# ARG2, option 1: illness
# ARG2, option 2: damage
# ARG2, option 3: illness
# ARG2, naive: syndrome
# ---------------------------------------------
# PRRSV increases the susceptibility of the host to a wide range of viral and bacterial respiratory pathogens , resulting in increased severity of clinical signs and lung lesions .
# ARG2, option 0: severity
# ARG2, option 1: clinical
# ARG2, option 2: lesions
# ARG2, option 3: and
# ARG2, naive: severity
# ---------------------------------------------
# In humans , the virus causes a lower respiratory tract disease and may progress to ARDS , multiorgan failure , and death in severe cases .
# ARG2, option 0: disease
# ARG2, option 1: In
# ARG2, option 2: a
# ARG2, option 3: may
# ARG2, naive: disease
# ---------------------------------------------
# (5467, 768)
#
#
# QUERY 2: infected arg1:patients $usually $develop <>arg2:[entity]respiratory illness.
# ===========================================================
# ===========================================================
# After an incubation period of 5 to 14 days , SARS-CoV-2-infected people commonly manifest features of pneumonia , including fever , dry cough , dyspnoea , myalgia and fatigue .
# ARG2, option 0: pneumonia
# ARG2, option 1: fever
# ARG2, option 2: and
# ARG2, option 3: fatigue
# ARG2, naive: pneumonia
# ---------------------------------------------
# After an incubation period of 2 to 3 days , patients who have pneumonic plague typically develop fulminant pneumonia , with malaise , high fever , cough , hemoptysis , and septicemia with ecchymoses and extremity necrosis .
# ARG2, option 0: pneumonia
# ARG2, option 1: and
# ARG2, option 2: fever
# ARG2, option 3: cough
# ARG2, naive: pneumonia
# ---------------------------------------------
# Patients suffering from severe DENV infection often exhibit encephalopathy and encephalitis .
# ARG2, option 0: encephalitis
# ARG2, option 1: infection
# ARG2, option 2: and
# ARG2, option 3: severe
# ARG2, naive: encephalitis
# ---------------------------------------------
# Following an incubation period of usually 4 - 5 days , patients infected with SARS-CoV often present with symptoms of fever , headache , and myalgias .
# ARG2, option 0: fever
# ARG2, option 1: symptoms
# ARG2, option 2: and
# ARG2, option 3: headache
# ARG2, naive: fever
# ---------------------------------------------
# Cats with FIP show nonspecific clinical signs such as fever , weight loss and anorexia , often accompanied by body cavity effusions and/or ocular and neurological signs .
# ARG2, option 0: clinical
# ARG2, option 1: fever
# ARG2, option 2: and
# ARG2, option 3: by
# ARG2, naive: clinical
# ---------------------------------------------
# Cats with signs from FIV often have lethargy , anorexia and weight loss associated with secondary infections of the skin , and gastrointestinal or respiratory tracts .
# ARG2, option 0: have
# ARG2, option 1: and
# ARG2, option 2: have
# ARG2, option 3: FIV
# ARG2, naive: have
# ---------------------------------------------
# Enteric FCoV infection typically results in inappetence and/or mild gastrointestinal signs such as vomiting and diarrhea .
# ARG2, option 0: infection
# ARG2, option 1: and
# ARG2, option 2: diarrhea
# ARG2, option 3: vomiting
# ARG2, naive: gastrointestinal
# ---------------------------------------------
# Most patients with MERS develop severe acute respiratory illness accompanied by fever , cough , and shortness of breath [ 50 ] .
# ARG2, option 0: illness
# ARG2, option 1: fever
# ARG2, option 2: respiratory
# ARG2, option 3: severe
# ARG2, naive: illness
# ---------------------------------------------
# The terminal stages of Ebola virus infection usually include diffuse bleeding , and hypotensive shock accounts for many Ebola virus fatalities .
# ARG2, option 0: infection
# ARG2, option 1: bleeding
# ARG2, option 2: diffuse
# ARG2, option 3: shock
# ARG2, naive: diffuse
# ---------------------------------------------
# In rats , infection is usually asymptomatic , although nonspecific clinical signs such as weight loss and dyspnea may occur .
# ARG2, option 0: dyspnea
# ARG2, option 1: clinical
# ARG2, option 2: infection
# ARG2, option 3: and
# ARG2, naive: clinical
# ---------------------------------------------
# Following an average incubation period of 20 days , infected patients can present with severe headache , fever , chills , fatigue , and myalgia .
# ARG2, option 0: severe
# ARG2, option 1: fever
# ARG2, option 2: and
# ARG2, option 3: headache
# ARG2, naive: severe
# ---------------------------------------------
# Patients infected with EVD rapidly deteriorate and commonly present with gastrointestinal symptoms including vomiting , diarrhea and dehydration .
# ARG2, option 0: symptoms
# ARG2, option 1: dehydration
# ARG2, option 2: vomiting
# ARG2, option 3: and
# ARG2, naive: symptoms
# ---------------------------------------------
# Adult rabbits usually develop a chronic disease course , which can lead to intestinal fi brosis , liver necrosis and stenosis , and myocardial disease .
# ARG2, option 0: disease
# ARG2, option 1: and
# ARG2, option 2: disease
# ARG2, option 3: intestinal
# ARG2, naive: disease
# ---------------------------------------------
# Cats are primarily infected subclinically , but gastrointestinal disease manifested as enterocolitis and endotoxemia can occur and is initially associated with fever , malaise , and anorexia followed by vomiting , abdominal pain , and diarrhoea [ 7 ] .
# ARG2, option 0: disease
# ARG2, option 1: fever
# ARG2, option 2: and
# ARG2, option 3: vomiting
# ARG2, naive: disease
# ---------------------------------------------
# Affected rabbits usually develop sepsis , which quickly leads to death ; however , diarrhea may occur as well .
# ARG2, option 0: sepsis
# ARG2, option 1: diarrhea
# ARG2, naive: sepsis
# ---------------------------------------------
# Affected rabbits usually develop sepsis , which quickly leads to death ; however , diarrhea may occur as well .
# ARG2, option 0: sepsis
# ARG2, option 1: diarrhea
# ARG2, naive: sepsis
# ---------------------------------------------
# (4851, 768)
#
#
# QUERY 3: a arg1:subset of patients $progress to arg2:hemorrhagic fever
# ===========================================================
# ===========================================================
# In severe cases , dyspnea and/or hypoxemia usually occur one week after the onset of the disease , and in severe cases , it rapidly progresses to acute respiratory distress syndrome , septic shock , metabolic acidosis that is difficult to correct , and bleeding and coagulation dysfunction .
# ARG2, option 0: severe
# ARG2, option 1: to
# ARG2, option 2: acute
# ARG2, option 3: disease
# ARG2, naive: severe
# ---------------------------------------------
# In severe cases , the disease may progress to respiratory , circulatory , and renal failure , and ultimately death due to multiorgan failure .
# ARG2, option 0: severe
# ARG2, option 1: respiratory
# ARG2, option 2: to
# ARG2, option 3: may
# ARG2, naive: severe
# ---------------------------------------------
# While disease is often mild with cold-like symptoms , it can progress to severe presentations such as bronchiolitis or pneumonia requiring hospitalization or resulting in death .
# ARG2, option 0: severe
# ARG2, option 1: to
# ARG2, option 2: pneumonia
# ARG2, option 3: as
# ARG2, naive: severe
# ---------------------------------------------
# In some cases , rapid progression of lung consolidation occurs , leading to respiratory failure and death .
# ARG2, option 0: respiratory
# ARG2, option 1: rapid
# ARG2, option 2: to
# ARG2, option 3: lung
# ARG2, naive: respiratory
# ---------------------------------------------
# In severe cases , the illness can progress to the development of interstitial pneumonia , acute respiratory distress syndrome , meningoencephalitis , acute kidney injury , or disseminated intravascular coagulation .
# ARG2, option 0: severe
# ARG2, option 1: pneumonia
# ARG2, option 2: to
# ARG2, option 3: can
# ARG2, naive: severe
# ---------------------------------------------
# Severe cases can develop dyspnea and hypoxemia after 1 week of onset , and may quickly progress to acute respiratory distress syndrome , persistent metabolic acidosis , coagulation dysfunction , and multiple organ failure .
# ARG2, option 0: Severe
# ARG2, option 1: to
# ARG2, option 2: acute
# ARG2, option 3: respiratory
# ARG2, naive: Severe
# ---------------------------------------------
# Persistent high fever may occur in severe patients , with rapid progress of the conditions into apparent pneumonia , acute lung injury , and acute respiratory distress syndrome .
# ARG2, option 0: severe
# ARG2, option 1: acute
# ARG2, option 2: lung
# ARG2, option 3: pneumonia
# ARG2, naive: severe
# ---------------------------------------------
# Mild infections may be self-limiting in few days , but in some cases the respiratory symptoms can develop into acute respiratory distress syndrome ( ARDS ) with a high risk of death from multiorgan failure .
# ARG2, option 0: respiratory
# ARG2, option 1: Mild
# ARG2, option 2: can
# ARG2, option 3: acute
# ARG2, naive: respiratory
# ---------------------------------------------
# Severe cases may progress to a capillary leak syndrome with septic shock , rash , facial and neck swelling , and multi-organ system failure .
# ARG2, option 0: Severe
# ARG2, option 1: to
# ARG2, option 2: a
# ARG2, option 3: septic
# ARG2, naive: Severe
# ---------------------------------------------
# In severe cases , the pneumonia rapidly progresses to acute respiratory distress syndrome and multiorgan failure .
# ARG2, option 0: to
# ARG2, option 1: severe
# ARG2, option 2: acute
# ARG2, option 3: pneumonia
# ARG2, naive: severe
# ---------------------------------------------
# In critical patients , the disease progresses rapidly , and dyspnea may occur 1 week after onset and may advance to acute respiratory distress syndrome , sepsis , internal environmental imbalance , and multiple organ dysfunction syndrome .
# ARG2, option 0: acute
# ARG2, option 1: to
# ARG2, option 2: critical
# ARG2, option 3: respiratory
# ARG2, naive: acute
# ---------------------------------------------
# Symptoms can progress to a severe form of pneumonia with critical complications , including septic shock , pulmonary edema , acute respiratory distress syndrome and multi-organ failure .
# ARG2, option 0: severe
# ARG2, option 1: pulmonary
# ARG2, option 2: to
# ARG2, option 3: pneumonia
# ARG2, naive: severe
# ---------------------------------------------
# Some patients with BCC develop a life-threatening , sometimes necrotizing , pneumonia , associated with bacteremia and severe respiratory failure .
# ARG2, option 0: severe
# ARG2, option 1: respiratory
# ARG2, option 2: a
# ARG2, naive: severe
# ---------------------------------------------
# Mild disease may resolve without medical care or may progress to pneumonia and respiratory failure requiring hospitalization .
# ARG2, option 0: respiratory
# ARG2, option 1: to
# ARG2, option 2: pneumonia
# ARG2, option 3: Mild
# ARG2, naive: respiratory
# ---------------------------------------------
# The disease may progress into respiratory failure comparable with an acute respiratory distress syndrome ( ARDS ) .
# ARG2, option 0: respiratory
# ARG2, option 1: disease
# ARG2, option 2: may
# ARG2, option 3: into
# ARG2, naive: respiratory
# ---------------------------------------------
# Some cases of viral pneumonia have a rapid and relentless fatal course , with generalized alveolar and interstitial opacities , development of the adult respiratory distress syndrome ( ARDS ) , and progressive respiratory failure .
# ARG2, option 0: respiratory
# ARG2, option 1: progressive
# ARG2, option 2: viral
# ARG2, option 3: pneumonia
# ARG2, naive: progressive
# ---------------------------------------------
# (4235, 768)
#
#
# QUERY 4: people with arg1:[e]asthma are $susceptible to arg2:[e]asthma
# ===========================================================
# ===========================================================
# Patients with lung cancer are highly susceptible to infection compared to healthy individuals because of systemic immunosuppression induced by malignancy and anticancer therapy .
# ARG2, option 0: infection
# ARG2, naive: infection
# ---------------------------------------------
# Patients with lung cancer are highly susceptible to infection compared to healthy individuals because of systemic immunosuppression induced by malignancy and anticancer therapy .
# ARG2, option 0: infection
# ARG2, naive: infection
# ---------------------------------------------
# Patients with ARDS triggered by viral infection , in particular influenza , are prone to invasive aspergillosis even in absence of prior immunodeficiency .
# ARG2, option 0: infection
# ARG2, option 1: invasive
# ARG2, option 2: influenza
# ARG2, option 3: Patients
# ARG2, naive: invasive
# ---------------------------------------------
# Individuals with SCD are strongly susceptible to encapsulated bacterial organisms such as S. pneumoniae , a common colonizer of the nasopharynx in healthy children .
# ARG2, option 0: organisms
# ARG2, option 1: are
# ARG2, option 2: bacterial
# ARG2, naive: organisms
# ---------------------------------------------
# Individuals with diabetes , immunosuppressive disorders , and liver disease including hemochromatosis and alcoholic liver disease are especially susceptible to infection .
# ARG2, option 0: infection
# ARG2, naive: infection
# ---------------------------------------------
# Moreover , children receiving immunomodulatory or immunosuppressive therapies due to malignancy , transplantation , or autoimmune disease are more susceptible to viral infection or reactivation .
# ARG2, option 0: infection
# ARG2, option 1: viral
# ARG2, option 2: reactivation
# ARG2, option 3: children
# ARG2, naive: infection
# ---------------------------------------------
# Accordingly , young children , compared with adult transplant recipients , are at higher risk of acquiring primary infection with many organisms after they are immunosuppressed , which can lead to increased severity .
# ARG2, option 0: infection
# ARG2, option 1: organisms
# ARG2, naive: infection
# ---------------------------------------------
# On one hand , elderly patients are at risk for gram-negative and anaerobic polymicrobial aspiration pneumonia , and on the other hand are more prone to bacterial superinfections following influenza infection .
# ARG2, option 0: infection
# ARG2, option 1: pneumonia
# ARG2, option 2: bacterial
# ARG2, option 3: influenza
# ARG2, naive: infection
# ---------------------------------------------
# Patients with cancer are known to be at an increased risk for community-acquired respiratory viruses , such as influenza , because of their frequently observed immunocompromised state .
# ARG2, option 0: viruses
# ARG2, option 1: influenza
# ARG2, option 2: Patients
# ARG2, naive: viruses
# ---------------------------------------------
# However , immunocompromised patients , including those with HIV/AIDS and patients taking immunosuppressants post-transplant , are at an increased risk for viral and fungal pneumonia .
# ARG2, option 0: pneumonia
# ARG2, naive: pneumonia
# ---------------------------------------------
# Although the incidence of RSV infection is low among patients with AML , it is associated with high mortality in children with AML [ 21 ] , and it is well known that infants , both immunocompetent and immunocompromised , are particularly vulnerable to RSV .
# ARG2, option 0: infection
# ARG2, option 1: RSV
# ARG2, naive: infection
# ---------------------------------------------
# However , neonates , older individuals , and those with immune deficiencies are prone to more frequent and more serious CNS viral infections .
# ARG2, option 0: infections
# ARG2, naive: infections
# ---------------------------------------------
# However , immunocompromised individuals , both children and adults , are prone to develop severe illness as a result of HPIV infection .
# ARG2, option 0: infection
# ARG2, option 1: are
# ARG2, naive: infection
# ---------------------------------------------
# Due to the physiological changes in their immune and cardiopulmonary systems , pregnant women are more likely to develop severe illness after infection with respiratory viruses .
# ARG2, option 0: infection
# ARG2, option 1: illness
# ARG2, option 2: viruses
# ARG2, naive: infection
# ---------------------------------------------
# Due to the physiological changes in their immune and cardiopulmonary systems , pregnant women are more likely to develop severe illness after infection with respiratory viruses .
# ARG2, option 0: infection
# ARG2, option 1: illness
# ARG2, option 2: viruses
# ARG2, option 3: are
# ARG2, naive: infection
# ---------------------------------------------
# The patients with rheumatic immune diseases have immune dysfunction and are often on glucocorticoid and immunosuppressant therapy , which in turn predispose them to an increased risk of contracting SARS-CoV-2 infection .
# ARG2, option 0: infection
# ARG2, naive: infection
# ---------------------------------------------
# (5159, 768)
#
#
# QUERY 5: arg1:[e]paracetamol is $not useful for treating arg2:[e]asthma.
# ===========================================================
# ===========================================================
# However , while tocilizumab is a promising agent against COVID-19 , it is not an appropriate agent in patients with active or latent tuberculosis , bacterial and fungal infections , multi-organ failure , and gastrointestinal perforation [ 7 ] .
# ARG2, option 0: [
# ARG2, option 1: patients
# ARG2, option 2: tuberculosis
# ARG2, option 3: However
# ARG2, naive: tuberculosis
# ---------------------------------------------
# There are cases of ADEM or even fulminant presentation such as AHL where steroids alone are not sufficient for suppressing inflammation and improving clinical findings .
# ARG2, option 0: inflammation
# ARG2, naive: inflammation
# ---------------------------------------------
# Thus , ribavirin may not be useful for treating SARS infections because of its questionable efficacy and because of its known toxicity ( reviewed by van Vonderen et al. , 2003 ; Lai , 2005 ) .
# ARG2, option 0: SARS
# ARG2, option 1: infections
# ARG2, naive: SARS
# ---------------------------------------------
# In general , steroid therapy is not recommended in the clinical treatment of SARS-CoV-2 [ 103 ] .
# ARG2, option 0: treatment
# ARG2, option 1: of
# ARG2, option 2: of
# ARG2, option 3: [
# ARG2, naive: of
# ---------------------------------------------
# In fact , steroids are not recommended in COVID-19 infection outside of clinical trial because of potential increased risk of mechanical ventilation ( 10 ) .
# ARG2, option 0: infection
# ARG2, option 1: (
# ARG2, option 2: in
# ARG2, naive: infection
# ---------------------------------------------
# Patients with PCP typically die due to refractory hypoxemia from severe respiratory failure , and corticosteroids have failed to demonstrate benefit outside of the HIV population [ 62 , 63 ] .
# ARG2, option 0: Patients
# ARG2, option 1: HIV
# ARG2, option 2: [
# ARG2, option 3: with
# ARG2, naive: population
# ---------------------------------------------
# In addition , steroids are not effective for the treatment of lung injury or shock in adults ' SARS-CoV-2 infection [ 11 ] .
# ARG2, option 0: infection
# ARG2, option 1: [
# ARG2, option 2: of
# ARG2, option 3: in
# ARG2, naive: '
# ---------------------------------------------
# Corticosteroids in the treatment of SARS-CoV-2 pneumonia are not usually recommended ; they may delay virus clearance from the body [ 1 , 3 ] .
# ARG2, option 0: virus
# ARG2, option 1: pneumonia
# ARG2, option 2: of
# ARG2, option 3: [
# ARG2, naive: of
# ---------------------------------------------
# At present , there is no effective therapeutic agent against CVB3 , and only ribavirin is available for CVB3 infection despite its weak antiviral activity [ 93 ] .
# ARG2, option 0: infection
# ARG2, option 1: [
# ARG2, option 2: for
# ARG2, naive: infection
# ---------------------------------------------
# Drugs currently licensed for the treatment of systemic CMV infections have limited therapeutic effectiveness due to dose-limiting toxicities , and prolonged therapy often results in resistance ( Biron , 2006 ) .
# ARG2, option 0: infections
# ARG2, option 1: CMV
# ARG2, option 2: of
# ARG2, option 3: (
# ARG2, naive: CMV
# ---------------------------------------------
# Most of the TCM agents are mildly effective and slow-acting , and therefore , should not be used as the only treatment modality due to the rapid progression of disease .
# ARG2, option 0: disease
# ARG2, option 1: of
# ARG2, option 2: treatment
# ARG2, naive: disease
# ---------------------------------------------
# In addition , antivirals such as NA inhibitors and M2 blockers have limited efficacy in severe cases of influenza infection if not administered within 48 hours from symptoms onset and may select for resistance .
# ARG2, option 0: influenza
# ARG2, option 1: infection
# ARG2, option 2: of
# ARG2, naive: infection
# ---------------------------------------------
# The efficacy rate is also low in children , and the treatment is normally ineffective in secondary ITP with underlying diseases , such as systemic lupus erythematosus [ 25 ] .
# ARG2, option 0: treatment
# ARG2, option 1: [
# ARG2, option 2: in
# ARG2, option 3: children
# ARG2, naive: underlying
# ---------------------------------------------
# However , the use of corticosteroids in the treatment of COVID-19 can cause host immune suppression and delay viral clearance .
# ARG2, option 0: viral
# ARG2, option 1: host
# ARG2, option 2: of
# ARG2, option 3: However
# ARG2, naive: host
# ---------------------------------------------
# However , the clinical use of interferon to treat dengue is not common , possibly due to IFN-α side effects associated with its systemic activity .
# ARG2, option 0: dengue
# ARG2, option 1: However
# ARG2, option 2: is
# ARG2, option 3: treat
# ARG2, naive: dengue
# ---------------------------------------------
# Unfortunately , a consistent benefit has not been observed in all clinical trials and ribavirin is currently not considered to be a drug of choice for influenza .
# ARG2, option 0: influenza
# ARG2, option 1: for
# ARG2, option 2: and
# ARG2, option 3: clinical
# ARG2, naive: influenza
# ---------------------------------------------
# (3311, 768)
#
#
# QUERY 6: arg1:[e]stroke is a $complication of :[e]COVID-19 arg2:infection
# ===========================================================
# ===========================================================
# Acute kidney injury is a possible manifestation in severe forms of COVID-19 , conferring a high mortality 7 .
# ARG2, option 0: is
# ARG2, option 1: of
# ARG2, option 2: of
# ARG2, option 3: severe
# ARG2, naive: of
# ---------------------------------------------
# Coagulation dysfunction is one of the major causes for death in patients with severe COVID-19 [ 4 ] .
# ARG2, option 0: patients
# ARG2, option 1: severe
# ARG2, option 2: is
# ARG2, naive: patients
# ---------------------------------------------
# Coagulopathy is one of the main complications occurring in hospitalized patients with severe COVID -19 .
# ARG2, option 0: patients
# ARG2, option 1: COVID
# ARG2, option 2: is
# ARG2, naive: patients
# ---------------------------------------------
# Hypoxia is the most common manifestation of patients with COVID-19 , especially in severely or critically ill patients .
# ARG2, option 0: patients
# ARG2, option 1: is
# ARG2, option 2: with
# ARG2, option 3: with
# ARG2, naive: patients
# ---------------------------------------------
# Early-onset pneumonia is a common and severe complication that is related to aspiration in patients with GBS .
# ARG2, option 0: patients
# ARG2, option 1: is
# ARG2, option 2: pneumonia
# ARG2, naive: patients
# ---------------------------------------------
# Barotrauma is a common complication in patients with SARS .
# ARG2, option 0: patients
# ARG2, option 1: is
# ARG2, option 2: in
# ARG2, naive: patients
# ---------------------------------------------
# COVID-19 infection is associated with several cardiac complications with high rates of adverse outcomes .
# ARG2, option 0: infection
# ARG2, option 1: is
# ARG2, naive: infection
# ---------------------------------------------
# COVID-19 infection is associated with several cardiac complications with high rates of adverse outcomes .
# ARG2, option 0: infection
# ARG2, option 1: is
# ARG2, naive: infection
# ---------------------------------------------
# AKI is one of the common complications with COVID-19 , and is associated with increased morbidity and mortality .
# ARG2, option 0: is
# ARG2, option 1: with
# ARG2, option 2: with
# ARG2, option 3: with
# ARG2, naive: with
# ---------------------------------------------
# Spontaneous pneumothorax is a specific and potentially life-threatening complication in SARS patients .
# ARG2, option 0: patients
# ARG2, option 1: is
# ARG2, naive: patients
# ---------------------------------------------
# COVID-19 pneumonia may lead to acute respiratory distress syndrome and severe respiratory failure ( 1 ) .
# ARG2, option 0: pneumonia
# ARG2, option 1: may
# ARG2, naive: pneumonia
# ---------------------------------------------
# Pneumonia is the most frequent and serious complication of COVID-19 , due to excessive host immune response causing an acute respiratory distress syndrome .
# ARG2, option 0: of
# ARG2, option 1: is
# ARG2, option 2: of
# ARG2, option 3: of
# ARG2, naive: of
# ---------------------------------------------
# Acute respiratory distress syndrome developing in patients with COVID-19 pneumonia is associated with a high mortality rate and is the main cause of death in patients with SRAS-Cov-2 infection [ 1 ] .
# ARG2, option 0: infection
# ARG2, option 1: patients
# ARG2, option 2: is
# ARG2, option 3: with
# ARG2, naive: infection
# ---------------------------------------------
# Pneumonia is a life-threatening complication of COVID-19 infection 10 .
# ARG2, option 0: infection
# ARG2, option 1: is
# ARG2, option 2: of
# ARG2, option 3: of
# ARG2, naive: infection
# ---------------------------------------------
# ARDS and shock are common complications that can lead to death in COVID-19 patients .
# ARG2, option 0: patients
# ARG2, option 1: in
# ARG2, option 2: in
# ARG2, naive: patients
# ---------------------------------------------
# Multiorgan injury , which significantly increases mortality , is often evident in patients with COVID-19 .
# ARG2, option 0: patients
# ARG2, option 1: with
# ARG2, option 2: with
# ARG2, option 3: is
# ARG2, naive: patients
# ---------------------------------------------
# (5313, 768)
#
#
# QUERY 7: the recommended arg1:[w]quarantine period is arg2:14 :[w]days
# ===========================================================
# ===========================================================
# If we aim to control the failure rate of quarantine to be below 1 % with 95 % confidence , then the quarantine period must be at least 22 days .
# ARG2, option 0: 22
# ARG2, option 1: days
# ARG2, naive: 22
# ---------------------------------------------
# In general , the duration of the quarantine period should be 21 to 30 days .
# ARG2, option 0: 30
# ARG2, option 1: days
# ARG2, option 2: 21
# ARG2, option 3: duration
# ARG2, naive: 30
# ---------------------------------------------
# Although for extreme cases , the quarantine period should be extended up to three weeks .
# ARG2, option 0: three
# ARG2, option 1: weeks
# ARG2, option 2: the
# ARG2, option 3: extreme
# ARG2, naive: three
# ---------------------------------------------
# At the beginning and the end of a SARS epidemic , to control the epidemic completely , we recommend a period of 22 days for quarantine , which would capture 99 percent of all probable SARS cases with a probability of 0.9 .
# ARG2, option 0: 22
# ARG2, option 1: days
# ARG2, naive: 22
# ---------------------------------------------
# Based on the 95th percentile estimate of the incubation period , we recommend that the length of quarantine should be at least 14 days .
# ARG2, option 0: 14
# ARG2, option 1: days
# ARG2, naive: 14
# ---------------------------------------------
# Based on the 95th percentile estimate of the incubation period , we recommend that the length of quarantine should be at least 14 days .
# ARG2, option 0: 14
# ARG2, naive: 14
# ---------------------------------------------
# As such , the quarantine period should be extended up to three weeks .
# ARG2, option 0: three
# ARG2, option 1: weeks
# ARG2, option 2: the
# ARG2, option 3: period
# ARG2, naive: three
# ---------------------------------------------
# For example , if the rate of transmission is reduced by 10 % , the quarantine from symptom onset needs to be implemented within 32.37 h.
# ARG2, option 0: within
# ARG2, option 1: 10
# ARG2, option 2: within
# ARG2, option 3: the
# ARG2, naive: within
# ---------------------------------------------
# If testing is not done , the quarantine period should at least exceed the incubation and shedding period of the diseases of concern .
# ARG2, option 0: the
# ARG2, option 1: period
# ARG2, option 2: should
# ARG2, option 3: exceed
# ARG2, naive: exceed
# ---------------------------------------------
# Therefore , the quarantine period should be around 2 weeks after a close contact with a person with symptoms .
# ARG2, option 0: 2
# ARG2, option 1: weeks
# ARG2, option 2: after
# ARG2, option 3: Therefore
# ARG2, naive: 2
# ---------------------------------------------
# As per the CDC guidelines , 14 days should be the period of quarantine ( Science Daily website ) .
# ARG2, option 0: 14
# ARG2, option 1: days
# ARG2, naive: 14
# ---------------------------------------------
# The quarantine period is typically 30 days .
# ARG2, option 0: 30
# ARG2, option 1: days
# ARG2, option 2: The
# ARG2, naive: 30
# ---------------------------------------------
# Because a longer and more volatile incubation period has been observed in travelers , the duration of quarantine should be extended to 3 weeks .
# ARG2, option 0: 3
# ARG2, option 1: weeks
# ARG2, naive: 3
# ---------------------------------------------
# The time for which a patient can infect others varies between 7 and 14 days for moderate cases according to [ 3 ] , and this is why quarantine should last at least two weeks .
# ARG2, option 0: 14
# ARG2, option 1: days
# ARG2, naive: 14
# ---------------------------------------------
# Therefore , we suggest that the appropriate duration of quarantine is 4 days .
# ARG2, option 0: 4
# ARG2, option 1: days
# ARG2, naive: 4
# ---------------------------------------------
# A quarantine period of at least 15 days should allow adequate time for the return and evaluation of test data .
# ARG2, option 0: 15
# ARG2, option 1: days
# ARG2, naive: 15
# ---------------------------------------------
# (5082, 768)
#
#
# QUERY 8: arg1:[e]COVID-19 $infects arg2:cells
# ===========================================================
# ===========================================================
# SARS-CoV targets human angiotensin-converting enzyme 2 ( hACE2 ) and infects intrapulmonary epithelial cells more than cells of the upper airways [ 13 , 14 ] .
# ARG2, option 0: cells
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 infects ACE2 + cells in the oral mucosa and lungs , including ACE-2 cells in the alveoli [ 97 ] .
# ARG2, option 0: cells
# ARG2, naive: cells
# ---------------------------------------------
# Like other viruses , SARS-CoV-2 infects lung alveolar epithelial cells using receptor-mediated endocytosis via the angiotensin-converting enzyme II ( ACE2 ) as an entry receptor [ 4 ] .
# ARG2, option 0: cells
# ARG2, option 1: lung
# ARG2, naive: cells
# ---------------------------------------------
# Initially , SARS-CoV-2 infects cells in the respiratory system and causes inflammation and cell death .
# ARG2, option 0: cells
# ARG2, option 1: respiratory
# ARG2, naive: cells
# ---------------------------------------------
# The SARA-CoV-2 primarily invades alveolar epithelial cells and interacts with ACE2 , leading to respiratory symptoms in patients [ 33 ] .
# ARG2, option 0: cells
# ARG2, option 1: alveolar
# ARG2, naive: cells
# ---------------------------------------------
# In the lungs , SARS-CoV-2 infects type I and type II alveolar epithelial cells , as well as alveolar macrophages that are among the first producers of pro-inflammatory cytokines .
# ARG2, option 0: cells
# ARG2, option 1: lungs
# ARG2, option 2: alveolar
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 binds to the ACE2 receptor on ciliated bronchial epithelial cells to gain entry into these cells for viral replication and dissemination in the airway [ 6 ] .
# ARG2, option 0: cells
# ARG2, option 1: airway
# ARG2, option 2: cells
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 infects ACE2positive cells in the oral mucosa and lungs , including ACE2 + AT2 cells in the alveoli .
# ARG2, option 0: cells
# ARG2, option 1: the
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV enters host cells by a mechanism involving the interaction between its spike ( S ) protein and human angiotensin-converting enzyme 2 ( ACE2 ) expressed on host cells in the lung [ 5 ] .
# ARG2, option 0: cells
# ARG2, option 1: host
# ARG2, naive: cells
# ---------------------------------------------
# Research has demonstrated that COVID-19 is caused by the severe acute respiratory syndrome coronavirus 2 ( SARS-CoV-2 ) , which enters the cells by binding to the angiotensin-converting enzyme 2 ( ACE2 ) receptor .
# ARG2, option 0: cells
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 invades target cells via its spike proteins , which bind to angiotensin-converting enzyme (ACE)-2 receptors that are widely distributed in many types of human cells , including the alveolar type II cells in the lungs [ 71 , 72 ] .
# ARG2, option 0: cells
# ARG2, option 1: cells
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 infects human epithelial cells through the host cell receptor angiotensin-converting enzyme II ( ACE2 ) , which is expressed on cells lining the lungs , oral buccal and gingiva ( 19 ) .
# ARG2, option 0: cells
# ARG2, naive: cells
# ---------------------------------------------
# SARS-CoV-2 can infect cells via the angiotensin-converting enzyme 2 ( ACE2 ) receptor which is ubiquitous but largely expressed in endothelial cells [ 10 ] .
# ARG2, option 0: cells
# ARG2, option 1: cells
# ARG2, naive: cells
# ---------------------------------------------
# Similar to SARS-CoV , SARS-CoV-2 exploits angiotensin-converting enzyme 2 ( ACE2 ) as a receptor to invade cells , notably type II alveolar epithelial cells .
# ARG2, option 0: cells
# ARG2, option 1: cells
# ARG2, naive: cells
# ---------------------------------------------
# The SARS-Cov-2 first predominantly infects lower airways and binds to ACE2 on alveolar epithelial cells .
# ARG2, option 0: cells
# ARG2, option 1: alveolar
# ARG2, option 2: airways
# ARG2, naive: cells
# ---------------------------------------------
# Like a related coronavirus that emerged in 2003 , SARS-CoV-2 enters human cells by binding to the extracellular domain of Angiotensin Converting Enzyme 2 ( ACE2 ) [ 14 , 15 ] .
# ARG2, option 0: cells
# ARG2, naive: cells
# ---------------------------------------------
# (6776, 768)
#
#
# QUERY 9: arg1:[e]COVID-19 activates the arg2:ATP $receptor
# ===========================================================
# ===========================================================
# Human angiotensin-converting enzyme 2 ( ACE2 ) is a functional receptor hijacked by SARS-CoV-2 for cell entry , similar to SARS-CoV [ 8 , 16 ] .
# ARG2, option 0: enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: receptor
# ARG2, option 3: (
# ARG2, naive: enzyme
# ---------------------------------------------
# Molecularly , like SARS-CoV , the SARS-CoV-2 virus likely uses ACE-2 as entry receptor , which is highly expressed in the lung and gastrointestinal tract [ 10 ] [ 11 ] [ 12 ] .
# ARG2, option 0: receptor
# ARG2, option 1: ACE-2
# ARG2, option 2: uses
# ARG2, option 3: uses
# ARG2, naive: receptor
# ---------------------------------------------
# SARS-CoV-2 enters respiratory epithelial cells by attaching to angiotensin converting enzyme-2 ( ACE-2 ) via S-protein ; ACE-2 is also a receptor for SARS-CoV-1 [ 27 ] .
# ARG2, option 0: converting
# ARG2, option 1: receptor
# ARG2, option 2: angiotensin
# ARG2, option 3: ACE-2
# ARG2, naive: converting
# ---------------------------------------------
# With regard to COVID-19 , it is known that the angiotensin-converting enzyme 2 ( ACE2 ) ACE2 provides the cell membrane receptor entry point for SARS-CoV-2 .
# ARG2, option 0: enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: receptor
# ARG2, option 3: the
# ARG2, naive: enzyme
# ---------------------------------------------
# It is now known that SARS-CoV-2 utilizes the same receptor of SARS-CoV , which is angiotensin converting enzyme II ( ACE2 ) for viral entry into the host cells [ 5 , 40 ] .
# ARG2, option 0: enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: receptor
# ARG2, option 3: (
# ARG2, naive: enzyme
# ---------------------------------------------
# Both SARS-CoV and SARS-CoV-2 infect human respiratory epithelial cells through the interaction of spike protein with human ACE2 , and only cells expressing ACE2 can be infected with SARS-CoV-2 in vitro [ 25 ] .
# ARG2, option 0: ACE2
# ARG2, option 1: human
# ARG2, naive: human
# ---------------------------------------------
# Like a related coronavirus that emerged in 2003 ( Li et al. , 2003 ) , SARS-CoV-2 enters human cells by binding to the extracellular domain of Angiotensin Converting Enzyme 2 ( ACE2 ) ( Hoffmann et al. , 2020 ; Zhou et al. , 2020 ) .
# ARG2, option 0: Enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: cells
# ARG2, option 3: (
# ARG2, naive: Enzyme
# ---------------------------------------------
# SARS-CoV-2 , much like the structurally similar and precedent SARS-CoV , uses the ACE2 receptor to establish host uptake [ 2 ] .
# ARG2, option 0: ACE2
# ARG2, option 1: receptor
# ARG2, option 2: the
# ARG2, naive: ACE2
# ---------------------------------------------
# SARS-CoV-2 seems to use the same cell entry receptor , ACE2 , as the SARS-CoV because ACE2 shows binding to RBD of both SARS-CoV and SARS-CoV-2 [ 11 ] .
# ARG2, option 0: ACE2
# ARG2, option 1: receptor
# ARG2, option 2: ,
# ARG2, option 3: cell
# ARG2, naive: cell
# ---------------------------------------------
# SARS-CoV-2 exploits the ACE-2 receptor , the same receptor as SARS , in the human lower respiratory tract for entry into lung cells [ 41 , 42 ] .
# ARG2, option 0: receptor
# ARG2, option 1: ACE-2
# ARG2, option 2: the
# ARG2, option 3: the
# ARG2, naive: the
# ---------------------------------------------
# Similar to severe acute respiratory syndrome-associated coronavirus ( SARS-CoV ) 16 , 17 , the SARS-CoV-2 employs angiotensin-converting enzyme-2 ( ACE2 ) as a receptor for cellular entry .
# ARG2, option 0: angiotensin-converting
# ARG2, option 1: ACE2
# ARG2, option 2: (
# ARG2, option 3: receptor
# ARG2, naive: angiotensin-converting
# ---------------------------------------------
# Like SARS-CoV , 2019-nCoV may use angiotensin-converting enzyme 2 ( ACE2 ) as a potential receptor for host cell infectivity [ 17 ] .
# ARG2, option 0: enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: receptor
# ARG2, option 3: (
# ARG2, naive: enzyme
# ---------------------------------------------
# The SARS-CoV-2 virus utilizes Angiotensin Converting Enzyme 2 ( ACE2 ) receptors as its cell surface receptor , similar to the SARS 2002 - 3 virus .
# ARG2, option 0: Enzyme
# ARG2, option 1: ACE2
# ARG2, option 2: receptor
# ARG2, option 3: Angiotensin
# ARG2, naive: Enzyme
# ---------------------------------------------
# Presumably , SARS-CoV infects cells through the S protein , which binds to cell surface receptor-angiotensin-converting enzyme 2 [ 4 ] .
# ARG2, option 0: enzyme
# ARG2, option 1: 2
# ARG2, option 2: cell
# ARG2, option 3: surface
# ARG2, naive: enzyme
# ---------------------------------------------
# SARS-CoV-2 utilizes ACE2 as a receptor for entry into the host pneumocytes [ 13 ] .
# ARG2, option 0: ACE2
# ARG2, option 1: receptor
# ARG2, option 2: utilizes
# ARG2, naive: ACE2
# ---------------------------------------------
# Several studies also confirm that SARS-CoV-2 also leverages the ACE2 receptor to gain entry into target cells ( 5 ) ( 6 ) ( 7 ) .
# ARG2, option 0: ACE2
# ARG2, option 1: receptor
# ARG2, option 2: the
# ARG2, naive: ACE2
# ---------------------------------------------
